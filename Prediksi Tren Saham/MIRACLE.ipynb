# %% [markdown]
# # Import Library

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 

# Metode
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_iris
from sklearn.gaussian_process.kernels import RBF
from sklearn.datasets import make_classification
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler


# Klasifikasi
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.dummy import DummyClassifier
from sklearn.linear_model import SGDClassifier

# %% [markdown]
# # Dataset

# %%
dataset_telkom = pd.read_csv("Telkovid.csv")
dataset_freen = pd.read_csv("Frenvid.csv")
dataset_indosat = pd.read_csv("vidisat.csv")

TELKM = dataset_telkom.values
ISAT = dataset_indosat.values
FREEN = dataset_freen.values

# %%
# Tampil Telkom
print(dataset_telkom)


# Tampil Telkom Index 1
print(dataset_telkom.iloc[:,1])
# Out:
#            Date  Open  High   Low  Close  new case  death
# 0     3/16/2020  3300  3300  3160   3160        21      1
# 1     3/17/2020  3160  3160  2940   2940        17      0
# 2     3/18/2020  3010  3080  2740   2810        38      0
# 3     3/19/2020  2810  2810  2620   2620         0      0
# 4     3/20/2020  2660  2990  2450   2880        55     14
# ..          ...   ...   ...   ...    ...       ...    ...
# 165  11/23/2020  3230  3340  3220   3320      4360    110
# 166  11/24/2020  3350  3380  3330   3350      4442    118
# 167  11/25/2020  3370  3390  3280   3280      4192    109
# 168  11/26/2020  3280  3480  3280   3470      5534    114
# 169  11/27/2020  3480  3500  3420   3460      4917    127
#
# [170 rows x 7 columns]
# 0      3300
# 1      3160
# 2      3010
# 3      2810
# 4      2660
#        ...
# 165    3230
# 166    3350
# 167    3370
# 168    3280
# 169    3480
# Name: Open, Length: 170, dtype: int64

# %%
# Tampil ISAT
print(dataset_indosat)

# Tampil ISAT Index 1
print(dataset_indosat.iloc[:,1])
# Out:
#            Date  Open  High   Low  Close  new case  death
# 0     3/16/2020  1685  1685  1580   1580        21      1
# 1     3/17/2020  1570  1580  1470   1470        17      0
# 2     3/18/2020  1480  1500  1370   1370        38      0
# 3     3/19/2020  1370  1370  1275   1275         0      0
# 4     3/20/2020  1260  1375  1190   1375        55     14
# ..          ...   ...   ...   ...    ...       ...    ...
# 165  11/23/2020  2210  2290  2190   2280      4360    110
# 166  11/24/2020  2310  2340  2280   2320      4442    118
# 167  11/25/2020  2330  2380  2280   2300      4192    109
# 168  11/26/2020  2300  2370  2290   2330      5534    114
# 169  11/27/2020  2350  2370  2330   2350      4917    127
#
# [170 rows x 7 columns]
# 0      1685
# 1      1570
# 2      1480
# 3      1370
# 4      1260
#        ...
# 165    2210
# 166    2310
# 167    2330
# 168    2300
# 169    2350
# Name: Open, Length: 170, dtype: int64

# %%
# Tampil FREN
print(dataset_freen)

# Tampil FREN Index 1
print(dataset_freen.iloc[:,1])
# Out:
#            Date  Open  High  Low  Close  new case  death
# 0     3/16/2020    60    60   59     59        21      1
# 1     3/17/2020    55    55   55     55        17      0
# 2     3/18/2020    52    52   52     52        38      0
# 3     3/19/2020    50    51   50     50         0      0
# 4     3/20/2020    50    56   50     52        55     14
# ..          ...   ...   ...  ...    ...       ...    ...
# 165  11/23/2020    68    72   68     70      4360    110
# 166  11/24/2020    71    77   70     74      4442    118
# 167  11/25/2020    76    77   70     73      4192    109
# 168  11/26/2020    73    74   70     70      5534    114
# 169  11/27/2020    70    73   69     69      4917    127
#
# [170 rows x 7 columns]
# 0      60
# 1      55
# 2      52
# 3      50
# 4      50
#        ..
# 165    68
# 166    71
# 167    76
# 168    73
# 169    70
# Name: Open, Length: 170, dtype: int64

# %%
#Tampil Grafik Plot Telkomsel
line_1, = plt.plot(TELKM[0:,1], label='harga open')
line_2, = plt.plot(TELKM[0:,2], label='harga High')
line_3, = plt.plot(TELKM[0:,3], label='harga low')
line_4, = plt.plot(TELKM[0:,4], label='harga close')
line_5, = plt.plot(TELKM[0:,5], label='new cases')
line_6, = plt.plot(TELKM[0:,6], label='death')
plt.xlabel('Jumlah Data') #Sumbu -X
plt.ylabel('Harga/jumlah persebaran')#Sumbu -Y 

plt.legend(handles=[line_1])#, line_2, line_3, line_4, line_5,line_6])

# %%
line_1, = plt.plot(ISAT[0:,1], label='harga open')
line_2, = plt.plot(ISAT[0:,2], label='harga High')
line_3, = plt.plot(ISAT[0:,3], label='harga low')
line_4, = plt.plot(ISAT[0:,4], label='harga close')
line_5, = plt.plot(ISAT[0:,5], label='new cases')
line_6, = plt.plot(ISAT[0:,6], label='death')
plt.xlabel('Jumlah Data') #Sumbu -X
plt.ylabel('Harga/jumlah persebaran')#Sumbu -Y 

plt.legend(handles=[line_1, line_2, line_3, line_4, line_5, line_6])

# %%
# Tampil Grafik Plot
line_1, = plt.plot(FREEN[0:,1], label='harga open')
line_2, = plt.plot(FREEN[0:,2], label='harga High')
line_3, = plt.plot(FREEN[0:,3], label='harga low')
line_4, = plt.plot(FREEN[0:,4], label='harga close')
line_5, = plt.plot(FREEN[0:,5], label='new cases')
line_6, = plt.plot(FREEN[0:,6], label='death')
plt.xlabel('Jumlah Data') #Sumbu -X
plt.ylabel('Harga/jumlah persebaran')#Sumbu -Y 

plt.legend(handles=[line_1, line_2, line_3, line_4, line_5,line_6])

# %% [markdown]
# # Inisialisasi Data

# %%
# Inisialisasi Data
split = 5

# %% [markdown]
# # **Fungsi**

# %%
def printHasil(data_y, predic_y, judul):
  print(judul, '\n')
  print("Matrik\n")
  print(confusion_matrix(data_y, predic_y))

  print("\nHasil\n")
  print(classification_report(data_y, predic_y))

  print("\nAkurasi\n")
  accuracy = accuracy_score(data_y, predic_y)
  print(accuracy)

  print("\nGrafik\n")
  plt.plot(data_y)
  plt.plot(predic_y)

# %%
def klasifikasiData(data, split_jadi):

  data_x = []
  data_y = []

  if data == 'telkom':
    # Telkomsel
    dset = TELKM[:,1]
    
  elif data == 'indosat':
    # Indosat
    dset = ISAT[:,1] 
    
  else:
    # Freen
    dset = FREEN[:,1]
   
  # Ambil sejumlah count
  for i in range(0,len(dset)-split_jadi):
    data_x.append(dset[i:i+split_jadi])
    data_y.append((dset[i+split_jadi]>dset[i+split_jadi-1])*1)

  x_train, x_test, y_train, y_test = train_test_split(data_x, data_y, random_state = 100, test_size=0.1) 
  return x_train, x_test, y_train, y_test

# %% [markdown]
# # **Klasifikasi KNeighboursClassifier**

# %%
for totalsplit in range(5,100):

# indosat
  x_train, x_test, y_train, y_test = klasifikasiData(data='indosat', split_jadi=totalsplit)
  klasifikasiKNeighbor = KNeighborsClassifier(n_neighbors=5)
  klasifikasiKNeighbor.fit(x_train, y_train)
  predic_y = klasifikasiKNeighbor.predict(x_test)
  print(totalsplit)

  printHasil(y_test, predic_y, "indosat")
# Out:
# 5
# indosat
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 6
# indosat
#
# Matrik
#
# [[3 9]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.25      0.33        12
#            1       0.18      0.40      0.25         5
#
#     accuracy                           0.29        17
#    macro avg       0.34      0.33      0.29        17
# weighted avg       0.41      0.29      0.31        17
#
#
# Akurasi
#
# 0.29411764705882354
#
# Grafik
#
# 7
# indosat
#
# Matrik
#
# [[6 2]
#  [5 4]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.55      0.75      0.63         8
#            1       0.67      0.44      0.53         9
#
#     accuracy                           0.59        17
#    macro avg       0.61      0.60      0.58        17
# weighted avg       0.61      0.59      0.58        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 8
# indosat
#
# Matrik
#
# [[5 5]
#  [4 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.50      0.53        10
#            1       0.38      0.43      0.40         7
#
#     accuracy                           0.47        17
#    macro avg       0.47      0.46      0.46        17
# weighted avg       0.48      0.47      0.47        17
#
#
# Akurasi
#
# 0.47058823529411764
#
# Grafik
#
# 9
# indosat
#
# Matrik
#
# [[6 3]
#  [2 6]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.67      0.71         9
#            1       0.67      0.75      0.71         8
#
#     accuracy                           0.71        17
#    macro avg       0.71      0.71      0.71        17
# weighted avg       0.71      0.71      0.71        17
#
#
# Akurasi
#
# 0.7058823529411765
#
# Grafik
#
# 10
# indosat
#
# Matrik
#
# [[6 4]
#  [3 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.60      0.63        10
#            1       0.43      0.50      0.46         6
#
#     accuracy                           0.56        16
#    macro avg       0.55      0.55      0.55        16
# weighted avg       0.58      0.56      0.57        16
#
#
# Akurasi
#
# 0.5625
#
# Grafik
#
# 11
# indosat
#
# Matrik
#
# [[4 3]
#  [5 4]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.44      0.57      0.50         7
#            1       0.57      0.44      0.50         9
#
#     accuracy                           0.50        16
#    macro avg       0.51      0.51      0.50        16
# weighted avg       0.52      0.50      0.50        16
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 12
# indosat
#
# Matrik
#
# [[8 0]
#  [4 4]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80         8
#            1       1.00      0.50      0.67         8
#
#     accuracy                           0.75        16
#    macro avg       0.83      0.75      0.73        16
# weighted avg       0.83      0.75      0.73        16
#
#
# Akurasi
#
# 0.75
#
# Grafik
#
# 13
# indosat
#
# Matrik
#
# [[9 0]
#  [4 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.69      1.00      0.82         9
#            1       1.00      0.43      0.60         7
#
#     accuracy                           0.75        16
#    macro avg       0.85      0.71      0.71        16
# weighted avg       0.83      0.75      0.72        16
#
#
# Akurasi
#
# 0.75
#
# Grafik
#
# 14
# indosat
#
# Matrik
#
# [[7 1]
#  [7 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.88      0.64         8
#            1       0.50      0.12      0.20         8
#
#     accuracy                           0.50        16
#    macro avg       0.50      0.50      0.42        16
# weighted avg       0.50      0.50      0.42        16
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 15
# indosat
#
# Matrik
#
# [[7 5]
#  [3 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.17      0.25      0.20         4
#
#     accuracy                           0.50        16
#    macro avg       0.43      0.42      0.42        16
# weighted avg       0.57      0.50      0.53        16
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 16
# indosat
#
# Matrik
#
# [[6 3]
#  [5 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.55      0.67      0.60         9
#            1       0.40      0.29      0.33         7
#
#     accuracy                           0.50        16
#    macro avg       0.47      0.48      0.47        16
# weighted avg       0.48      0.50      0.48        16
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 17
# indosat
#
# Matrik
#
# [[6 1]
#  [5 4]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.55      0.86      0.67         7
#            1       0.80      0.44      0.57         9
#
#     accuracy                           0.62        16
#    macro avg       0.67      0.65      0.62        16
# weighted avg       0.69      0.62      0.61        16
#
#
# Akurasi
#
# 0.625
#
# Grafik
#
# 18
# indosat
#
# Matrik
#
# [[8 2]
#  [3 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.80      0.76        10
#            1       0.60      0.50      0.55         6
#
#     accuracy                           0.69        16
#    macro avg       0.66      0.65      0.65        16
# weighted avg       0.68      0.69      0.68        16
#
#
# Akurasi
#
# 0.6875
#
# Grafik
#
# 19
# indosat
#
# Matrik
#
# [[7 2]
#  [5 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.58      0.78      0.67         9
#            1       0.50      0.29      0.36         7
#
#     accuracy                           0.56        16
#    macro avg       0.54      0.53      0.52        16
# weighted avg       0.55      0.56      0.53        16
#
#
# Akurasi
#
# 0.5625
#
# Grafik
#
# 20
# indosat
#
# Matrik
#
# [[4 3]
#  [8 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.33      0.57      0.42         7
#            1       0.00      0.00      0.00         8
#
#     accuracy                           0.27        15
#    macro avg       0.17      0.29      0.21        15
# weighted avg       0.16      0.27      0.20        15
#
#
# Akurasi
#
# 0.26666666666666666
#
# Grafik
#
# 21
# indosat
#
# Matrik
#
# [[7 3]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.70      0.67        10
#            1       0.25      0.20      0.22         5
#
#     accuracy                           0.53        15
#    macro avg       0.44      0.45      0.44        15
# weighted avg       0.51      0.53      0.52        15
#
#
# Akurasi
#
# 0.5333333333333333
#
# Grafik
#
# 22
# indosat
#
# Matrik
#
# [[5 6]
#  [2 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.45      0.56        11
#            1       0.25      0.50      0.33         4
#
#     accuracy                           0.47        15
#    macro avg       0.48      0.48      0.44        15
# weighted avg       0.59      0.47      0.50        15
#
#
# Akurasi
#
# 0.4666666666666667
#
# Grafik
#
# 23
# indosat
#
# Matrik
#
# [[4 5]
#  [4 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.44      0.47         9
#            1       0.29      0.33      0.31         6
#
#     accuracy                           0.40        15
#    macro avg       0.39      0.39      0.39        15
# weighted avg       0.41      0.40      0.41        15
#
#
# Akurasi
#
# 0.4
#
# Grafik
#
# 24
# indosat
#
# Matrik
#
# [[6 6]
#  [2 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.50      0.60        12
#            1       0.14      0.33      0.20         3
#
#     accuracy                           0.47        15
#    macro avg       0.45      0.42      0.40        15
# weighted avg       0.63      0.47      0.52        15
#
#
# Akurasi
#
# 0.4666666666666667
#
# Grafik
#
# 25
# indosat
#
# Matrik
#
# [[8 2]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.80      0.76        10
#            1       0.50      0.40      0.44         5
#
#     accuracy                           0.67        15
#    macro avg       0.61      0.60      0.60        15
# weighted avg       0.65      0.67      0.66        15
#
#
# Akurasi
#
# 0.6666666666666666
#
# Grafik
#
# 26
# indosat
#
# Matrik
#
# [[5 2]
#  [5 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.71      0.59         7
#            1       0.60      0.38      0.46         8
#
#     accuracy                           0.53        15
#    macro avg       0.55      0.54      0.52        15
# weighted avg       0.55      0.53      0.52        15
#
#
# Akurasi
#
# 0.5333333333333333
#
# Grafik
#
# 27
# indosat
#
# Matrik
#
# [[6 0]
#  [8 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.43      1.00      0.60         6
#            1       1.00      0.11      0.20         9
#
#     accuracy                           0.47        15
#    macro avg       0.71      0.56      0.40        15
# weighted avg       0.77      0.47      0.36        15
#
#
# Akurasi
#
# 0.4666666666666667
#
# Grafik
#
# 28
# indosat
#
# Matrik
#
# [[7 2]
#  [4 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.78      0.70         9
#            1       0.50      0.33      0.40         6
#
#     accuracy                           0.60        15
#    macro avg       0.57      0.56      0.55        15
# weighted avg       0.58      0.60      0.58        15
#
#
# Akurasi
#
# 0.6
#
# Grafik
#
# 29
# indosat
#
# Matrik
#
# [[4 6]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.40      0.50        10
#            1       0.33      0.60      0.43         5
#
#     accuracy                           0.47        15
#    macro avg       0.50      0.50      0.46        15
# weighted avg       0.56      0.47      0.48        15
#
#
# Akurasi
#
# 0.4666666666666667
#
# Grafik
#
# 30
# indosat
#
# Matrik
#
# [[5 4]
#  [1 4]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.56      0.67         9
#            1       0.50      0.80      0.62         5
#
#     accuracy                           0.64        14
#    macro avg       0.67      0.68      0.64        14
# weighted avg       0.71      0.64      0.65        14
#
#
# Akurasi
#
# 0.6428571428571429
#
# Grafik
#
# 31
# indosat
#
# Matrik
#
# [[5 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.56      0.59         9
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.50        14
#    macro avg       0.48      0.48      0.48        14
# weighted avg       0.52      0.50      0.51        14
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 32
# indosat
#
# Matrik
#
# [[3 2]
#  [5 4]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.38      0.60      0.46         5
#            1       0.67      0.44      0.53         9
#
#     accuracy                           0.50        14
#    macro avg       0.52      0.52      0.50        14
# weighted avg       0.56      0.50      0.51        14
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 33
# indosat
#
# Matrik
#
# [[5 1]
#  [5 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.83      0.62         6
#            1       0.75      0.38      0.50         8
#
#     accuracy                           0.57        14
#    macro avg       0.62      0.60      0.56        14
# weighted avg       0.64      0.57      0.55        14
#
#
# Akurasi
#
# 0.5714285714285714
#
# Grafik
#
# 34
# indosat
#
# Matrik
#
# [[5 3]
#  [4 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.62      0.59         8
#            1       0.40      0.33      0.36         6
#
#     accuracy                           0.50        14
#    macro avg       0.48      0.48      0.48        14
# weighted avg       0.49      0.50      0.49        14
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 35
# indosat
#
# Matrik
#
# [[7 3]
#  [1 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.70      0.78        10
#            1       0.50      0.75      0.60         4
#
#     accuracy                           0.71        14
#    macro avg       0.69      0.72      0.69        14
# weighted avg       0.77      0.71      0.73        14
#
#
# Akurasi
#
# 0.7142857142857143
#
# Grafik
#
# 36
# indosat
#
# Matrik
#
# [[8 1]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.89      0.76         9
#            1       0.50      0.20      0.29         5
#
#     accuracy                           0.64        14
#    macro avg       0.58      0.54      0.52        14
# weighted avg       0.61      0.64      0.59        14
#
#
# Akurasi
#
# 0.6428571428571429
#
# Grafik
#
# 37
# indosat
#
# Matrik
#
# [[6 3]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.67      0.63         9
#            1       0.25      0.20      0.22         5
#
#     accuracy                           0.50        14
#    macro avg       0.42      0.43      0.43        14
# weighted avg       0.47      0.50      0.49        14
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 38
# indosat
#
# Matrik
#
# [[5 2]
#  [4 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.71      0.63         7
#            1       0.60      0.43      0.50         7
#
#     accuracy                           0.57        14
#    macro avg       0.58      0.57      0.56        14
# weighted avg       0.58      0.57      0.56        14
#
#
# Akurasi
#
# 0.5714285714285714
#
# Grafik
#
# 39
# indosat
#
# Matrik
#
# [[7 1]
#  [5 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.58      0.88      0.70         8
#            1       0.50      0.17      0.25         6
#
#     accuracy                           0.57        14
#    macro avg       0.54      0.52      0.48        14
# weighted avg       0.55      0.57      0.51        14
#
#
# Akurasi
#
# 0.5714285714285714
#
# Grafik
#
# 40
# indosat
#
# Matrik
#
# [[5 4]
#  [2 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.56      0.63         9
#            1       0.33      0.50      0.40         4
#
#     accuracy                           0.54        13
#    macro avg       0.52      0.53      0.51        13
# weighted avg       0.60      0.54      0.56        13
#
#
# Akurasi
#
# 0.5384615384615384
#
# Grafik
#
# 41
# indosat
#
# Matrik
#
# [[6 5]
#  [1 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.55      0.67        11
#            1       0.17      0.50      0.25         2
#
#     accuracy                           0.54        13
#    macro avg       0.51      0.52      0.46        13
# weighted avg       0.75      0.54      0.60        13
#
#
# Akurasi
#
# 0.5384615384615384
#
# Grafik
#
# 42
# indosat
#
# Matrik
#
# [[3 4]
#  [3 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.43      0.46         7
#            1       0.43      0.50      0.46         6
#
#     accuracy                           0.46        13
#    macro avg       0.46      0.46      0.46        13
# weighted avg       0.47      0.46      0.46        13
#
#
# Akurasi
#
# 0.46153846153846156
#
# Grafik
#
# 43
# indosat
#
# Matrik
#
# [[4 6]
#  [2 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.40      0.50        10
#            1       0.14      0.33      0.20         3
#
#     accuracy                           0.38        13
#    macro avg       0.40      0.37      0.35        13
# weighted avg       0.55      0.38      0.43        13
#
#
# Akurasi
#
# 0.38461538461538464
#
# Grafik
#
# 44
# indosat
#
# Matrik
#
# [[1 4]
#  [6 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.14      0.20      0.17         5
#            1       0.33      0.25      0.29         8
#
#     accuracy                           0.23        13
#    macro avg       0.24      0.23      0.23        13
# weighted avg       0.26      0.23      0.24        13
#
#
# Akurasi
#
# 0.23076923076923078
#
# Grafik
#
# 45
# indosat
#
# Matrik
#
# [[4 5]
#  [1 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.44      0.57         9
#            1       0.38      0.75      0.50         4
#
#     accuracy                           0.54        13
#    macro avg       0.59      0.60      0.54        13
# weighted avg       0.67      0.54      0.55        13
#
#
# Akurasi
#
# 0.5384615384615384
#
# Grafik
#
# 46
# indosat
#
# Matrik
#
# [[2 3]
#  [5 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.29      0.40      0.33         5
#            1       0.50      0.38      0.43         8
#
#     accuracy                           0.38        13
#    macro avg       0.39      0.39      0.38        13
# weighted avg       0.42      0.38      0.39        13
#
#
# Akurasi
#
# 0.38461538461538464
#
# Grafik
#
# 47
# indosat
#
# Matrik
#
# [[3 3]
#  [3 4]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50         6
#            1       0.57      0.57      0.57         7
#
#     accuracy                           0.54        13
#    macro avg       0.54      0.54      0.54        13
# weighted avg       0.54      0.54      0.54        13
#
#
# Akurasi
#
# 0.5384615384615384
#
# Grafik
#
# 48
# indosat
#
# Matrik
#
# [[3 3]
#  [4 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.43      0.50      0.46         6
#            1       0.50      0.43      0.46         7
#
#     accuracy                           0.46        13
#    macro avg       0.46      0.46      0.46        13
# weighted avg       0.47      0.46      0.46        13
#
#
# Akurasi
#
# 0.46153846153846156
#
# Grafik
#
# 49
# indosat
#
# Matrik
#
# [[2 5]
#  [3 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.40      0.29      0.33         7
#            1       0.38      0.50      0.43         6
#
#     accuracy                           0.38        13
#    macro avg       0.39      0.39      0.38        13
# weighted avg       0.39      0.38      0.38        13
#
#
# Akurasi
#
# 0.38461538461538464
#
# Grafik
#
# 50
# indosat
#
# Matrik
#
# [[4 3]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.57      0.62         7
#            1       0.50      0.60      0.55         5
#
#     accuracy                           0.58        12
#    macro avg       0.58      0.59      0.58        12
# weighted avg       0.60      0.58      0.59        12
#
#
# Akurasi
#
# 0.5833333333333334
#
# Grafik
#
# 51
# indosat
#
# Matrik
#
# [[0 4]
#  [5 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.43      0.38      0.40         8
#
#     accuracy                           0.25        12
#    macro avg       0.21      0.19      0.20        12
# weighted avg       0.29      0.25      0.27        12
#
#
# Akurasi
#
# 0.25
#
# Grafik
#
# 52
# indosat
#
# Matrik
#
# [[4 4]
#  [2 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.50      0.57         8
#            1       0.33      0.50      0.40         4
#
#     accuracy                           0.50        12
#    macro avg       0.50      0.50      0.49        12
# weighted avg       0.56      0.50      0.51        12
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 53
# indosat
#
# Matrik
#
# [[3 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.43      0.50         7
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.50        12
#    macro avg       0.51      0.51      0.50        12
# weighted avg       0.53      0.50      0.50        12
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 54
# indosat
#
# Matrik
#
# [[5 2]
#  [5 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.71      0.59         7
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.42        12
#    macro avg       0.25      0.36      0.29        12
# weighted avg       0.29      0.42      0.34        12
#
#
# Akurasi
#
# 0.4166666666666667
#
# Grafik
#
# 55
# indosat
#
# Matrik
#
# [[3 3]
#  [5 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.38      0.50      0.43         6
#            1       0.25      0.17      0.20         6
#
#     accuracy                           0.33        12
#    macro avg       0.31      0.33      0.31        12
# weighted avg       0.31      0.33      0.31        12
#
#
# Akurasi
#
# 0.3333333333333333
#
# Grafik
#
# 56
# indosat
#
# Matrik
#
# [[2 3]
#  [5 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.29      0.40      0.33         5
#            1       0.40      0.29      0.33         7
#
#     accuracy                           0.33        12
#    macro avg       0.34      0.34      0.33        12
# weighted avg       0.35      0.33      0.33        12
#
#
# Akurasi
#
# 0.3333333333333333
#
# Grafik
#
# 57
# indosat
#
# Matrik
#
# [[3 5]
#  [2 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.38      0.46         8
#            1       0.29      0.50      0.36         4
#
#     accuracy                           0.42        12
#    macro avg       0.44      0.44      0.41        12
# weighted avg       0.50      0.42      0.43        12
#
#
# Akurasi
#
# 0.4166666666666667
#
# Grafik
#
# 58
# indosat
#
# Matrik
#
# [[5 2]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.71      0.67         7
#            1       0.50      0.40      0.44         5
#
#     accuracy                           0.58        12
#    macro avg       0.56      0.56      0.56        12
# weighted avg       0.57      0.58      0.57        12
#
#
# Akurasi
#
# 0.5833333333333334
#
# Grafik
#
# 59
# indosat
#
# Matrik
#
# [[3 0]
#  [9 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.25      1.00      0.40         3
#            1       0.00      0.00      0.00         9
#
#     accuracy                           0.25        12
#    macro avg       0.12      0.50      0.20        12
# weighted avg       0.06      0.25      0.10        12
#
#
# Akurasi
#
# 0.25
#
# Grafik
#
# 60
# indosat
#
# Matrik
#
# [[5 2]
#  [3 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.71      0.67         7
#            1       0.33      0.25      0.29         4
#
#     accuracy                           0.55        11
#    macro avg       0.48      0.48      0.48        11
# weighted avg       0.52      0.55      0.53        11
#
#
# Akurasi
#
# 0.5454545454545454
#
# Grafik
#
# 61
# indosat
#
# Matrik
#
# [[5 3]
#  [2 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.62      0.67         8
#            1       0.25      0.33      0.29         3
#
#     accuracy                           0.55        11
#    macro avg       0.48      0.48      0.48        11
# weighted avg       0.59      0.55      0.56        11
#
#
# Akurasi
#
# 0.5454545454545454
#
# Grafik
#
# 62
# indosat
#
# Matrik
#
# [[6 4]
#  [1 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.60      0.71        10
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.55        11
#    macro avg       0.43      0.30      0.35        11
# weighted avg       0.78      0.55      0.64        11
#
#
# Akurasi
#
# 0.5454545454545454
#
# Grafik
#
# 63
# indosat
#
# Matrik
#
# [[6 3]
#  [2 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.67      0.71         9
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.55        11
#    macro avg       0.38      0.33      0.35        11
# weighted avg       0.61      0.55      0.58        11
#
#
# Akurasi
#
# 0.5454545454545454
#
# Grafik
#
# 64
# indosat
#
# Matrik
#
# [[4 3]
#  [3 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.57      0.57         7
#            1       0.25      0.25      0.25         4
#
#     accuracy                           0.45        11
#    macro avg       0.41      0.41      0.41        11
# weighted avg       0.45      0.45      0.45        11
#
#
# Akurasi
#
# 0.45454545454545453
#
# Grafik
#
# 65
# indosat
#
# Matrik
#
# [[4 2]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.67      0.57         6
#            1       0.33      0.20      0.25         5
#
#     accuracy                           0.45        11
#    macro avg       0.42      0.43      0.41        11
# weighted avg       0.42      0.45      0.43        11
#
#
# Akurasi
#
# 0.45454545454545453
#
# Grafik
#
# 66
# indosat
#
# Matrik
#
# [[4 4]
#  [3 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.50      0.53         8
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.36        11
#    macro avg       0.29      0.25      0.27        11
# weighted avg       0.42      0.36      0.39        11
#
#
# Akurasi
#
# 0.36363636363636365
#
# Grafik
#
# 67
# indosat
#
# Matrik
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [[5 2]
#  [4 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.71      0.63         7
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.45        11
#    macro avg       0.28      0.36      0.31        11
# weighted avg       0.35      0.45      0.40        11
#
#
# Akurasi
#
# 0.45454545454545453
#
# Grafik
#
# 68
# indosat
#
# Matrik
#
# [[5 0]
#  [6 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.45      1.00      0.62         5
#            1       0.00      0.00      0.00         6
#
#     accuracy                           0.45        11
#    macro avg       0.23      0.50      0.31        11
# weighted avg       0.21      0.45      0.28        11
#
#
# Akurasi
#
# 0.45454545454545453
#
# Grafik
#
# 69
# indosat
#
# Matrik
#
# [[5 2]
#  [3 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.71      0.67         7
#            1       0.33      0.25      0.29         4
#
#     accuracy                           0.55        11
#    macro avg       0.48      0.48      0.48        11
# weighted avg       0.52      0.55      0.53        11
#
#
# Akurasi
#
# 0.5454545454545454
#
# Grafik
#
# 70
# indosat
#
# Matrik
#
# [[5 0]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.62      1.00      0.77         5
#            1       1.00      0.40      0.57         5
#
#     accuracy                           0.70        10
#    macro avg       0.81      0.70      0.67        10
# weighted avg       0.81      0.70      0.67        10
#
#
# Akurasi
#
# 0.7
#
# Grafik
#
# 71
# indosat
#
# Matrik
#
# [[6 3]
#  [1 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.67      0.75         9
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.60        10
#    macro avg       0.43      0.33      0.38        10
# weighted avg       0.77      0.60      0.68        10
#
#
# Akurasi
#
# 0.6
#
# Grafik
#
# 72
# indosat
#
# Matrik
#
# [[3 2]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.60      0.55         5
#            1       0.50      0.40      0.44         5
#
#     accuracy                           0.50        10
#    macro avg       0.50      0.50      0.49        10
# weighted avg       0.50      0.50      0.49        10
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 73
# indosat
#
# Matrik
#
# [[5 2]
#  [1 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.71      0.77         7
#            1       0.50      0.67      0.57         3
#
#     accuracy                           0.70        10
#    macro avg       0.67      0.69      0.67        10
# weighted avg       0.73      0.70      0.71        10
#
#
# Akurasi
#
# 0.7
#
# Grafik
#
# 74
# indosat
#
# Matrik
#
# [[3 1]
#  [5 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.38      0.75      0.50         4
#            1       0.50      0.17      0.25         6
#
#     accuracy                           0.40        10
#    macro avg       0.44      0.46      0.38        10
# weighted avg       0.45      0.40      0.35        10
#
#
# Akurasi
#
# 0.4
#
# Grafik
#
# 75
# indosat
#
# Matrik
#
# [[4 1]
#  [5 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.44      0.80      0.57         5
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.40        10
#    macro avg       0.22      0.40      0.29        10
# weighted avg       0.22      0.40      0.29        10
#
#
# Akurasi
#
# 0.4
#
# Grafik
#
# 76
# indosat
#
# Matrik
#
# [[6 1]
#  [2 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.86      0.80         7
#            1       0.50      0.33      0.40         3
#
#     accuracy                           0.70        10
#    macro avg       0.62      0.60      0.60        10
# weighted avg       0.68      0.70      0.68        10
#
#
# Akurasi
#
# 0.7
#
# Grafik
#
# 77
# indosat
#
# Matrik
#
# [[4 2]
#  [3 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.67      0.62         6
#            1       0.33      0.25      0.29         4
#
#     accuracy                           0.50        10
#    macro avg       0.45      0.46      0.45        10
# weighted avg       0.48      0.50      0.48        10
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 78
# indosat
#
# Matrik
#
# [[5 2]
#  [3 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.71      0.67         7
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.50        10
#    macro avg       0.31      0.36      0.33        10
# weighted avg       0.44      0.50      0.47        10
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 79
# indosat
#
# Matrik
#
# [[3 3]
#  [4 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.43      0.50      0.46         6
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.30        10
#    macro avg       0.21      0.25      0.23        10
# weighted avg       0.26      0.30      0.28        10
#
#
# Akurasi
#
# 0.3
#
# Grafik
#
# 80
# indosat
#
# Matrik
#
# [[5 0]
#  [4 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.56      1.00      0.71         5
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.56         9
#    macro avg       0.28      0.50      0.36         9
# weighted avg       0.31      0.56      0.40         9
#
#
# Akurasi
#
# 0.5555555555555556
#
# Grafik
#
# 81
# indosat
#
# Matrik
#
# [[6 1]
#  [2 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.86      0.80         7
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.67         9
#    macro avg       0.38      0.43      0.40         9
# weighted avg       0.58      0.67      0.62         9
#
#
# Akurasi
#
# 0.6666666666666666
#
# Grafik
#
# 82
# indosat
#
# Matrik
#
# [[4 2]
#  [3 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.67      0.62         6
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.44         9
#    macro avg       0.29      0.33      0.31         9
# weighted avg       0.38      0.44      0.41         9
#
#
# Akurasi
#
# 0.4444444444444444
#
# Grafik
#
# 83
# indosat
#
# Matrik
#
# [[5 0]
#  [2 2]]
#
# Hasil
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83         5
#            1       1.00      0.50      0.67         4
#
#     accuracy                           0.78         9
#    macro avg       0.86      0.75      0.75         9
# weighted avg       0.84      0.78      0.76         9
#
#
# Akurasi
#
# 0.7777777777777778
#
# Grafik
#
# 84
# indosat
#
# Matrik
#
# [[5 0]
#  [3 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.62      1.00      0.77         5
#            1       1.00      0.25      0.40         4
#
#     accuracy                           0.67         9
#    macro avg       0.81      0.62      0.58         9
# weighted avg       0.79      0.67      0.61         9
#
#
# Akurasi
#
# 0.6666666666666666
#
# Grafik
#
# 85
# indosat
#
# Matrik
#
# [[4 1]
#  [3 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.80      0.67         5
#            1       0.50      0.25      0.33         4
#
#     accuracy                           0.56         9
#    macro avg       0.54      0.53      0.50         9
# weighted avg       0.54      0.56      0.52         9
#
#
# Akurasi
#
# 0.5555555555555556
#
# Grafik
#
# 86
# indosat
#
# Matrik
#
# [[4 2]
#  [3 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.67      0.62         6
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.44         9
#    macro avg       0.29      0.33      0.31         9
# weighted avg       0.38      0.44      0.41         9
#
#
# Akurasi
#
# 0.4444444444444444
#
# Grafik
#
# 87
# indosat
#
# Matrik
#
# [[4 0]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         4
#            1       1.00      0.20      0.33         5
#
#     accuracy                           0.56         9
#    macro avg       0.75      0.60      0.50         9
# weighted avg       0.78      0.56      0.48         9
#
#
# Akurasi
#
# 0.5555555555555556
#
# Grafik
#
# 88
# indosat
#
# Matrik
#
# [[3 3]
#  [3 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50         6
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.33         9
#    macro avg       0.25      0.25      0.25         9
# weighted avg       0.33      0.33      0.33         9
#
#
# Akurasi
#
# 0.3333333333333333
#
# Grafik
#
# 89
# indosat
#
# Matrik
#
# [[3 1]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.43      0.75      0.55         4
#            1       0.50      0.20      0.29         5
#
#     accuracy                           0.44         9
#    macro avg       0.46      0.47      0.42         9
# weighted avg       0.47      0.44      0.40         9
#
#
# Akurasi
#
# 0.4444444444444444
#
# Grafik
#
# 90
# indosat
#
# Matrik
#
# [[2 1]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.33      0.67      0.44         3
#            1       0.50      0.20      0.29         5
#
#     accuracy                           0.38         8
#    macro avg       0.42      0.43      0.37         8
# weighted avg       0.44      0.38      0.35         8
#
#
# Akurasi
#
# 0.375
#
# Grafik
#
# 91
# indosat
#
# Matrik
#
# [[5 2]
#  [0 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.71      0.83         7
#            1       0.33      1.00      0.50         1
#
#     accuracy                           0.75         8
#    macro avg       0.67      0.86      0.67         8
# weighted avg       0.92      0.75      0.79         8
#
#
# Akurasi
#
# 0.75
#
# Grafik
#
# 92
# indosat
#
# Matrik
#
# [[5 2]
#  [0 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.71      0.83         7
#            1       0.33      1.00      0.50         1
#
#     accuracy                           0.75         8
#    macro avg       0.67      0.86      0.67         8
# weighted avg       0.92      0.75      0.79         8
#
#
# Akurasi
#
# 0.75
#
# Grafik
#
# 93
# indosat
#
# Matrik
#
# [[3 3]
#  [1 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.50      0.60         6
#            1       0.25      0.50      0.33         2
#
#     accuracy                           0.50         8
#    macro avg       0.50      0.50      0.47         8
# weighted avg       0.62      0.50      0.53         8
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 94
# indosat
#
# Matrik
#
# [[2 1]
#  [5 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.29      0.67      0.40         3
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.25         8
#    macro avg       0.14      0.33      0.20         8
# weighted avg       0.11      0.25      0.15         8
#
#
# Akurasi
#
# 0.25
#
# Grafik
#
# 95
# indosat
#
# Matrik
#
# [[4 1]
#  [3 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.80      0.67         5
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.50         8
#    macro avg       0.29      0.40      0.33         8
# weighted avg       0.36      0.50      0.42         8
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 96
# indosat
#
# Matrik
#
# [[2 2]
#  [4 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.33      0.50      0.40         4
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.25         8
#    macro avg       0.17      0.25      0.20         8
# weighted avg       0.17      0.25      0.20         8
#
#
# Akurasi
#
# 0.25
#
# Grafik
#
# 97
# indosat
#
# Matrik
#
# [[3 2]
#  [3 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.60      0.55         5
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.38         8
#    macro avg       0.25      0.30      0.27         8
# weighted avg       0.31      0.38      0.34         8
#
#
# Akurasi
#
# 0.375
#
# Grafik
#
# 98
# indosat
#
# Matrik
#
# [[4 4]
#  [0 0]]
#
# Hasil
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67         8
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.50         8
#    macro avg       0.50      0.25      0.33         8
# weighted avg       1.00      0.50      0.67         8
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 99
# indosat
#
# Matrik
#
# [[5 0]
#  [3 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.62      1.00      0.77         5
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.62         8
#    macro avg       0.31      0.50      0.38         8
# weighted avg       0.39      0.62      0.48         8
#
#
# Akurasi
#
# 0.625
#
# Grafik

# %%
x_train, x_test, y_train, y_test = klasifikasiData(data='indosat', split_jadi=83)
klasifikasiKNeighbor = KNeighborsClassifier(n_neighbors=5)
klasifikasiKNeighbor.fit(x_train, y_train)
predic_y = klasifikasiKNeighbor.predict(x_test)
  
printHasil(y_test, predic_y, "indosat")
import pickle
file = open('KNN_Indosat.otak', 'wb')

# dump information to that file
pickle.dump(klasifikasiKNeighbor, file)

# close the file
file.close()
# Out:
# indosat
#
# Matrik
#
# [[5 0]
#  [2 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83         5
#            1       1.00      0.50      0.67         4
#
#     accuracy                           0.78         9
#    macro avg       0.86      0.75      0.75         9
# weighted avg       0.84      0.78      0.76         9
#
#
# Akurasi
#
# 0.7777777777777778
#
# Grafik

# %%
for totalsplit in range(5,100):

# Telkomsel
  x_train, x_test, y_train, y_test = klasifikasiData(data='telkom', split_jadi=totalsplit)
  klasifikasiKNeighbor = KNeighborsClassifier(n_neighbors=5)
  klasifikasiKNeighbor.fit(x_train, y_train)
  predic_y = klasifikasiKNeighbor.predict(x_test)
  print(totalsplit)

  printHasil(y_test, predic_y, "Telkomsel")
# Out:
# 5
# Telkomsel
#
# Matrik
#
# [[7 5]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.58      0.61        12
#            1       0.17      0.20      0.18         5
#
#     accuracy                           0.47        17
#    macro avg       0.40      0.39      0.40        17
# weighted avg       0.50      0.47      0.48        17
#
#
# Akurasi
#
# 0.47058823529411764
#
# Grafik
#
# 6
# Telkomsel
#
# Matrik
#
# [[8 4]
#  [5 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.67      0.64        12
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.47        17
#    macro avg       0.31      0.33      0.32        17
# weighted avg       0.43      0.47      0.45        17
#
#
# Akurasi
#
# 0.47058823529411764
#
# Grafik
#
# 7
# Telkomsel
#
# Matrik
#
# [[5 5]
#  [6 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.45      0.50      0.48        10
#            1       0.17      0.14      0.15         7
#
#     accuracy                           0.35        17
#    macro avg       0.31      0.32      0.32        17
# weighted avg       0.34      0.35      0.34        17
#
#
# Akurasi
#
# 0.35294117647058826
#
# Grafik
#
# 8
# Telkomsel
#
# Matrik
#
# [[6 4]
#  [3 4]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.60      0.63        10
#            1       0.50      0.57      0.53         7
#
#     accuracy                           0.59        17
#    macro avg       0.58      0.59      0.58        17
# weighted avg       0.60      0.59      0.59        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 9
# Telkomsel
#
# Matrik
#
# [[6 3]
#  [4 4]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.67      0.63         9
#            1       0.57      0.50      0.53         8
#
#     accuracy                           0.59        17
#    macro avg       0.59      0.58      0.58        17
# weighted avg       0.59      0.59      0.59        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 10
# Telkomsel
#
# Matrik
#
# [[9 4]
#  [2 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.69      0.75        13
#            1       0.20      0.33      0.25         3
#
#     accuracy                           0.62        16
#    macro avg       0.51      0.51      0.50        16
# weighted avg       0.70      0.62      0.66        16
#
#
# Akurasi
#
# 0.625
#
# Grafik
#
# 11
# Telkomsel
#
# Matrik
#
# [[7 1]
#  [3 5]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.88      0.78         8
#            1       0.83      0.62      0.71         8
#
#     accuracy                           0.75        16
#    macro avg       0.77      0.75      0.75        16
# weighted avg       0.77      0.75      0.75        16
#
#
# Akurasi
#
# 0.75
#
# Grafik
#
# 12
# Telkomsel
#
# Matrik
#
# [[6 4]
#  [4 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.60      0.60        10
#            1       0.33      0.33      0.33         6
#
#     accuracy                           0.50        16
#    macro avg       0.47      0.47      0.47        16
# weighted avg       0.50      0.50      0.50        16
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 13
# Telkomsel
#
# Matrik
#
# [[7 1]
#  [4 4]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.88      0.74         8
#            1       0.80      0.50      0.62         8
#
#     accuracy                           0.69        16
#    macro avg       0.72      0.69      0.68        16
# weighted avg       0.72      0.69      0.68        16
#
#
# Akurasi
#
# 0.6875
#
# Grafik
#
# 14
# Telkomsel
#
# Matrik
#
# [[5 2]
#  [6 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.45      0.71      0.56         7
#            1       0.60      0.33      0.43         9
#
#     accuracy                           0.50        16
#    macro avg       0.53      0.52      0.49        16
# weighted avg       0.54      0.50      0.48        16
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 15
# Telkomsel
#
# Matrik
#
# [[6 6]
#  [1 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.50      0.63        12
#            1       0.33      0.75      0.46         4
#
#     accuracy                           0.56        16
#    macro avg       0.60      0.62      0.55        16
# weighted avg       0.73      0.56      0.59        16
#
#
# Akurasi
#
# 0.5625
#
# Grafik
#
# 16
# Telkomsel
#
# Matrik
#
# [[6 1]
#  [6 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.86      0.63         7
#            1       0.75      0.33      0.46         9
#
#     accuracy                           0.56        16
#    macro avg       0.62      0.60      0.55        16
# weighted avg       0.64      0.56      0.54        16
#
#
# Akurasi
#
# 0.5625
#
# Grafik
#
# 17
# Telkomsel
#
# Matrik
#
# [[7 0]
#  [6 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.54      1.00      0.70         7
#            1       1.00      0.33      0.50         9
#
#     accuracy                           0.62        16
#    macro avg       0.77      0.67      0.60        16
# weighted avg       0.80      0.62      0.59        16
#
#
# Akurasi
#
# 0.625
#
# Grafik
#
# 18
# Telkomsel
#
# Matrik
#
# [[6 2]
#  [4 4]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.75      0.67         8
#            1       0.67      0.50      0.57         8
#
#     accuracy                           0.62        16
#    macro avg       0.63      0.62      0.62        16
# weighted avg       0.63      0.62      0.62        16
#
#
# Akurasi
#
# 0.625
#
# Grafik
#
# 19
# Telkomsel
#
# Matrik
#
# [[3 4]
#  [5 4]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.38      0.43      0.40         7
#            1       0.50      0.44      0.47         9
#
#     accuracy                           0.44        16
#    macro avg       0.44      0.44      0.44        16
# weighted avg       0.45      0.44      0.44        16
#
#
# Akurasi
#
# 0.4375
#
# Grafik
#
# 20
# Telkomsel
#
# Matrik
#
# [[4 3]
#  [4 4]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.57      0.53         7
#            1       0.57      0.50      0.53         8
#
#     accuracy                           0.53        15
#    macro avg       0.54      0.54      0.53        15
# weighted avg       0.54      0.53      0.53        15
#
#
# Akurasi
#
# 0.5333333333333333
#
# Grafik
#
# 21
# Telkomsel
#
# Matrik
#
# [[4 3]
#  [4 4]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.57      0.53         7
#            1       0.57      0.50      0.53         8
#
#     accuracy                           0.53        15
#    macro avg       0.54      0.54      0.53        15
# weighted avg       0.54      0.53      0.53        15
#
#
# Akurasi
#
# 0.5333333333333333
#
# Grafik
#
# 22
# Telkomsel
#
# Matrik
#
# [[7 3]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.70      0.70        10
#            1       0.40      0.40      0.40         5
#
#     accuracy                           0.60        15
#    macro avg       0.55      0.55      0.55        15
# weighted avg       0.60      0.60      0.60        15
#
#
# Akurasi
#
# 0.6
#
# Grafik
#
# 23
# Telkomsel
#
# Matrik
#
# [[6 4]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.60      0.60        10
#            1       0.20      0.20      0.20         5
#
#     accuracy                           0.47        15
#    macro avg       0.40      0.40      0.40        15
# weighted avg       0.47      0.47      0.47        15
#
#
# Akurasi
#
# 0.4666666666666667
#
# Grafik
#
# 24
# Telkomsel
#
# Matrik
#
# [[8 1]
#  [1 5]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89         9
#            1       0.83      0.83      0.83         6
#
#     accuracy                           0.87        15
#    macro avg       0.86      0.86      0.86        15
# weighted avg       0.87      0.87      0.87        15
#
#
# Akurasi
#
# 0.8666666666666667
#
# Grafik
#
# 25
# Telkomsel
#
# Matrik
#
# [[8 3]
#  [2 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.73      0.76        11
#            1       0.40      0.50      0.44         4
#
#     accuracy                           0.67        15
#    macro avg       0.60      0.61      0.60        15
# weighted avg       0.69      0.67      0.68        15
#
#
# Akurasi
#
# 0.6666666666666666
#
# Grafik
#
# 26
# Telkomsel
#
# Matrik
#
# [[5 1]
#  [7 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.42      0.83      0.56         6
#            1       0.67      0.22      0.33         9
#
#     accuracy                           0.47        15
#    macro avg       0.54      0.53      0.44        15
# weighted avg       0.57      0.47      0.42        15
#
#
# Akurasi
#
# 0.4666666666666667
#
# Grafik
#
# 27
# Telkomsel
#
# Matrik
#
# [[3 3]
#  [5 4]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.38      0.50      0.43         6
#            1       0.57      0.44      0.50         9
#
#     accuracy                           0.47        15
#    macro avg       0.47      0.47      0.46        15
# weighted avg       0.49      0.47      0.47        15
#
#
# Akurasi
#
# 0.4666666666666667
#
# Grafik
#
# 28
# Telkomsel
#
# Matrik
#
# [[3 1]
#  [6 5]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.33      0.75      0.46         4
#            1       0.83      0.45      0.59        11
#
#     accuracy                           0.53        15
#    macro avg       0.58      0.60      0.52        15
# weighted avg       0.70      0.53      0.55        15
#
#
# Akurasi
#
# 0.5333333333333333
#
# Grafik
#
# 29
# Telkomsel
#
# Matrik
#
# [[3 5]
#  [2 5]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.38      0.46         8
#            1       0.50      0.71      0.59         7
#
#     accuracy                           0.53        15
#    macro avg       0.55      0.54      0.52        15
# weighted avg       0.55      0.53      0.52        15
#
#
# Akurasi
#
# 0.5333333333333333
#
# Grafik
#
# 30
# Telkomsel
#
# Matrik
#
# [[6 1]
#  [5 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.55      0.86      0.67         7
#            1       0.67      0.29      0.40         7
#
#     accuracy                           0.57        14
#    macro avg       0.61      0.57      0.53        14
# weighted avg       0.61      0.57      0.53        14
#
#
# Akurasi
#
# 0.5714285714285714
#
# Grafik
#
# 31
# Telkomsel
#
# Matrik
#
# [[6 1]
#  [4 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.86      0.71         7
#            1       0.75      0.43      0.55         7
#
#     accuracy                           0.64        14
#    macro avg       0.68      0.64      0.63        14
# weighted avg       0.67      0.64      0.63        14
#
#
# Akurasi
#
# 0.6428571428571429
#
# Grafik
#
# 32
# Telkomsel
#
# Matrik
#
# [[5 3]
#  [4 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.62      0.59         8
#            1       0.40      0.33      0.36         6
#
#     accuracy                           0.50        14
#    macro avg       0.48      0.48      0.48        14
# weighted avg       0.49      0.50      0.49        14
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 33
# Telkomsel
#
# Matrik
#
# [[2 3]
#  [7 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.22      0.40      0.29         5
#            1       0.40      0.22      0.29         9
#
#     accuracy                           0.29        14
#    macro avg       0.31      0.31      0.29        14
# weighted avg       0.34      0.29      0.29        14
#
#
# Akurasi
#
# 0.2857142857142857
#
# Grafik
#
# 34
# Telkomsel
#
# Matrik
#
# [[4 2]
#  [5 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.44      0.67      0.53         6
#            1       0.60      0.38      0.46         8
#
#     accuracy                           0.50        14
#    macro avg       0.52      0.52      0.50        14
# weighted avg       0.53      0.50      0.49        14
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 35
# Telkomsel
#
# Matrik
#
# [[5 2]
#  [5 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.71      0.59         7
#            1       0.50      0.29      0.36         7
#
#     accuracy                           0.50        14
#    macro avg       0.50      0.50      0.48        14
# weighted avg       0.50      0.50      0.48        14
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 36
# Telkomsel
#
# Matrik
#
# [[2 5]
#  [4 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.33      0.29      0.31         7
#            1       0.38      0.43      0.40         7
#
#     accuracy                           0.36        14
#    macro avg       0.35      0.36      0.35        14
# weighted avg       0.35      0.36      0.35        14
#
#
# Akurasi
#
# 0.35714285714285715
#
# Grafik
#
# 37
# Telkomsel
#
# Matrik
#
# [[4 5]
#  [1 4]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.44      0.57         9
#            1       0.44      0.80      0.57         5
#
#     accuracy                           0.57        14
#    macro avg       0.62      0.62      0.57        14
# weighted avg       0.67      0.57      0.57        14
#
#
# Akurasi
#
# 0.5714285714285714
#
# Grafik
#
# 38
# Telkomsel
#
# Matrik
#
# [[4 1]
#  [3 6]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.80      0.67         5
#            1       0.86      0.67      0.75         9
#
#     accuracy                           0.71        14
#    macro avg       0.71      0.73      0.71        14
# weighted avg       0.76      0.71      0.72        14
#
#
# Akurasi
#
# 0.7142857142857143
#
# Grafik
#
# 39
# Telkomsel
#
# Matrik
#
# [[3 4]
#  [1 6]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.43      0.55         7
#            1       0.60      0.86      0.71         7
#
#     accuracy                           0.64        14
#    macro avg       0.68      0.64      0.63        14
# weighted avg       0.67      0.64      0.63        14
#
#
# Akurasi
#
# 0.6428571428571429
#
# Grafik
#
# 40
# Telkomsel
#
# Matrik
#
# [[1 4]
#  [5 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.17      0.20      0.18         5
#            1       0.43      0.38      0.40         8
#
#     accuracy                           0.31        13
#    macro avg       0.30      0.29      0.29        13
# weighted avg       0.33      0.31      0.32        13
#
#
# Akurasi
#
# 0.3076923076923077
#
# Grafik
#
# 41
# Telkomsel
#
# Matrik
#
# [[4 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.50      0.57         8
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.54        13
#    macro avg       0.55      0.55      0.54        13
# weighted avg       0.58      0.54      0.54        13
#
#
# Akurasi
#
# 0.5384615384615384
#
# Grafik
#
# 42
# Telkomsel
#
# Matrik
#
# [[7 0]
#  [3 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.82         7
#            1       1.00      0.50      0.67         6
#
#     accuracy                           0.77        13
#    macro avg       0.85      0.75      0.75        13
# weighted avg       0.84      0.77      0.75        13
#
#
# Akurasi
#
# 0.7692307692307693
#
# Grafik
#
# 43
# Telkomsel
#
# Matrik
#
# [[4 6]
#  [1 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.40      0.53        10
#            1       0.25      0.67      0.36         3
#
#     accuracy                           0.46        13
#    macro avg       0.53      0.53      0.45        13
# weighted avg       0.67      0.46      0.49        13
#
#
# Akurasi
#
# 0.46153846153846156
#
# Grafik
#
# 44
# Telkomsel
#
# Matrik
#
# [[5 2]
#  [3 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.71      0.67         7
#            1       0.60      0.50      0.55         6
#
#     accuracy                           0.62        13
#    macro avg       0.61      0.61      0.61        13
# weighted avg       0.61      0.62      0.61        13
#
#
# Akurasi
#
# 0.6153846153846154
#
# Grafik
#
# 45
# Telkomsel
#
# Matrik
#
# [[4 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.50      0.53         8
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.46        13
#    macro avg       0.45      0.45      0.45        13
# weighted avg       0.48      0.46      0.47        13
#
#
# Akurasi
#
# 0.46153846153846156
#
# Grafik
#
# 46
# Telkomsel
#
# Matrik
#
# [[5 1]
#  [6 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.45      0.83      0.59         6
#            1       0.50      0.14      0.22         7
#
#     accuracy                           0.46        13
#    macro avg       0.48      0.49      0.41        13
# weighted avg       0.48      0.46      0.39        13
#
#
# Akurasi
#
# 0.46153846153846156
#
# Grafik
#
# 47
# Telkomsel
#
# Matrik
#
# [[4 5]
#  [1 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.44      0.57         9
#            1       0.38      0.75      0.50         4
#
#     accuracy                           0.54        13
#    macro avg       0.59      0.60      0.54        13
# weighted avg       0.67      0.54      0.55        13
#
#
# Akurasi
#
# 0.5384615384615384
#
# Grafik
#
# 48
# Telkomsel
#
# Matrik
#
# [[5 2]
#  [2 4]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.71      0.71         7
#            1       0.67      0.67      0.67         6
#
#     accuracy                           0.69        13
#    macro avg       0.69      0.69      0.69        13
# weighted avg       0.69      0.69      0.69        13
#
#
# Akurasi
#
# 0.6923076923076923
#
# Grafik
#
# 49
# Telkomsel
#
# Matrik
#
# [[4 2]
#  [3 4]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.67      0.62         6
#            1       0.67      0.57      0.62         7
#
#     accuracy                           0.62        13
#    macro avg       0.62      0.62      0.62        13
# weighted avg       0.62      0.62      0.62        13
#
#
# Akurasi
#
# 0.6153846153846154
#
# Grafik
#
# 50
# Telkomsel
#
# Matrik
#
# [[5 1]
#  [4 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.83      0.67         6
#            1       0.67      0.33      0.44         6
#
#     accuracy                           0.58        12
#    macro avg       0.61      0.58      0.56        12
# weighted avg       0.61      0.58      0.56        12
#
#
# Akurasi
#
# 0.5833333333333334
#
# Grafik
#
# 51
# Telkomsel
#
# Matrik
#
# [[4 2]
#  [2 4]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67         6
#            1       0.67      0.67      0.67         6
#
#     accuracy                           0.67        12
#    macro avg       0.67      0.67      0.67        12
# weighted avg       0.67      0.67      0.67        12
#
#
# Akurasi
#
# 0.6666666666666666
#
# Grafik
#
# 52
# Telkomsel
#
# Matrik
#
# [[3 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.43      0.46         7
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.42        12
#    macro avg       0.42      0.41      0.41        12
# weighted avg       0.43      0.42      0.42        12
#
#
# Akurasi
#
# 0.4166666666666667
#
# Grafik
#
# 53
# Telkomsel
#
# Matrik
#
# [[3 1]
#  [5 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.38      0.75      0.50         4
#            1       0.75      0.38      0.50         8
#
#     accuracy                           0.50        12
#    macro avg       0.56      0.56      0.50        12
# weighted avg       0.62      0.50      0.50        12
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 54
# Telkomsel
#
# Matrik
#
# [[6 4]
#  [2 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.60      0.67        10
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.50        12
#    macro avg       0.38      0.30      0.33        12
# weighted avg       0.62      0.50      0.56        12
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 55
# Telkomsel
#
# Matrik
#
# [[5 2]
#  [5 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.71      0.59         7
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.42        12
#    macro avg       0.25      0.36      0.29        12
# weighted avg       0.29      0.42      0.34        12
#
#
# Akurasi
#
# 0.4166666666666667
#
# Grafik
#
# 56
# Telkomsel
#
# Matrik
#
# [[4 1]
#  [2 5]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.80      0.73         5
#            1       0.83      0.71      0.77         7
#
#     accuracy                           0.75        12
#    macro avg       0.75      0.76      0.75        12
# weighted avg       0.76      0.75      0.75        12
#
#
# Akurasi
#
# 0.75
#
# Grafik
#
# 57
# Telkomsel
#
# Matrik
#
# [[3 5]
#  [3 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.38      0.43         8
#            1       0.17      0.25      0.20         4
#
#     accuracy                           0.33        12
#    macro avg       0.33      0.31      0.31        12
# weighted avg       0.39      0.33      0.35        12
#
#
# Akurasi
#
# 0.3333333333333333
#
# Grafik
#
# 58
# Telkomsel
#
# Matrik
#
# [[3 2]
#  [5 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.38      0.60      0.46         5
#            1       0.50      0.29      0.36         7
#
#     accuracy                           0.42        12
#    macro avg       0.44      0.44      0.41        12
# weighted avg       0.45      0.42      0.40        12
#
#
# Akurasi
#
# 0.4166666666666667
#
# Grafik
#
# 59
# Telkomsel
#
# Matrik
#
# [[5 1]
#  [4 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.83      0.67         6
#            1       0.67      0.33      0.44         6
#
#     accuracy                           0.58        12
#    macro avg       0.61      0.58      0.56        12
# weighted avg       0.61      0.58      0.56        12
#
#
# Akurasi
#
# 0.5833333333333334
#
# Grafik
#
# 60
# Telkomsel
#
# Matrik
#
# [[4 2]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67         6
#            1       0.60      0.60      0.60         5
#
#     accuracy                           0.64        11
#    macro avg       0.63      0.63      0.63        11
# weighted avg       0.64      0.64      0.64        11
#
#
# Akurasi
#
# 0.6363636363636364
#
# Grafik
#
# 61
# Telkomsel
#
# Matrik
#
# [[4 2]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67         6
#            1       0.60      0.60      0.60         5
#
#     accuracy                           0.64        11
#    macro avg       0.63      0.63      0.63        11
# weighted avg       0.64      0.64      0.64        11
#
#
# Akurasi
#
# 0.6363636363636364
#
# Grafik
#
# 62
# Telkomsel
#
# Matrik
#
# [[4 2]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.67      0.62         6
#            1       0.50      0.40      0.44         5
#
#     accuracy                           0.55        11
#    macro avg       0.54      0.53      0.53        11
# weighted avg       0.54      0.55      0.54        11
#
#
# Akurasi
#
# 0.5454545454545454
#
# Grafik
#
# 63
# Telkomsel
#
# Matrik
#
# [[5 1]
#  [1 4]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83         6
#            1       0.80      0.80      0.80         5
#
#     accuracy                           0.82        11
#    macro avg       0.82      0.82      0.82        11
# weighted avg       0.82      0.82      0.82        11
#
#
# Akurasi
#
# 0.8181818181818182
#
# Grafik
#
# 64
# Telkomsel
#
# Matrik
#
# [[4 2]
#  [1 4]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73         6
#            1       0.67      0.80      0.73         5
#
#     accuracy                           0.73        11
#    macro avg       0.73      0.73      0.73        11
# weighted avg       0.74      0.73      0.73        11
#
#
# Akurasi
#
# 0.7272727272727273
#
# Grafik
#
# 65
# Telkomsel
#
# Matrik
#
# [[3 0]
#  [5 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.38      1.00      0.55         3
#            1       1.00      0.38      0.55         8
#
#     accuracy                           0.55        11
#    macro avg       0.69      0.69      0.55        11
# weighted avg       0.83      0.55      0.55        11
#
#
# Akurasi
#
# 0.5454545454545454
#
# Grafik
#
# 66
# Telkomsel
#
# Matrik
#
# [[2 3]
#  [4 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.33      0.40      0.36         5
#            1       0.40      0.33      0.36         6
#
#     accuracy                           0.36        11
#    macro avg       0.37      0.37      0.36        11
# weighted avg       0.37      0.36      0.36        11
#
#
# Akurasi
#
# 0.36363636363636365
#
# Grafik
#
# 67
# Telkomsel
#
# Matrik
#
# [[5 1]
#  [0 5]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.91         6
#            1       0.83      1.00      0.91         5
#
#     accuracy                           0.91        11
#    macro avg       0.92      0.92      0.91        11
# weighted avg       0.92      0.91      0.91        11
#
#
# Akurasi
#
# 0.9090909090909091
#
# Grafik
#
# 68
# Telkomsel
#
# Matrik
#
# [[2 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.33      0.40         6
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.45        11
#    macro avg       0.46      0.47      0.45        11
# weighted avg       0.47      0.45      0.45        11
#
#
# Akurasi
#
# 0.45454545454545453
#
# Grafik
#
# 69
# Telkomsel
#
# Matrik
#
# [[4 0]
#  [4 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         4
#            1       1.00      0.43      0.60         7
#
#     accuracy                           0.64        11
#    macro avg       0.75      0.71      0.63        11
# weighted avg       0.82      0.64      0.62        11
#
#
# Akurasi
#
# 0.6363636363636364
#
# Grafik
#
# 70
# Telkomsel
#
# Matrik
#
# [[3 2]
#  [5 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.38      0.60      0.46         5
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.30        10
#    macro avg       0.19      0.30      0.23        10
# weighted avg       0.19      0.30      0.23        10
#
#
# Akurasi
#
# 0.3
#
# Grafik
#
# 71
# Telkomsel
#
# Matrik
#
# [[0 6]
#  [2 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         6
#            1       0.25      0.50      0.33         4
#
#     accuracy                           0.20        10
#    macro avg       0.12      0.25      0.17        10
# weighted avg       0.10      0.20      0.13        10
#
#
# Akurasi
#
# 0.2
#
# Grafik
#
# 72
# Telkomsel
#
# Matrik
#
# [[3 1]
#  [3 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.75      0.60         4
#            1       0.75      0.50      0.60         6
#
#     accuracy                           0.60        10
#    macro avg       0.62      0.62      0.60        10
# weighted avg       0.65      0.60      0.60        10
#
#
# Akurasi
#
# 0.6
#
# Grafik
#
# 73
# Telkomsel
#
# Matrik
#
# [[2 3]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.40      0.40      0.40         5
#            1       0.40      0.40      0.40         5
#
#     accuracy                           0.40        10
#    macro avg       0.40      0.40      0.40        10
# weighted avg       0.40      0.40      0.40        10
#
#
# Akurasi
#
# 0.4
#
# Grafik
#
# 74
# Telkomsel
#
# Matrik
#
# [[3 1]
#  [2 4]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.75      0.67         4
#            1       0.80      0.67      0.73         6
#
#     accuracy                           0.70        10
#    macro avg       0.70      0.71      0.70        10
# weighted avg       0.72      0.70      0.70        10
#
#
# Akurasi
#
# 0.7
#
# Grafik
#
# 75
# Telkomsel
#
# Matrik
#
# [[3 1]
#  [3 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.75      0.60         4
#            1       0.75      0.50      0.60         6
#
#     accuracy                           0.60        10
#    macro avg       0.62      0.62      0.60        10
# weighted avg       0.65      0.60      0.60        10
#
#
# Akurasi
#
# 0.6
#
# Grafik
#
# 76
# Telkomsel
#
# Matrik
#
# [[3 3]
#  [2 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.50      0.55         6
#            1       0.40      0.50      0.44         4
#
#     accuracy                           0.50        10
#    macro avg       0.50      0.50      0.49        10
# weighted avg       0.52      0.50      0.51        10
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 77
# Telkomsel
#
# Matrik
#
# [[1 5]
#  [1 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.17      0.25         6
#            1       0.38      0.75      0.50         4
#
#     accuracy                           0.40        10
#    macro avg       0.44      0.46      0.38        10
# weighted avg       0.45      0.40      0.35        10
#
#
# Akurasi
#
# 0.4
#
# Grafik
#
# 78
# Telkomsel
#
# Matrik
#
# [[2 4]
#  [2 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.33      0.40         6
#            1       0.33      0.50      0.40         4
#
#     accuracy                           0.40        10
#    macro avg       0.42      0.42      0.40        10
# weighted avg       0.43      0.40      0.40        10
#
#
# Akurasi
#
# 0.4
#
# Grafik
#
# 79
# Telkomsel
#
# Matrik
#
# [[3 1]
#  [4 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.43      0.75      0.55         4
#            1       0.67      0.33      0.44         6
#
#     accuracy                           0.50        10
#    macro avg       0.55      0.54      0.49        10
# weighted avg       0.57      0.50      0.48        10
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 80
# Telkomsel
#
# Matrik
#
# [[3 0]
#  [6 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.33      1.00      0.50         3
#            1       0.00      0.00      0.00         6
#
#     accuracy                           0.33         9
#    macro avg       0.17      0.50      0.25         9
# weighted avg       0.11      0.33      0.17         9
#
#
# Akurasi
#
# 0.3333333333333333
#
# Grafik
#
# 81
# Telkomsel
#
# Matrik
#
# [[6 2]
#  [0 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.75      0.86         8
#            1       0.33      1.00      0.50         1
#
#     accuracy                           0.78         9
#    macro avg       0.67      0.88      0.68         9
# weighted avg       0.93      0.78      0.82         9
#
#
# Akurasi
#
# 0.7777777777777778
#
# Grafik
#
# 82
# Telkomsel
#
# Matrik
#
# [[2 2]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.40      0.50      0.44         4
#            1       0.50      0.40      0.44         5
#
#     accuracy                           0.44         9
#    macro avg       0.45      0.45      0.44         9
# weighted avg       0.46      0.44      0.44         9
#
#
# Akurasi
#
# 0.4444444444444444
#
# Grafik
#
# 83
# Telkomsel
#
# Matrik
#
# [[3 2]
#  [3 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.60      0.55         5
#            1       0.33      0.25      0.29         4
#
#     accuracy                           0.44         9
#    macro avg       0.42      0.42      0.42         9
# weighted avg       0.43      0.44      0.43         9
#
#
# Akurasi
#
# 0.4444444444444444
#
# Grafik
#
# 84
# Telkomsel
#
# Matrik
#
# [[2 5]
#  [1 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.29      0.40         7
#            1       0.17      0.50      0.25         2
#
#     accuracy                           0.33         9
#    macro avg       0.42      0.39      0.33         9
# weighted avg       0.56      0.33      0.37         9
#
#
# Akurasi
#
# 0.3333333333333333
#
# Grafik
#
# 85
# Telkomsel
#
# Matrik
#
# [[3 2]
#  [2 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.60      0.60         5
#            1       0.50      0.50      0.50         4
#
#     accuracy                           0.56         9
#    macro avg       0.55      0.55      0.55         9
# weighted avg       0.56      0.56      0.56         9
#
#
# Akurasi
#
# 0.5555555555555556
#
# Grafik
#
# 86
# Telkomsel
#
# Matrik
#
# [[3 1]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.43      0.75      0.55         4
#            1       0.50      0.20      0.29         5
#
#     accuracy                           0.44         9
#    macro avg       0.46      0.47      0.42         9
# weighted avg       0.47      0.44      0.40         9
#
#
# Akurasi
#
# 0.4444444444444444
#
# Grafik
#
# 87
# Telkomsel
#
# Matrik
#
# [[1 5]
#  [1 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.17      0.25         6
#            1       0.29      0.67      0.40         3
#
#     accuracy                           0.33         9
#    macro avg       0.39      0.42      0.33         9
# weighted avg       0.43      0.33      0.30         9
#
#
# Akurasi
#
# 0.3333333333333333
#
# Grafik
#
# 88
# Telkomsel
#
# Matrik
#
# [[4 2]
#  [3 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.67      0.62         6
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.44         9
#    macro avg       0.29      0.33      0.31         9
# weighted avg       0.38      0.44      0.41         9
#
#
# Akurasi
#
# 0.4444444444444444
#
# Grafik
#
# 89
# Telkomsel
#
# Matrik
#
# [[2 2]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.40      0.50      0.44         4
#            1       0.50      0.40      0.44         5
#
#     accuracy                           0.44         9
#    macro avg       0.45      0.45      0.44         9
# weighted avg       0.46      0.44      0.44         9
#
#
# Akurasi
#
# 0.4444444444444444
#
# Grafik
#
# 90
# Telkomsel
#
# Matrik
#
# [[2 1]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.40      0.67      0.50         3
#            1       0.67      0.40      0.50         5
#
#     accuracy                           0.50         8
#    macro avg       0.53      0.53      0.50         8
# weighted avg       0.57      0.50      0.50         8
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 91
# Telkomsel
#
# Matrik
#
# [[2 2]
#  [3 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.40      0.50      0.44         4
#            1       0.33      0.25      0.29         4
#
#     accuracy                           0.38         8
#    macro avg       0.37      0.38      0.37         8
# weighted avg       0.37      0.38      0.37         8
#
#
# Akurasi
#
# 0.375
#
# Grafik
#
# 92
# Telkomsel
#
# Matrik
#
# [[2 3]
#  [1 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.40      0.50         5
#            1       0.40      0.67      0.50         3
#
#     accuracy                           0.50         8
#    macro avg       0.53      0.53      0.50         8
# weighted avg       0.57      0.50      0.50         8
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 93
# Telkomsel
#
# Matrik
#
# [[4 3]
#  [0 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.57      0.73         7
#            1       0.25      1.00      0.40         1
#
#     accuracy                           0.62         8
#    macro avg       0.62      0.79      0.56         8
# weighted avg       0.91      0.62      0.69         8
#
#
# Akurasi
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.625
#
# Grafik
#
# 94
# Telkomsel
#
# Matrik
#
# [[1 3]
#  [2 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.33      0.25      0.29         4
#            1       0.40      0.50      0.44         4
#
#     accuracy                           0.38         8
#    macro avg       0.37      0.38      0.37         8
# weighted avg       0.37      0.38      0.37         8
#
#
# Akurasi
#
# 0.375
#
# Grafik
#
# 95
# Telkomsel
#
# Matrik
#
# [[4 2]
#  [1 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73         6
#            1       0.33      0.50      0.40         2
#
#     accuracy                           0.62         8
#    macro avg       0.57      0.58      0.56         8
# weighted avg       0.68      0.62      0.65         8
#
#
# Akurasi
#
# 0.625
#
# Grafik
#
# 96
# Telkomsel
#
# Matrik
#
# [[2 4]
#  [1 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.33      0.44         6
#            1       0.20      0.50      0.29         2
#
#     accuracy                           0.38         8
#    macro avg       0.43      0.42      0.37         8
# weighted avg       0.55      0.38      0.40         8
#
#
# Akurasi
#
# 0.375
#
# Grafik
#
# 97
# Telkomsel
#
# Matrik
#
# [[2 1]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.67      0.57         3
#            1       0.75      0.60      0.67         5
#
#     accuracy                           0.62         8
#    macro avg       0.62      0.63      0.62         8
# weighted avg       0.66      0.62      0.63         8
#
#
# Akurasi
#
# 0.625
#
# Grafik
#
# 98
# Telkomsel
#
# Matrik
#
# [[4 2]
#  [1 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73         6
#            1       0.33      0.50      0.40         2
#
#     accuracy                           0.62         8
#    macro avg       0.57      0.58      0.56         8
# weighted avg       0.68      0.62      0.65         8
#
#
# Akurasi
#
# 0.625
#
# Grafik
#
# 99
# Telkomsel
#
# Matrik
#
# [[4 1]
#  [3 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.80      0.67         5
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.50         8
#    macro avg       0.29      0.40      0.33         8
# weighted avg       0.36      0.50      0.42         8
#
#
# Akurasi
#
# 0.5
#
# Grafik

# %%
x_train, x_test, y_train, y_test = klasifikasiData(data='telkom', split_jadi=67)
klasifikasiKNeighbor = KNeighborsClassifier(n_neighbors=5)
klasifikasiKNeighbor.fit(x_train, y_train)
predic_y = klasifikasiKNeighbor.predict(x_test)
  
printHasil(y_test, predic_y, "Telkomsel")
import pickle
file = open('KNN_Telkom.otak', 'wb')

# dump information to that file
pickle.dump(klasifikasiKNeighbor, file)

# close the file
file.close()
# Out:
# Telkomsel
#
# Matrik
#
# [[5 1]
#  [0 5]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.91         6
#            1       0.83      1.00      0.91         5
#
#     accuracy                           0.91        11
#    macro avg       0.92      0.92      0.91        11
# weighted avg       0.92      0.91      0.91        11
#
#
# Akurasi
#
# 0.9090909090909091
#
# Grafik

# %%
for totalsplit in range(5,100):

# Smartfren
  x_train, x_test, y_train, y_test = klasifikasiData(data='Smartfren', split_jadi=totalsplit)
  klasifikasiKNeighbor = KNeighborsClassifier(n_neighbors=5)
  klasifikasiKNeighbor.fit(x_train, y_train)
  predic_y = klasifikasiKNeighbor.predict(x_test)
  print(totalsplit)

  printHasil(y_test, predic_y, "Smartfren")
# Out:
# 5
# Smartfren
#
# Matrik
#
# [[9 4]
#  [4 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.69      0.69      0.69        13
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.53        17
#    macro avg       0.35      0.35      0.35        17
# weighted avg       0.53      0.53      0.53        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 6
# Smartfren
#
# Matrik
#
# [[12  3]
#  [ 1  1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.80      0.86        15
#            1       0.25      0.50      0.33         2
#
#     accuracy                           0.76        17
#    macro avg       0.59      0.65      0.60        17
# weighted avg       0.84      0.76      0.80        17
#
#
# Akurasi
#
# 0.7647058823529411
#
# Grafik
#
# 7
# Smartfren
#
# Matrik
#
# [[7 1]
#  [6 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.54      0.88      0.67         8
#            1       0.75      0.33      0.46         9
#
#     accuracy                           0.59        17
#    macro avg       0.64      0.60      0.56        17
# weighted avg       0.65      0.59      0.56        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 8
# Smartfren
#
# Matrik
#
# [[8 5]
#  [3 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.62      0.67        13
#            1       0.17      0.25      0.20         4
#
#     accuracy                           0.53        17
#    macro avg       0.45      0.43      0.43        17
# weighted avg       0.60      0.53      0.56        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 9
# Smartfren
#
# Matrik
#
# [[7 5]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.58      0.61        12
#            1       0.17      0.20      0.18         5
#
#     accuracy                           0.47        17
#    macro avg       0.40      0.39      0.40        17
# weighted avg       0.50      0.47      0.48        17
#
#
# Akurasi
#
# 0.47058823529411764
#
# Grafik
#
# 10
# Smartfren
#
# Matrik
#
# [[8 2]
#  [5 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.80      0.70        10
#            1       0.33      0.17      0.22         6
#
#     accuracy                           0.56        16
#    macro avg       0.47      0.48      0.46        16
# weighted avg       0.51      0.56      0.52        16
#
#
# Akurasi
#
# 0.5625
#
# Grafik
#
# 11
# Smartfren
#
# Matrik
#
# [[7 1]
#  [6 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.54      0.88      0.67         8
#            1       0.67      0.25      0.36         8
#
#     accuracy                           0.56        16
#    macro avg       0.60      0.56      0.52        16
# weighted avg       0.60      0.56      0.52        16
#
#
# Akurasi
#
# 0.5625
#
# Grafik
#
# 12
# Smartfren
#
# Matrik
#
# [[7 3]
#  [5 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.58      0.70      0.64        10
#            1       0.25      0.17      0.20         6
#
#     accuracy                           0.50        16
#    macro avg       0.42      0.43      0.42        16
# weighted avg       0.46      0.50      0.47        16
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 13
# Smartfren
#
# Matrik
#
# [[9 3]
#  [2 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.75      0.78        12
#            1       0.40      0.50      0.44         4
#
#     accuracy                           0.69        16
#    macro avg       0.61      0.62      0.61        16
# weighted avg       0.71      0.69      0.70        16
#
#
# Akurasi
#
# 0.6875
#
# Grafik
#
# 14
# Smartfren
#
# Matrik
#
# [[11  0]
#  [ 4  1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      1.00      0.85        11
#            1       1.00      0.20      0.33         5
#
#     accuracy                           0.75        16
#    macro avg       0.87      0.60      0.59        16
# weighted avg       0.82      0.75      0.69        16
#
#
# Akurasi
#
# 0.75
#
# Grafik
#
# 15
# Smartfren
#
# Matrik
#
# [[8 3]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.73      0.70        11
#            1       0.25      0.20      0.22         5
#
#     accuracy                           0.56        16
#    macro avg       0.46      0.46      0.46        16
# weighted avg       0.54      0.56      0.55        16
#
#
# Akurasi
#
# 0.5625
#
# Grafik
#
# 16
# Smartfren
#
# Matrik
#
# [[9 2]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.82      0.78        11
#            1       0.50      0.40      0.44         5
#
#     accuracy                           0.69        16
#    macro avg       0.62      0.61      0.61        16
# weighted avg       0.67      0.69      0.68        16
#
#
# Akurasi
#
# 0.6875
#
# Grafik
#
# 17
# Smartfren
#
# Matrik
#
# [[7 4]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.64      0.64        11
#            1       0.20      0.20      0.20         5
#
#     accuracy                           0.50        16
#    macro avg       0.42      0.42      0.42        16
# weighted avg       0.50      0.50      0.50        16
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 18
# Smartfren
#
# Matrik
#
# [[7 0]
#  [8 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.47      1.00      0.64         7
#            1       1.00      0.11      0.20         9
#
#     accuracy                           0.50        16
#    macro avg       0.73      0.56      0.42        16
# weighted avg       0.77      0.50      0.39        16
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 19
# Smartfren
#
# Matrik
#
# [[9 2]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.82      0.78        11
#            1       0.50      0.40      0.44         5
#
#     accuracy                           0.69        16
#    macro avg       0.62      0.61      0.61        16
# weighted avg       0.67      0.69      0.68        16
#
#
# Akurasi
#
# 0.6875
#
# Grafik
#
# 20
# Smartfren
#
# Matrik
#
# [[8 2]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80        10
#            1       0.60      0.60      0.60         5
#
#     accuracy                           0.73        15
#    macro avg       0.70      0.70      0.70        15
# weighted avg       0.73      0.73      0.73        15
#
#
# Akurasi
#
# 0.7333333333333333
#
# Grafik
#
# 21
# Smartfren
#
# Matrik
#
# [[7 4]
#  [2 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.64      0.70        11
#            1       0.33      0.50      0.40         4
#
#     accuracy                           0.60        15
#    macro avg       0.56      0.57      0.55        15
# weighted avg       0.66      0.60      0.62        15
#
#
# Akurasi
#
# 0.6
#
# Grafik
#
# 22
# Smartfren
#
# Matrik
#
# [[9 1]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.69      0.90      0.78        10
#            1       0.50      0.20      0.29         5
#
#     accuracy                           0.67        15
#    macro avg       0.60      0.55      0.53        15
# weighted avg       0.63      0.67      0.62        15
#
#
# Akurasi
#
# 0.6666666666666666
#
# Grafik
#
# 23
# Smartfren
#
# Matrik
#
# [[9 3]
#  [3 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75        12
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.60        15
#    macro avg       0.38      0.38      0.38        15
# weighted avg       0.60      0.60      0.60        15
#
#
# Akurasi
#
# 0.6
#
# Grafik
#
# 24
# Smartfren
#
# Matrik
#
# [[10  3]
#  [ 1  1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.77      0.83        13
#            1       0.25      0.50      0.33         2
#
#     accuracy                           0.73        15
#    macro avg       0.58      0.63      0.58        15
# weighted avg       0.82      0.73      0.77        15
#
#
# Akurasi
#
# 0.7333333333333333
#
# Grafik
#
# 25
# Smartfren
#
# Matrik
#
# [[8 1]
#  [5 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.89      0.73         9
#            1       0.50      0.17      0.25         6
#
#     accuracy                           0.60        15
#    macro avg       0.56      0.53      0.49        15
# weighted avg       0.57      0.60      0.54        15
#
#
# Akurasi
#
# 0.6
#
# Grafik
#
# 26
# Smartfren
#
# Matrik
#
# [[8 5]
#  [1 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.62      0.73        13
#            1       0.17      0.50      0.25         2
#
#     accuracy                           0.60        15
#    macro avg       0.53      0.56      0.49        15
# weighted avg       0.79      0.60      0.66        15
#
#
# Akurasi
#
# 0.6
#
# Grafik
#
# 27
# Smartfren
#
# Matrik
#
# [[5 5]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.50      0.59        10
#            1       0.38      0.60      0.46         5
#
#     accuracy                           0.53        15
#    macro avg       0.54      0.55      0.52        15
# weighted avg       0.60      0.53      0.55        15
#
#
# Akurasi
#
# 0.5333333333333333
#
# Grafik
#
# 28
# Smartfren
#
# Matrik
#
# [[8 2]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.80      0.73        10
#            1       0.33      0.20      0.25         5
#
#     accuracy                           0.60        15
#    macro avg       0.50      0.50      0.49        15
# weighted avg       0.56      0.60      0.57        15
#
#
# Akurasi
#
# 0.6
#
# Grafik
#
# 29
# Smartfren
#
# Matrik
#
# [[9 3]
#  [3 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75        12
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.60        15
#    macro avg       0.38      0.38      0.38        15
# weighted avg       0.60      0.60      0.60        15
#
#
# Akurasi
#
# 0.6
#
# Grafik
#
# 30
# Smartfren
#
# Matrik
#
# [[7 4]
#  [2 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.64      0.70        11
#            1       0.20      0.33      0.25         3
#
#     accuracy                           0.57        14
#    macro avg       0.49      0.48      0.48        14
# weighted avg       0.65      0.57      0.60        14
#
#
# Akurasi
#
# 0.5714285714285714
#
# Grafik
#
# 31
# Smartfren
#
# Matrik
#
# [[8 2]
#  [4 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.80      0.73        10
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.57        14
#    macro avg       0.33      0.40      0.36        14
# weighted avg       0.48      0.57      0.52        14
#
#
# Akurasi
#
# 0.5714285714285714
#
# Grafik
#
# 32
# Smartfren
#
# Matrik
#
# [[9 2]
#  [2 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82        11
#            1       0.33      0.33      0.33         3
#
#     accuracy                           0.71        14
#    macro avg       0.58      0.58      0.58        14
# weighted avg       0.71      0.71      0.71        14
#
#
# Akurasi
#
# 0.7142857142857143
#
# Grafik
#
# 33
# Smartfren
#
# Matrik
#
# [[8 2]
#  [4 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.80      0.73        10
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.57        14
#    macro avg       0.33      0.40      0.36        14
# weighted avg       0.48      0.57      0.52        14
#
#
# Akurasi
#
# 0.5714285714285714
#
# Grafik
#
# 34
# Smartfren
#
# Matrik
#
# [[8 4]
#  [1 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.67      0.76        12
#            1       0.20      0.50      0.29         2
#
#     accuracy                           0.64        14
#    macro avg       0.54      0.58      0.52        14
# weighted avg       0.79      0.64      0.69        14
#
#
# Akurasi
#
# 0.6428571428571429
#
# Grafik
#
# 35
# Smartfren
#
# Matrik
#
# [[7 3]
#  [4 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.70      0.67        10
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.50        14
#    macro avg       0.32      0.35      0.33        14
# weighted avg       0.45      0.50      0.48        14
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 36
# Smartfren
#
# Matrik
#
# [[8 3]
#  [2 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.73      0.76        11
#            1       0.25      0.33      0.29         3
#
#     accuracy                           0.64        14
#    macro avg       0.53      0.53      0.52        14
# weighted avg       0.68      0.64      0.66        14
#
#
# Akurasi
#
# 0.6428571428571429
#
# Grafik
#
# 37
# Smartfren
#
# Matrik
#
# [[11  1]
#  [ 1  1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92        12
#            1       0.50      0.50      0.50         2
#
#     accuracy                           0.86        14
#    macro avg       0.71      0.71      0.71        14
# weighted avg       0.86      0.86      0.86        14
#
#
# Akurasi
#
# 0.8571428571428571
#
# Grafik
#
# 38
# Smartfren
#
# Matrik
#
# [[8 4]
#  [2 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.57        14
#    macro avg       0.40      0.33      0.36        14
# weighted avg       0.69      0.57      0.62        14
#
#
# Akurasi
#
# 0.5714285714285714
#
# Grafik
#
# 39
# Smartfren
#
# Matrik
#
# [[7 3]
#  [2 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.70      0.74        10
#            1       0.40      0.50      0.44         4
#
#     accuracy                           0.64        14
#    macro avg       0.59      0.60      0.59        14
# weighted avg       0.67      0.64      0.65        14
#
#
# Akurasi
#
# 0.6428571428571429
#
# Grafik
#
# 40
# Smartfren
#
# Matrik
#
# [[8 1]
#  [2 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.89      0.84         9
#            1       0.67      0.50      0.57         4
#
#     accuracy                           0.77        13
#    macro avg       0.73      0.69      0.71        13
# weighted avg       0.76      0.77      0.76        13
#
#
# Akurasi
#
# 0.7692307692307693
#
# Grafik
#
# 41
# Smartfren
#
# Matrik
#
# [[9 1]
#  [1 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90        10
#            1       0.67      0.67      0.67         3
#
#     accuracy                           0.85        13
#    macro avg       0.78      0.78      0.78        13
# weighted avg       0.85      0.85      0.85        13
#
#
# Akurasi
#
# 0.8461538461538461
#
# Grafik
#
# 42
# Smartfren
#
# Matrik
#
# [[10  0]
#  [ 0  3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         3
#
#     accuracy                           1.00        13
#    macro avg       1.00      1.00      1.00        13
# weighted avg       1.00      1.00      1.00        13
#
#
# Akurasi
#
# 1.0
#
# Grafik
#
# 43
# Smartfren
#
# Matrik
#
# [[8 0]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80         8
#            1       1.00      0.20      0.33         5
#
#     accuracy                           0.69        13
#    macro avg       0.83      0.60      0.57        13
# weighted avg       0.79      0.69      0.62        13
#
#
# Akurasi
#
# 0.6923076923076923
#
# Grafik
#
# 44
# Smartfren
#
# Matrik
#
# [[9 2]
#  [2 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82        11
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.69        13
#    macro avg       0.41      0.41      0.41        13
# weighted avg       0.69      0.69      0.69        13
#
#
# Akurasi
#
# 0.6923076923076923
#
# Grafik
#
# 45
# Smartfren
#
# Matrik
#
# [[9 2]
#  [1 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.82      0.86        11
#            1       0.33      0.50      0.40         2
#
#     accuracy                           0.77        13
#    macro avg       0.62      0.66      0.63        13
# weighted avg       0.81      0.77      0.79        13
#
#
# Akurasi
#
# 0.7692307692307693
#
# Grafik
#
# 46
# Smartfren
#
# Matrik
#
# [[9 0]
#  [4 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.69      1.00      0.82         9
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.69        13
#    macro avg       0.35      0.50      0.41        13
# weighted avg       0.48      0.69      0.57        13
#
#
# Akurasi
#
# 0.6923076923076923
#
# Grafik
#
# 47
# Smartfren
#
# Matrik
#
# [[8 0]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80         8
#            1       1.00      0.20      0.33         5
#
#     accuracy                           0.69        13
#    macro avg       0.83      0.60      0.57        13
# weighted avg       0.79      0.69      0.62        13
#
#
# Akurasi
#
# 0.6923076923076923
#
# Grafik
#
# 48
# Smartfren
#
# Matrik
#
# [[7 0]
#  [4 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.64      1.00      0.78         7
#            1       1.00      0.33      0.50         6
#
#     accuracy                           0.69        13
#    macro avg       0.82      0.67      0.64        13
# weighted avg       0.80      0.69      0.65        13
#
#
# Akurasi
#
# 0.6923076923076923
#
# Grafik
#
# 49
# Smartfren
#
# Matrik
#
# [[4 2]
#  [6 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.40      0.67      0.50         6
#            1       0.33      0.14      0.20         7
#
#     accuracy                           0.38        13
#    macro avg       0.37      0.40      0.35        13
# weighted avg       0.36      0.38      0.34        13
#
#
# Akurasi
#
# 0.38461538461538464
#
# Grafik
#
# 50
# Smartfren
#
# Matrik
#
# [[4 1]
#  [6 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.40      0.80      0.53         5
#            1       0.50      0.14      0.22         7
#
#     accuracy                           0.42        12
#    macro avg       0.45      0.47      0.38        12
# weighted avg       0.46      0.42      0.35        12
#
#
# Akurasi
#
# 0.4166666666666667
#
# Grafik
#
# 51
# Smartfren
#
# Matrik
#
# [[7 1]
#  [3 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.88      0.78         8
#            1       0.50      0.25      0.33         4
#
#     accuracy                           0.67        12
#    macro avg       0.60      0.56      0.56        12
# weighted avg       0.63      0.67      0.63        12
#
#
# Akurasi
#
# 0.6666666666666666
#
# Grafik
#
# 52
# Smartfren
#
# Matrik
#
# [[8 3]
#  [0 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.73      0.84        11
#            1       0.25      1.00      0.40         1
#
#     accuracy                           0.75        12
#    macro avg       0.62      0.86      0.62        12
# weighted avg       0.94      0.75      0.81        12
#
#
# Akurasi
#
# 0.75
#
# Grafik
#
# 53
# Smartfren
#
# Matrik
#
# [[8 1]
#  [3 0]]
#
# Hasil
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.73      0.89      0.80         9
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.67        12
#    macro avg       0.36      0.44      0.40        12
# weighted avg       0.55      0.67      0.60        12
#
#
# Akurasi
#
# 0.6666666666666666
#
# Grafik
#
# 54
# Smartfren
#
# Matrik
#
# [[7 0]
#  [5 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.58      1.00      0.74         7
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.58        12
#    macro avg       0.29      0.50      0.37        12
# weighted avg       0.34      0.58      0.43        12
#
#
# Akurasi
#
# 0.5833333333333334
#
# Grafik
#
# 55
# Smartfren
#
# Matrik
#
# [[5 2]
#  [5 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.71      0.59         7
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.42        12
#    macro avg       0.25      0.36      0.29        12
# weighted avg       0.29      0.42      0.34        12
#
#
# Akurasi
#
# 0.4166666666666667
#
# Grafik
#
# 56
# Smartfren
#
# Matrik
#
# [[5 4]
#  [1 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.56      0.67         9
#            1       0.33      0.67      0.44         3
#
#     accuracy                           0.58        12
#    macro avg       0.58      0.61      0.56        12
# weighted avg       0.71      0.58      0.61        12
#
#
# Akurasi
#
# 0.5833333333333334
#
# Grafik
#
# 57
# Smartfren
#
# Matrik
#
# [[6 1]
#  [5 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.55      0.86      0.67         7
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.50        12
#    macro avg       0.27      0.43      0.33        12
# weighted avg       0.32      0.50      0.39        12
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 58
# Smartfren
#
# Matrik
#
# [[7 1]
#  [4 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.88      0.74         8
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.58        12
#    macro avg       0.32      0.44      0.37        12
# weighted avg       0.42      0.58      0.49        12
#
#
# Akurasi
#
# 0.5833333333333334
#
# Grafik
#
# 59
# Smartfren
#
# Matrik
#
# [[9 2]
#  [0 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90        11
#            1       0.33      1.00      0.50         1
#
#     accuracy                           0.83        12
#    macro avg       0.67      0.91      0.70        12
# weighted avg       0.94      0.83      0.87        12
#
#
# Akurasi
#
# 0.8333333333333334
#
# Grafik
#
# 60
# Smartfren
#
# Matrik
#
# [[5 2]
#  [3 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.71      0.67         7
#            1       0.33      0.25      0.29         4
#
#     accuracy                           0.55        11
#    macro avg       0.48      0.48      0.48        11
# weighted avg       0.52      0.55      0.53        11
#
#
# Akurasi
#
# 0.5454545454545454
#
# Grafik
#
# 61
# Smartfren
#
# Matrik
#
# [[5 0]
#  [6 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.45      1.00      0.62         5
#            1       0.00      0.00      0.00         6
#
#     accuracy                           0.45        11
#    macro avg       0.23      0.50      0.31        11
# weighted avg       0.21      0.45      0.28        11
#
#
# Akurasi
#
# 0.45454545454545453
#
# Grafik
#
# 62
# Smartfren
#
# Matrik
#
# [[7 2]
#  [2 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.78      0.78         9
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.64        11
#    macro avg       0.39      0.39      0.39        11
# weighted avg       0.64      0.64      0.64        11
#
#
# Akurasi
#
# 0.6363636363636364
#
# Grafik
#
# 63
# Smartfren
#
# Matrik
#
# [[5 5]
#  [1 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.50      0.62        10
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.45        11
#    macro avg       0.42      0.25      0.31        11
# weighted avg       0.76      0.45      0.57        11
#
#
# Akurasi
#
# 0.45454545454545453
#
# Grafik
#
# 64
# Smartfren
#
# Matrik
#
# [[6 0]
#  [5 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.55      1.00      0.71         6
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.55        11
#    macro avg       0.27      0.50      0.35        11
# weighted avg       0.30      0.55      0.39        11
#
#
# Akurasi
#
# 0.5454545454545454
#
# Grafik
#
# 65
# Smartfren
#
# Matrik
#
# [[5 0]
#  [6 0]]
#
# Hasil
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.45      1.00      0.62         5
#            1       0.00      0.00      0.00         6
#
#     accuracy                           0.45        11
#    macro avg       0.23      0.50      0.31        11
# weighted avg       0.21      0.45      0.28        11
#
#
# Akurasi
#
# 0.45454545454545453
#
# Grafik
#
# 66
# Smartfren
#
# Matrik
#
# [[6 2]
#  [2 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75         8
#            1       0.33      0.33      0.33         3
#
#     accuracy                           0.64        11
#    macro avg       0.54      0.54      0.54        11
# weighted avg       0.64      0.64      0.64        11
#
#
# Akurasi
#
# 0.6363636363636364
#
# Grafik
#
# 67
# Smartfren
#
# Matrik
#
# [[7 2]
#  [1 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.78      0.82         9
#            1       0.33      0.50      0.40         2
#
#     accuracy                           0.73        11
#    macro avg       0.60      0.64      0.61        11
# weighted avg       0.78      0.73      0.75        11
#
#
# Akurasi
#
# 0.7272727272727273
#
# Grafik
#
# 68
# Smartfren
#
# Matrik
#
# [[6 2]
#  [3 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.75      0.71         8
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.55        11
#    macro avg       0.33      0.38      0.35        11
# weighted avg       0.48      0.55      0.51        11
#
#
# Akurasi
#
# 0.5454545454545454
#
# Grafik
#
# 69
# Smartfren
#
# Matrik
#
# [[5 2]
#  [4 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.71      0.63         7
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.45        11
#    macro avg       0.28      0.36      0.31        11
# weighted avg       0.35      0.45      0.40        11
#
#
# Akurasi
#
# 0.45454545454545453
#
# Grafik
#
# 70
# Smartfren
#
# Matrik
#
# [[6 0]
#  [4 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.60      1.00      0.75         6
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.60        10
#    macro avg       0.30      0.50      0.37        10
# weighted avg       0.36      0.60      0.45        10
#
#
# Akurasi
#
# 0.6
#
# Grafik
#
# 71
# Smartfren
#
# Matrik
#
# [[7 2]
#  [1 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.78      0.82         9
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.70        10
#    macro avg       0.44      0.39      0.41        10
# weighted avg       0.79      0.70      0.74        10
#
#
# Akurasi
#
# 0.7
#
# Grafik
#
# 72
# Smartfren
#
# Matrik
#
# [[5 3]
#  [2 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.62      0.67         8
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.50        10
#    macro avg       0.36      0.31      0.33        10
# weighted avg       0.57      0.50      0.53        10
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 73
# Smartfren
#
# Matrik
#
# [[6 1]
#  [2 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.86      0.80         7
#            1       0.50      0.33      0.40         3
#
#     accuracy                           0.70        10
#    macro avg       0.62      0.60      0.60        10
# weighted avg       0.68      0.70      0.68        10
#
#
# Akurasi
#
# 0.7
#
# Grafik
#
# 74
# Smartfren
#
# Matrik
#
# [[4 3]
#  [3 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.57      0.57         7
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.40        10
#    macro avg       0.29      0.29      0.29        10
# weighted avg       0.40      0.40      0.40        10
#
#
# Akurasi
#
# 0.4
#
# Grafik
#
# 75
# Smartfren
#
# Matrik
#
# [[6 1]
#  [2 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.86      0.80         7
#            1       0.50      0.33      0.40         3
#
#     accuracy                           0.70        10
#    macro avg       0.62      0.60      0.60        10
# weighted avg       0.68      0.70      0.68        10
#
#
# Akurasi
#
# 0.7
#
# Grafik
#
# 76
# Smartfren
#
# Matrik
#
# [[8 0]
#  [2 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89         8
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.80        10
#    macro avg       0.40      0.50      0.44        10
# weighted avg       0.64      0.80      0.71        10
#
#
# Akurasi
#
# 0.8
#
# Grafik
#
# 77
# Smartfren
#
# Matrik
#
# [[7 0]
#  [2 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.78      1.00      0.88         7
#            1       1.00      0.33      0.50         3
#
#     accuracy                           0.80        10
#    macro avg       0.89      0.67      0.69        10
# weighted avg       0.84      0.80      0.76        10
#
#
# Akurasi
#
# 0.8
#
# Grafik
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 78
# Smartfren
#
# Matrik
#
# [[8 0]
#  [2 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89         8
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.80        10
#    macro avg       0.40      0.50      0.44        10
# weighted avg       0.64      0.80      0.71        10
#
#
# Akurasi
#
# 0.8
#
# Grafik
#
# 79
# Smartfren
#
# Matrik
#
# [[7 1]
#  [2 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.88      0.82         8
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.70        10
#    macro avg       0.39      0.44      0.41        10
# weighted avg       0.62      0.70      0.66        10
#
#
# Akurasi
#
# 0.7
#
# Grafik
#
# 80
# Smartfren
#
# Matrik
#
# [[6 1]
#  [2 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.86      0.80         7
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.67         9
#    macro avg       0.38      0.43      0.40         9
# weighted avg       0.58      0.67      0.62         9
#
#
# Akurasi
#
# 0.6666666666666666
#
# Grafik
#
# 81
# Smartfren
#
# Matrik
#
# [[7 0]
#  [2 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.78      1.00      0.88         7
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.78         9
#    macro avg       0.39      0.50      0.44         9
# weighted avg       0.60      0.78      0.68         9
#
#
# Akurasi
#
# 0.7777777777777778
#
# Grafik
#
# 82
# Smartfren
#
# Matrik
#
# [[4 1]
#  [3 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.80      0.67         5
#            1       0.50      0.25      0.33         4
#
#     accuracy                           0.56         9
#    macro avg       0.54      0.53      0.50         9
# weighted avg       0.54      0.56      0.52         9
#
#
# Akurasi
#
# 0.5555555555555556
#
# Grafik
#
# 83
# Smartfren
#
# Matrik
#
# [[4 3]
#  [2 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.57      0.62         7
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.44         9
#    macro avg       0.33      0.29      0.31         9
# weighted avg       0.52      0.44      0.48         9
#
#
# Akurasi
#
# 0.4444444444444444
#
# Grafik
#
# 84
# Smartfren
#
# Matrik
#
# [[5 1]
#  [3 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.83      0.71         6
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.56         9
#    macro avg       0.31      0.42      0.36         9
# weighted avg       0.42      0.56      0.48         9
#
#
# Akurasi
#
# 0.5555555555555556
#
# Grafik
#
# 85
# Smartfren
#
# Matrik
#
# [[3 1]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.75      0.60         4
#            1       0.67      0.40      0.50         5
#
#     accuracy                           0.56         9
#    macro avg       0.58      0.57      0.55         9
# weighted avg       0.59      0.56      0.54         9
#
#
# Akurasi
#
# 0.5555555555555556
#
# Grafik
#
# 86
# Smartfren
#
# Matrik
#
# [[3 1]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.43      0.75      0.55         4
#            1       0.50      0.20      0.29         5
#
#     accuracy                           0.44         9
#    macro avg       0.46      0.47      0.42         9
# weighted avg       0.47      0.44      0.40         9
#
#
# Akurasi
#
# 0.4444444444444444
#
# Grafik
#
# 87
# Smartfren
#
# Matrik
#
# [[4 1]
#  [4 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.80      0.62         5
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.44         9
#    macro avg       0.25      0.40      0.31         9
# weighted avg       0.28      0.44      0.34         9
#
#
# Akurasi
#
# 0.4444444444444444
#
# Grafik
#
# 88
# Smartfren
#
# Matrik
#
# [[6 1]
#  [1 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86         7
#            1       0.50      0.50      0.50         2
#
#     accuracy                           0.78         9
#    macro avg       0.68      0.68      0.68         9
# weighted avg       0.78      0.78      0.78         9
#
#
# Akurasi
#
# 0.7777777777777778
#
# Grafik
#
# 89
# Smartfren
#
# Matrik
#
# [[4 1]
#  [3 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.80      0.67         5
#            1       0.50      0.25      0.33         4
#
#     accuracy                           0.56         9
#    macro avg       0.54      0.53      0.50         9
# weighted avg       0.54      0.56      0.52         9
#
#
# Akurasi
#
# 0.5555555555555556
#
# Grafik
#
# 90
# Smartfren
#
# Matrik
#
# [[4 2]
#  [2 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67         6
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.50         8
#    macro avg       0.33      0.33      0.33         8
# weighted avg       0.50      0.50      0.50         8
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 91
# Smartfren
#
# Matrik
#
# [[6 2]
#  [0 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.75      0.86         8
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.75         8
#    macro avg       0.50      0.38      0.43         8
# weighted avg       1.00      0.75      0.86         8
#
#
# Akurasi
#
# 0.75
#
# Grafik
#
# 92
# Smartfren
#
# Matrik
#
# [[7 0]
#  [0 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         7
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         8
#    macro avg       1.00      1.00      1.00         8
# weighted avg       1.00      1.00      1.00         8
#
#
# Akurasi
#
# 1.0
#
# Grafik
#
# 93
# Smartfren
#
# Matrik
#
# [[6 0]
#  [2 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86         6
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.75         8
#    macro avg       0.38      0.50      0.43         8
# weighted avg       0.56      0.75      0.64         8
#
#
# Akurasi
#
# 0.75
#
# Grafik
#
# 94
# Smartfren
#
# Matrik
#
# [[5 1]
#  [1 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83         6
#            1       0.50      0.50      0.50         2
#
#     accuracy                           0.75         8
#    macro avg       0.67      0.67      0.67         8
# weighted avg       0.75      0.75      0.75         8
#
#
# Akurasi
#
# 0.75
#
# Grafik
#
# 95
# Smartfren
#
# Matrik
#
# [[5 0]
#  [3 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.62      1.00      0.77         5
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.62         8
#    macro avg       0.31      0.50      0.38         8
# weighted avg       0.39      0.62      0.48         8
#
#
# Akurasi
#
# 0.625
#
# Grafik
#
# 96
# Smartfren
#
# Matrik
#
# [[4 1]
#  [3 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.80      0.67         5
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.50         8
#    macro avg       0.29      0.40      0.33         8
# weighted avg       0.36      0.50      0.42         8
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 97
# Smartfren
#
# Matrik
#
# [[5 2]
#  [1 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.71      0.77         7
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.62         8
#    macro avg       0.42      0.36      0.38         8
# weighted avg       0.73      0.62      0.67         8
#
#
# Akurasi
#
# 0.625
#
# Grafik
#
# 98
# Smartfren
#
# Matrik
#
# [[5 1]
#  [2 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.83      0.77         6
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.62         8
#    macro avg       0.36      0.42      0.38         8
# weighted avg       0.54      0.62      0.58         8
#
#
# Akurasi
#
# 0.625
#
# Grafik
#
# 99
# Smartfren
#
# Matrik
#
# [[6 0]
#  [2 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86         6
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.75         8
#    macro avg       0.38      0.50      0.43         8
# weighted avg       0.56      0.75      0.64         8
#
#
# Akurasi
#
# 0.75
#
# Grafik
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
x_train, x_test, y_train, y_test = klasifikasiData(data='Smartfren', split_jadi=41)
klasifikasiKNeighbor = KNeighborsClassifier(n_neighbors=5)
klasifikasiKNeighbor.fit(x_train, y_train)
predic_y = klasifikasiKNeighbor.predict(x_test)
  
printHasil(y_test, predic_y, "Smartfren")
import pickle
file = open('KNN_Smartfren.otak', 'wb')

# dump information to that file
pickle.dump(klasifikasiKNeighbor, file)

# close the file
file.close()
# Out:
# Smartfren
#
# Matrik
#
# [[9 1]
#  [1 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90        10
#            1       0.67      0.67      0.67         3
#
#     accuracy                           0.85        13
#    macro avg       0.78      0.78      0.78        13
# weighted avg       0.85      0.85      0.85        13
#
#
# Akurasi
#
# 0.8461538461538461
#
# Grafik

# %% [markdown]
# # **Klasifikasi AdaBoostClassifier**

# %%
# Telkomsel

for totalsplit in range(5,100):

  x_train, x_test, y_train, y_test = klasifikasiData(data='telkom', split_jadi=totalsplit)
  klasifikasiAdaBoost = AdaBoostClassifier(n_estimators=100)
  klasifikasiAdaBoost.fit(x_train, y_train)
  predic_y = klasifikasiAdaBoost.predict(x_test)
  klasifikasiAdaBoost.predict_proba(x_test)
  print(totalsplit)

  printHasil(y_test, predic_y, "Telkomsel")

# %%
x_train, x_test, y_train, y_test = klasifikasiData(data='telkom', split_jadi=95)
klasifikasiAdaBoost = AdaBoostClassifier(n_estimators=100)
klasifikasiAdaBoost.fit(x_train, y_train)
predic_y = klasifikasiAdaBoost.predict(x_test)
klasifikasiAdaBoost.predict_proba(x_test)
  
printHasil(y_test, predic_y, "Telkomsel")
import pickle
file = open('Adaboost_Telkomsel.otak', 'wb')

# dump information to that file
pickle.dump(klasifikasiAdaBoost, file)

# close the file
file.close()

# %%
# Indosat
for totalsplit in range(5,100):

  x_train, x_test, y_train, y_test = klasifikasiData(data='indosat', split_jadi=totalsplit)
  klasifikasiAdaBoost = AdaBoostClassifier(n_estimators=100)
  klasifikasiAdaBoost.fit(x_train, y_train)
  predic_y = klasifikasiAdaBoost.predict(x_test)
  klasifikasiAdaBoost.predict_proba(x_test)
  print(totalsplit)

  printHasil(y_test, predic_y, "Indosat")

# %%
x_train, x_test, y_train, y_test = klasifikasiData(data='indosat', split_jadi=38)
klasifikasiAdaBoost = AdaBoostClassifier(n_estimators=100)
klasifikasiAdaBoost.fit(x_train, y_train)
predic_y = klasifikasiAdaBoost.predict(x_test)
klasifikasiAdaBoost.predict_proba(x_test)
  
printHasil(y_test, predic_y, "Indosat")
import pickle
file = open('Adaboost_Indosat.otak', 'wb')

# dump information to that file
pickle.dump(klasifikasiAdaBoost, file)

# close the file
file.close()
# Out:
# Indosat
#
# Matrik
#
# [[6 1]
#  [2 5]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.86      0.80         7
#            1       0.83      0.71      0.77         7
#
#     accuracy                           0.79        14
#    macro avg       0.79      0.79      0.78        14
# weighted avg       0.79      0.79      0.78        14
#
#
# Akurasi
#
# 0.7857142857142857
#
# Grafik

# %%
# Freen
for totalsplit in range(5,100):

  x_train, x_test, y_train, y_test = klasifikasiData(data='freen', split_jadi=totalsplit)
  klasifikasiAdaBoost = AdaBoostClassifier(n_estimators=100)
  klasifikasiAdaBoost.fit(x_train, y_train)
  predic_y = klasifikasiAdaBoost.predict(x_test)
  klasifikasiAdaBoost.predict_proba(x_test)
  print(totalsplit)

  printHasil(y_test, predic_y, "Freen")

# %%
x_train, x_test, y_train, y_test = klasifikasiData(data='freen', split_jadi=34)
klasifikasiAdaBoost = AdaBoostClassifier(n_estimators=100)
klasifikasiAdaBoost.fit(x_train, y_train)
predic_y = klasifikasiAdaBoost.predict(x_test)
klasifikasiAdaBoost.predict_proba(x_test)
  
printHasil(y_test, predic_y, "Freen")
import pickle
file = open('Adaboost_Freen.otak', 'wb')

# dump information to that file
pickle.dump(klasifikasiAdaBoost, file)

# close the file
file.close()
# Out:
# Freen
#
# Matrik
#
# [[11  1]
#  [ 0  2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.92      0.96        12
#            1       0.67      1.00      0.80         2
#
#     accuracy                           0.93        14
#    macro avg       0.83      0.96      0.88        14
# weighted avg       0.95      0.93      0.93        14
#
#
# Akurasi
#
# 0.9285714285714286
#
# Grafik

# %% [markdown]
# # **Klasifikasi BaggingClassifier**

# %%
# Telkomsel
for totalsplit in range(5,100):
  x_train, x_test, y_train, y_test = klasifikasiData(data='telkom', split_jadi=totalsplit)
  klasifikasiBagging = BaggingClassifier(n_estimators=100)
  klasifikasiBagging.fit(x_train, y_train)
  predic_y = klasifikasiBagging.predict(x_test)
  klasifikasiBagging.predict_proba(x_test)
  print(totalsplit)

  printHasil(y_test, predic_y, "Telkomsel")

# %%
x_train, x_test, y_train, y_test = klasifikasiData(data='telkom', split_jadi=95)
klasifikasiBagging = BaggingClassifier(n_estimators=100)
klasifikasiBagging.fit(x_train, y_train)
predic_y = klasifikasiBagging.predict(x_test)
klasifikasiBagging.predict_proba(x_test)
  
printHasil(y_test, predic_y, "Telkomsel")
import pickle
file = open('Bagging_Telkomsel.otak', 'wb')

# dump information to that file
pickle.dump(klasifikasiBagging, file)

# close the file
file.close()
# Out:
# Telkomsel
#
# Matrik
#
# [[5 1]
#  [0 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.91         6
#            1       0.67      1.00      0.80         2
#
#     accuracy                           0.88         8
#    macro avg       0.83      0.92      0.85         8
# weighted avg       0.92      0.88      0.88         8
#
#
# Akurasi
#
# 0.875
#
# Grafik

# %%
# Indosat
for totalsplit in range(5,100):
  x_train, x_test, y_train, y_test = klasifikasiData(data='indosat', split_jadi=totalsplit)
  klasifikasiBagging = BaggingClassifier(n_estimators=100)
  klasifikasiBagging.fit(x_train, y_train)
  predic_y = klasifikasiBagging.predict(x_test)
  klasifikasiBagging.predict_proba(x_test)
  print(totalsplit)

  printHasil(y_test, predic_y, "Indosat")

# %%
x_train, x_test, y_train, y_test = klasifikasiData(data='indosat', split_jadi=60
                                                   )
klasifikasiBagging = BaggingClassifier(n_estimators=100)
klasifikasiBagging.fit(x_train, y_train)
predic_y = klasifikasiBagging.predict(x_test)
klasifikasiBagging.predict_proba(x_test)
  
printHasil(y_test, predic_y, "Indosat")
import pickle
file = open('Bagging_Indosat.otak', 'wb')

# dump information to that file
pickle.dump(klasifikasiBagging, file)

# close the file
file.close()
# Out:
# Indosat
#
# Matrik
#
# [[7 0]
#  [2 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.78      1.00      0.88         7
#            1       1.00      0.50      0.67         4
#
#     accuracy                           0.82        11
#    macro avg       0.89      0.75      0.77        11
# weighted avg       0.86      0.82      0.80        11
#
#
# Akurasi
#
# 0.8181818181818182
#
# Grafik

# %%
# Smartfren
for totalsplit in range(5,100):
  x_train, x_test, y_train, y_test = klasifikasiData(data='freen', split_jadi=totalsplit)
  klasifikasiBagging = BaggingClassifier(n_estimators=100)
  klasifikasiBagging.fit(x_train, y_train)
  predic_y = klasifikasiBagging.predict(x_test)
  klasifikasiBagging.predict_proba(x_test)
  print(totalsplit)

  printHasil(y_test, predic_y, "Freen")

# %%
x_train, x_test, y_train, y_test = klasifikasiData(data='freen', split_jadi=41)
klasifikasiBagging = BaggingClassifier(n_estimators=100)
klasifikasiBagging.fit(x_train, y_train)
predic_y = klasifikasiBagging.predict(x_test)
klasifikasiBagging.predict_proba(x_test)
  
printHasil(y_test, predic_y, "Freen")
import pickle
file = open('Bagging_Freen.otak', 'wb')

# dump information to that file
pickle.dump(klasifikasiBagging, file)

# close the file
file.close()
# Out:
# Freen
#
# Matrik
#
# [[10  0]
#  [ 1  2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95        10
#            1       1.00      0.67      0.80         3
#
#     accuracy                           0.92        13
#    macro avg       0.95      0.83      0.88        13
# weighted avg       0.93      0.92      0.92        13
#
#
# Akurasi
#
# 0.9230769230769231
#
# Grafik

# %% [markdown]
# # **Klasifikasi RandomForestClassifier**

# %%
# Telkomsel
for totalsplit in range(5,100):
  x_train, x_test, y_train, y_test = klasifikasiData(data='telkom', split_jadi=totalsplit)
  klasifikasiRandomForestClassifier = RandomForestClassifier(n_estimators=100)
  klasifikasiRandomForestClassifier.fit(x_train, y_train)
  predic_y = klasifikasiRandomForestClassifier.predict(x_test)
  klasifikasiRandomForestClassifier.predict_proba(x_test)
  print(totalsplit)


  printHasil(y_test, predic_y, "Telkomsel")

# %%
x_train, x_test, y_train, y_test = klasifikasiData(data='telkom', split_jadi=98)
klasifikasiRandomForestClassifier = RandomForestClassifier(n_estimators=100)
klasifikasiRandomForestClassifier.fit(x_train, y_train)
predic_y = klasifikasiRandomForestClassifier.predict(x_test)
klasifikasiRandomForestClassifier.predict_proba(x_test)
  
printHasil(y_test, predic_y, "Telkomsel")
import pickle
file = open('RandomForest_Telkomsel.otak', 'wb')

# dump information to that file
pickle.dump(klasifikasiRandomForestClassifier, file)

# close the file
file.close()
# Out:
# Telkomsel
#
# Matrik
#
# [[5 1]
#  [0 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.91         6
#            1       0.67      1.00      0.80         2
#
#     accuracy                           0.88         8
#    macro avg       0.83      0.92      0.85         8
# weighted avg       0.92      0.88      0.88         8
#
#
# Akurasi
#
# 0.875
#
# Grafik

# %%
# Indosat
for totalsplit in range(5,100):
  x_train, x_test, y_train, y_test = klasifikasiData(data='indosat', split_jadi=totalsplit)
  klasifikasiRandomForestClassifier = RandomForestClassifier(n_estimators=100)
  klasifikasiRandomForestClassifier.fit(x_train, y_train)
  predic_y = klasifikasiRandomForestClassifier.predict(x_test)
  klasifikasiRandomForestClassifier.predict_proba(x_test)
  print(totalsplit)


  printHasil(y_test, predic_y, "Indosat")
# Out:
# 5
# Indosat
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 6
# Indosat
#
# Matrik
#
# [[7 5]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.58      0.67        12
#            1       0.38      0.60      0.46         5
#
#     accuracy                           0.59        17
#    macro avg       0.58      0.59      0.56        17
# weighted avg       0.66      0.59      0.61        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 7
# Indosat
#
# Matrik
#
# [[6 2]
#  [4 5]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.75      0.67         8
#            1       0.71      0.56      0.63         9
#
#     accuracy                           0.65        17
#    macro avg       0.66      0.65      0.65        17
# weighted avg       0.66      0.65      0.64        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 8
# Indosat
#
# Matrik
#
# [[5 5]
#  [5 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50        10
#            1       0.29      0.29      0.29         7
#
#     accuracy                           0.41        17
#    macro avg       0.39      0.39      0.39        17
# weighted avg       0.41      0.41      0.41        17
#
#
# Akurasi
#
# 0.4117647058823529
#
# Grafik
#
# 9
# Indosat
#
# Matrik
#
# [[7 2]
#  [4 4]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.78      0.70         9
#            1       0.67      0.50      0.57         8
#
#     accuracy                           0.65        17
#    macro avg       0.65      0.64      0.64        17
# weighted avg       0.65      0.65      0.64        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 10
# Indosat
#
# Matrik
#
# [[5 5]
#  [4 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.50      0.53        10
#            1       0.29      0.33      0.31         6
#
#     accuracy                           0.44        16
#    macro avg       0.42      0.42      0.42        16
# weighted avg       0.45      0.44      0.44        16
#
#
# Akurasi
#
# 0.4375
#
# Grafik
#
# 11
# Indosat
#
# Matrik
#
# [[3 4]
#  [4 5]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.43      0.43      0.43         7
#            1       0.56      0.56      0.56         9
#
#     accuracy                           0.50        16
#    macro avg       0.49      0.49      0.49        16
# weighted avg       0.50      0.50      0.50        16
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 12
# Indosat
#
# Matrik
#
# [[7 1]
#  [5 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.58      0.88      0.70         8
#            1       0.75      0.38      0.50         8
#
#     accuracy                           0.62        16
#    macro avg       0.67      0.62      0.60        16
# weighted avg       0.67      0.62      0.60        16
#
#
# Akurasi
#
# 0.625
#
# Grafik
#
# 13
# Indosat
#
# Matrik
#
# [[6 3]
#  [5 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.55      0.67      0.60         9
#            1       0.40      0.29      0.33         7
#
#     accuracy                           0.50        16
#    macro avg       0.47      0.48      0.47        16
# weighted avg       0.48      0.50      0.48        16
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 14
# Indosat
#
# Matrik
#
# [[7 1]
#  [6 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.54      0.88      0.67         8
#            1       0.67      0.25      0.36         8
#
#     accuracy                           0.56        16
#    macro avg       0.60      0.56      0.52        16
# weighted avg       0.60      0.56      0.52        16
#
#
# Akurasi
#
# 0.5625
#
# Grafik
#
# 15
# Indosat
#
# Matrik
#
# [[7 5]
#  [3 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.17      0.25      0.20         4
#
#     accuracy                           0.50        16
#    macro avg       0.43      0.42      0.42        16
# weighted avg       0.57      0.50      0.53        16
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 16
# Indosat
#
# Matrik
#
# [[5 4]
#  [5 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.56      0.53         9
#            1       0.33      0.29      0.31         7
#
#     accuracy                           0.44        16
#    macro avg       0.42      0.42      0.42        16
# weighted avg       0.43      0.44      0.43        16
#
#
# Akurasi
#
# 0.4375
#
# Grafik
#
# 17
# Indosat
#
# Matrik
#
# [[5 2]
#  [7 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.42      0.71      0.53         7
#            1       0.50      0.22      0.31         9
#
#     accuracy                           0.44        16
#    macro avg       0.46      0.47      0.42        16
# weighted avg       0.46      0.44      0.40        16
#
#
# Akurasi
#
# 0.4375
#
# Grafik
#
# 18
# Indosat
#
# Matrik
#
# [[7 3]
#  [3 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.70      0.70        10
#            1       0.50      0.50      0.50         6
#
#     accuracy                           0.62        16
#    macro avg       0.60      0.60      0.60        16
# weighted avg       0.62      0.62      0.62        16
#
#
# Akurasi
#
# 0.625
#
# Grafik
#
# 19
# Indosat
#
# Matrik
#
# [[8 1]
#  [7 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.53      0.89      0.67         9
#            1       0.00      0.00      0.00         7
#
#     accuracy                           0.50        16
#    macro avg       0.27      0.44      0.33        16
# weighted avg       0.30      0.50      0.38        16
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 20
# Indosat
#
# Matrik
#
# [[4 3]
#  [8 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.33      0.57      0.42         7
#            1       0.00      0.00      0.00         8
#
#     accuracy                           0.27        15
#    macro avg       0.17      0.29      0.21        15
# weighted avg       0.16      0.27      0.20        15
#
#
# Akurasi
#
# 0.26666666666666666
#
# Grafik
#
# 21
# Indosat
#
# Matrik
#
# [[8 2]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.80      0.73        10
#            1       0.33      0.20      0.25         5
#
#     accuracy                           0.60        15
#    macro avg       0.50      0.50      0.49        15
# weighted avg       0.56      0.60      0.57        15
#
#
# Akurasi
#
# 0.6
#
# Grafik
#
# 22
# Indosat
#
# Matrik
#
# [[6 5]
#  [4 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.55      0.57        11
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.40        15
#    macro avg       0.30      0.27      0.29        15
# weighted avg       0.44      0.40      0.42        15
#
#
# Akurasi
#
# 0.4
#
# Grafik
#
# 23
# Indosat
#
# Matrik
#
# [[2 7]
#  [6 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.25      0.22      0.24         9
#            1       0.00      0.00      0.00         6
#
#     accuracy                           0.13        15
#    macro avg       0.12      0.11      0.12        15
# weighted avg       0.15      0.13      0.14        15
#
#
# Akurasi
#
# 0.13333333333333333
#
# Grafik
#
# 24
# Indosat
#
# Matrik
#
# [[5 7]
#  [2 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.42      0.53        12
#            1       0.12      0.33      0.18         3
#
#     accuracy                           0.40        15
#    macro avg       0.42      0.38      0.35        15
# weighted avg       0.60      0.40      0.46        15
#
#
# Akurasi
#
# 0.4
#
# Grafik
#
# 25
# Indosat
#
# Matrik
#
# [[6 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.60      0.63        10
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.53        15
#    macro avg       0.50      0.50      0.50        15
# weighted avg       0.56      0.53      0.54        15
#
#
# Akurasi
#
# 0.5333333333333333
#
# Grafik
#
# 26
# Indosat
#
# Matrik
#
# [[3 4]
#  [7 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.30      0.43      0.35         7
#            1       0.20      0.12      0.15         8
#
#     accuracy                           0.27        15
#    macro avg       0.25      0.28      0.25        15
# weighted avg       0.25      0.27      0.25        15
#
#
# Akurasi
#
# 0.26666666666666666
#
# Grafik
#
# 27
# Indosat
#
# Matrik
#
# [[4 2]
#  [8 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.33      0.67      0.44         6
#            1       0.33      0.11      0.17         9
#
#     accuracy                           0.33        15
#    macro avg       0.33      0.39      0.31        15
# weighted avg       0.33      0.33      0.28        15
#
#
# Akurasi
#
# 0.3333333333333333
#
# Grafik
#
# 28
# Indosat
#
# Matrik
#
# [[6 3]
#  [5 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.55      0.67      0.60         9
#            1       0.25      0.17      0.20         6
#
#     accuracy                           0.47        15
#    macro avg       0.40      0.42      0.40        15
# weighted avg       0.43      0.47      0.44        15
#
#
# Akurasi
#
# 0.4666666666666667
#
# Grafik
#
# 29
# Indosat
#
# Matrik
#
# [[7 3]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.70      0.67        10
#            1       0.25      0.20      0.22         5
#
#     accuracy                           0.53        15
#    macro avg       0.44      0.45      0.44        15
# weighted avg       0.51      0.53      0.52        15
#
#
# Akurasi
#
# 0.5333333333333333
#
# Grafik
#
# 30
# Indosat
#
# Matrik
#
# [[5 4]
#  [5 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.56      0.53         9
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.36        14
#    macro avg       0.25      0.28      0.26        14
# weighted avg       0.32      0.36      0.34        14
#
#
# Akurasi
#
# 0.35714285714285715
#
# Grafik
#
# 31
# Indosat
#
# Matrik
#
# [[6 3]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.67      0.71         9
#            1       0.50      0.60      0.55         5
#
#     accuracy                           0.64        14
#    macro avg       0.62      0.63      0.63        14
# weighted avg       0.66      0.64      0.65        14
#
#
# Akurasi
#
# 0.6428571428571429
#
# Grafik
#
# 32
# Indosat
#
# Matrik
#
# [[3 2]
#  [5 4]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.38      0.60      0.46         5
#            1       0.67      0.44      0.53         9
#
#     accuracy                           0.50        14
#    macro avg       0.52      0.52      0.50        14
# weighted avg       0.56      0.50      0.51        14
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 33
# Indosat
#
# Matrik
#
# [[4 2]
#  [7 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.36      0.67      0.47         6
#            1       0.33      0.12      0.18         8
#
#     accuracy                           0.36        14
#    macro avg       0.35      0.40      0.33        14
# weighted avg       0.35      0.36      0.31        14
#
#
# Akurasi
#
# 0.35714285714285715
#
# Grafik
#
# 34
# Indosat
#
# Matrik
#
# [[4 4]
#  [4 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50         8
#            1       0.33      0.33      0.33         6
#
#     accuracy                           0.43        14
#    macro avg       0.42      0.42      0.42        14
# weighted avg       0.43      0.43      0.43        14
#
#
# Akurasi
#
# 0.42857142857142855
#
# Grafik
#
# 35
# Indosat
#
# Matrik
#
# [[6 4]
#  [1 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.60      0.71        10
#            1       0.43      0.75      0.55         4
#
#     accuracy                           0.64        14
#    macro avg       0.64      0.68      0.63        14
# weighted avg       0.73      0.64      0.66        14
#
#
# Akurasi
#
# 0.6428571428571429
#
# Grafik
#
# 36
# Indosat
#
# Matrik
#
# [[5 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.56      0.59         9
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.50        14
#    macro avg       0.48      0.48      0.48        14
# weighted avg       0.52      0.50      0.51        14
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 37
# Indosat
#
# Matrik
#
# [[6 3]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.67      0.63         9
#            1       0.25      0.20      0.22         5
#
#     accuracy                           0.50        14
#    macro avg       0.42      0.43      0.43        14
# weighted avg       0.47      0.50      0.49        14
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 38
# Indosat
#
# Matrik
#
# [[5 2]
#  [4 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.71      0.63         7
#            1       0.60      0.43      0.50         7
#
#     accuracy                           0.57        14
#    macro avg       0.58      0.57      0.56        14
# weighted avg       0.58      0.57      0.56        14
#
#
# Akurasi
#
# 0.5714285714285714
#
# Grafik
#
# 39
# Indosat
#
# Matrik
#
# [[5 3]
#  [4 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.62      0.59         8
#            1       0.40      0.33      0.36         6
#
#     accuracy                           0.50        14
#    macro avg       0.48      0.48      0.48        14
# weighted avg       0.49      0.50      0.49        14
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 40
# Indosat
#
# Matrik
#
# [[7 2]
#  [3 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.78      0.74         9
#            1       0.33      0.25      0.29         4
#
#     accuracy                           0.62        13
#    macro avg       0.52      0.51      0.51        13
# weighted avg       0.59      0.62      0.60        13
#
#
# Akurasi
#
# 0.6153846153846154
#
# Grafik
#
# 41
# Indosat
#
# Matrik
#
# [[7 4]
#  [2 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.64      0.70        11
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.54        13
#    macro avg       0.39      0.32      0.35        13
# weighted avg       0.66      0.54      0.59        13
#
#
# Akurasi
#
# 0.5384615384615384
#
# Grafik
#
# 42
# Indosat
#
# Matrik
#
# [[5 2]
#  [4 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.71      0.63         7
#            1       0.50      0.33      0.40         6
#
#     accuracy                           0.54        13
#    macro avg       0.53      0.52      0.51        13
# weighted avg       0.53      0.54      0.52        13
#
#
# Akurasi
#
# 0.5384615384615384
#
# Grafik
#
# 43
# Indosat
#
# Matrik
#
# [[4 6]
#  [2 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.40      0.50        10
#            1       0.14      0.33      0.20         3
#
#     accuracy                           0.38        13
#    macro avg       0.40      0.37      0.35        13
# weighted avg       0.55      0.38      0.43        13
#
#
# Akurasi
#
# 0.38461538461538464
#
# Grafik
#
# 44
# Indosat
#
# Matrik
#
# [[2 3]
#  [7 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.22      0.40      0.29         5
#            1       0.25      0.12      0.17         8
#
#     accuracy                           0.23        13
#    macro avg       0.24      0.26      0.23        13
# weighted avg       0.24      0.23      0.21        13
#
#
# Akurasi
#
# 0.23076923076923078
#
# Grafik
#
# 45
# Indosat
#
# Matrik
#
# [[6 3]
#  [0 4]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.67      0.80         9
#            1       0.57      1.00      0.73         4
#
#     accuracy                           0.77        13
#    macro avg       0.79      0.83      0.76        13
# weighted avg       0.87      0.77      0.78        13
#
#
# Akurasi
#
# 0.7692307692307693
#
# Grafik
#
# 46
# Indosat
#
# Matrik
#
# [[3 2]
#  [7 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.30      0.60      0.40         5
#            1       0.33      0.12      0.18         8
#
#     accuracy                           0.31        13
#    macro avg       0.32      0.36      0.29        13
# weighted avg       0.32      0.31      0.27        13
#
#
# Akurasi
#
# 0.3076923076923077
#
# Grafik
#
# 47
# Indosat
#
# Matrik
#
# [[4 2]
#  [3 4]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.67      0.62         6
#            1       0.67      0.57      0.62         7
#
#     accuracy                           0.62        13
#    macro avg       0.62      0.62      0.62        13
# weighted avg       0.62      0.62      0.62        13
#
#
# Akurasi
#
# 0.6153846153846154
#
# Grafik
#
# 48
# Indosat
#
# Matrik
#
# [[4 2]
#  [4 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.67      0.57         6
#            1       0.60      0.43      0.50         7
#
#     accuracy                           0.54        13
#    macro avg       0.55      0.55      0.54        13
# weighted avg       0.55      0.54      0.53        13
#
#
# Akurasi
#
# 0.5384615384615384
#
# Grafik
#
# 49
# Indosat
#
# Matrik
#
# [[4 3]
#  [5 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.44      0.57      0.50         7
#            1       0.25      0.17      0.20         6
#
#     accuracy                           0.38        13
#    macro avg       0.35      0.37      0.35        13
# weighted avg       0.35      0.38      0.36        13
#
#
# Akurasi
#
# 0.38461538461538464
#
# Grafik
#
# 50
# Indosat
#
# Matrik
#
# [[5 2]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.71      0.71         7
#            1       0.60      0.60      0.60         5
#
#     accuracy                           0.67        12
#    macro avg       0.66      0.66      0.66        12
# weighted avg       0.67      0.67      0.67        12
#
#
# Akurasi
#
# 0.6666666666666666
#
# Grafik
#
# 51
# Indosat
#
# Matrik
#
# [[1 3]
#  [5 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.17      0.25      0.20         4
#            1       0.50      0.38      0.43         8
#
#     accuracy                           0.33        12
#    macro avg       0.33      0.31      0.31        12
# weighted avg       0.39      0.33      0.35        12
#
#
# Akurasi
#
# 0.3333333333333333
#
# Grafik
#
# 52
# Indosat
#
# Matrik
#
# [[2 6]
#  [2 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.25      0.33         8
#            1       0.25      0.50      0.33         4
#
#     accuracy                           0.33        12
#    macro avg       0.38      0.38      0.33        12
# weighted avg       0.42      0.33      0.33        12
#
#
# Akurasi
#
# 0.3333333333333333
#
# Grafik
#
# 53
# Indosat
#
# Matrik
#
# [[4 3]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.57      0.57         7
#            1       0.40      0.40      0.40         5
#
#     accuracy                           0.50        12
#    macro avg       0.49      0.49      0.49        12
# weighted avg       0.50      0.50      0.50        12
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 54
# Indosat
#
# Matrik
#
# [[7 0]
#  [5 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.58      1.00      0.74         7
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.58        12
#    macro avg       0.29      0.50      0.37        12
# weighted avg       0.34      0.58      0.43        12
#
#
# Akurasi
#
# 0.5833333333333334
#
# Grafik
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 55
# Indosat
#
# Matrik
#
# [[3 3]
#  [5 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.38      0.50      0.43         6
#            1       0.25      0.17      0.20         6
#
#     accuracy                           0.33        12
#    macro avg       0.31      0.33      0.31        12
# weighted avg       0.31      0.33      0.31        12
#
#
# Akurasi
#
# 0.3333333333333333
#
# Grafik
#
# 56
# Indosat
#
# Matrik
#
# [[1 4]
#  [7 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.12      0.20      0.15         5
#            1       0.00      0.00      0.00         7
#
#     accuracy                           0.08        12
#    macro avg       0.06      0.10      0.08        12
# weighted avg       0.05      0.08      0.06        12
#
#
# Akurasi
#
# 0.08333333333333333
#
# Grafik
#
# 57
# Indosat
#
# Matrik
#
# [[6 2]
#  [3 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.75      0.71         8
#            1       0.33      0.25      0.29         4
#
#     accuracy                           0.58        12
#    macro avg       0.50      0.50      0.50        12
# weighted avg       0.56      0.58      0.57        12
#
#
# Akurasi
#
# 0.5833333333333334
#
# Grafik
#
# 58
# Indosat
#
# Matrik
#
# [[4 3]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.57      0.57         7
#            1       0.40      0.40      0.40         5
#
#     accuracy                           0.50        12
#    macro avg       0.49      0.49      0.49        12
# weighted avg       0.50      0.50      0.50        12
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 59
# Indosat
#
# Matrik
#
# [[2 1]
#  [9 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.18      0.67      0.29         3
#            1       0.00      0.00      0.00         9
#
#     accuracy                           0.17        12
#    macro avg       0.09      0.33      0.14        12
# weighted avg       0.05      0.17      0.07        12
#
#
# Akurasi
#
# 0.16666666666666666
#
# Grafik
#
# 60
# Indosat
#
# Matrik
#
# [[6 1]
#  [3 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.86      0.75         7
#            1       0.50      0.25      0.33         4
#
#     accuracy                           0.64        11
#    macro avg       0.58      0.55      0.54        11
# weighted avg       0.61      0.64      0.60        11
#
#
# Akurasi
#
# 0.6363636363636364
#
# Grafik
#
# 61
# Indosat
#
# Matrik
#
# [[6 2]
#  [2 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75         8
#            1       0.33      0.33      0.33         3
#
#     accuracy                           0.64        11
#    macro avg       0.54      0.54      0.54        11
# weighted avg       0.64      0.64      0.64        11
#
#
# Akurasi
#
# 0.6363636363636364
#
# Grafik
#
# 62
# Indosat
#
# Matrik
#
# [[8 2]
#  [1 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84        10
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.73        11
#    macro avg       0.44      0.40      0.42        11
# weighted avg       0.81      0.73      0.77        11
#
#
# Akurasi
#
# 0.7272727272727273
#
# Grafik
#
# 63
# Indosat
#
# Matrik
#
# [[7 2]
#  [2 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.78      0.78         9
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.64        11
#    macro avg       0.39      0.39      0.39        11
# weighted avg       0.64      0.64      0.64        11
#
#
# Akurasi
#
# 0.6363636363636364
#
# Grafik
#
# 64
# Indosat
#
# Matrik
#
# [[3 4]
#  [3 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.43      0.46         7
#            1       0.20      0.25      0.22         4
#
#     accuracy                           0.36        11
#    macro avg       0.35      0.34      0.34        11
# weighted avg       0.39      0.36      0.37        11
#
#
# Akurasi
#
# 0.36363636363636365
#
# Grafik
#
# 65
# Indosat
#
# Matrik
#
# [[5 1]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.83      0.71         6
#            1       0.67      0.40      0.50         5
#
#     accuracy                           0.64        11
#    macro avg       0.65      0.62      0.61        11
# weighted avg       0.64      0.64      0.62        11
#
#
# Akurasi
#
# 0.6363636363636364
#
# Grafik
#
# 66
# Indosat
#
# Matrik
#
# [[4 4]
#  [2 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.50      0.57         8
#            1       0.20      0.33      0.25         3
#
#     accuracy                           0.45        11
#    macro avg       0.43      0.42      0.41        11
# weighted avg       0.54      0.45      0.48        11
#
#
# Akurasi
#
# 0.45454545454545453
#
# Grafik
#
# 67
# Indosat
#
# Matrik
#
# [[4 3]
#  [3 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.57      0.57         7
#            1       0.25      0.25      0.25         4
#
#     accuracy                           0.45        11
#    macro avg       0.41      0.41      0.41        11
# weighted avg       0.45      0.45      0.45        11
#
#
# Akurasi
#
# 0.45454545454545453
#
# Grafik
#
# 68
# Indosat
#
# Matrik
#
# [[5 0]
#  [5 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         5
#            1       1.00      0.17      0.29         6
#
#     accuracy                           0.55        11
#    macro avg       0.75      0.58      0.48        11
# weighted avg       0.77      0.55      0.46        11
#
#
# Akurasi
#
# 0.5454545454545454
#
# Grafik
#
# 69
# Indosat
#
# Matrik
#
# [[6 1]
#  [3 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.86      0.75         7
#            1       0.50      0.25      0.33         4
#
#     accuracy                           0.64        11
#    macro avg       0.58      0.55      0.54        11
# weighted avg       0.61      0.64      0.60        11
#
#
# Akurasi
#
# 0.6363636363636364
#
# Grafik
#
# 70
# Indosat
#
# Matrik
#
# [[5 0]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.62      1.00      0.77         5
#            1       1.00      0.40      0.57         5
#
#     accuracy                           0.70        10
#    macro avg       0.81      0.70      0.67        10
# weighted avg       0.81      0.70      0.67        10
#
#
# Akurasi
#
# 0.7
#
# Grafik
#
# 71
# Indosat
#
# Matrik
#
# [[5 4]
#  [1 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.56      0.67         9
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.50        10
#    macro avg       0.42      0.28      0.33        10
# weighted avg       0.75      0.50      0.60        10
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 72
# Indosat
#
# Matrik
#
# [[3 2]
#  [5 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.38      0.60      0.46         5
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.30        10
#    macro avg       0.19      0.30      0.23        10
# weighted avg       0.19      0.30      0.23        10
#
#
# Akurasi
#
# 0.3
#
# Grafik
#
# 73
# Indosat
#
# Matrik
#
# [[5 2]
#  [1 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.71      0.77         7
#            1       0.50      0.67      0.57         3
#
#     accuracy                           0.70        10
#    macro avg       0.67      0.69      0.67        10
# weighted avg       0.73      0.70      0.71        10
#
#
# Akurasi
#
# 0.7
#
# Grafik
#
# 74
# Indosat
#
# Matrik
#
# [[4 0]
#  [5 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.44      1.00      0.62         4
#            1       1.00      0.17      0.29         6
#
#     accuracy                           0.50        10
#    macro avg       0.72      0.58      0.45        10
# weighted avg       0.78      0.50      0.42        10
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 75
# Indosat
#
# Matrik
#
# [[3 2]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.43      0.60      0.50         5
#            1       0.33      0.20      0.25         5
#
#     accuracy                           0.40        10
#    macro avg       0.38      0.40      0.38        10
# weighted avg       0.38      0.40      0.38        10
#
#
# Akurasi
#
# 0.4
#
# Grafik
#
# 76
# Indosat
#
# Matrik
#
# [[6 1]
#  [2 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.86      0.80         7
#            1       0.50      0.33      0.40         3
#
#     accuracy                           0.70        10
#    macro avg       0.62      0.60      0.60        10
# weighted avg       0.68      0.70      0.68        10
#
#
# Akurasi
#
# 0.7
#
# Grafik
#
# 77
# Indosat
#
# Matrik
#
# [[5 1]
#  [4 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.83      0.67         6
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.50        10
#    macro avg       0.28      0.42      0.33        10
# weighted avg       0.33      0.50      0.40        10
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 78
# Indosat
#
# Matrik
#
# [[7 0]
#  [3 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.82         7
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.70        10
#    macro avg       0.35      0.50      0.41        10
# weighted avg       0.49      0.70      0.58        10
#
#
# Akurasi
#
# 0.7
#
# Grafik
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 79
# Indosat
#
# Matrik
#
# [[5 1]
#  [4 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.83      0.67         6
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.50        10
#    macro avg       0.28      0.42      0.33        10
# weighted avg       0.33      0.50      0.40        10
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 80
# Indosat
#
# Matrik
#
# [[5 0]
#  [4 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.56      1.00      0.71         5
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.56         9
#    macro avg       0.28      0.50      0.36         9
# weighted avg       0.31      0.56      0.40         9
#
#
# Akurasi
#
# 0.5555555555555556
#
# Grafik
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 81
# Indosat
#
# Matrik
#
# [[6 1]
#  [2 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.86      0.80         7
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.67         9
#    macro avg       0.38      0.43      0.40         9
# weighted avg       0.58      0.67      0.62         9
#
#
# Akurasi
#
# 0.6666666666666666
#
# Grafik
#
# 82
# Indosat
#
# Matrik
#
# [[4 2]
#  [3 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.67      0.62         6
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.44         9
#    macro avg       0.29      0.33      0.31         9
# weighted avg       0.38      0.44      0.41         9
#
#
# Akurasi
#
# 0.4444444444444444
#
# Grafik
#
# 83
# Indosat
#
# Matrik
#
# [[4 1]
#  [4 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.80      0.62         5
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.44         9
#    macro avg       0.25      0.40      0.31         9
# weighted avg       0.28      0.44      0.34         9
#
#
# Akurasi
#
# 0.4444444444444444
#
# Grafik
#
# 84
# Indosat
#
# Matrik
#
# [[5 0]
#  [3 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.62      1.00      0.77         5
#            1       1.00      0.25      0.40         4
#
#     accuracy                           0.67         9
#    macro avg       0.81      0.62      0.58         9
# weighted avg       0.79      0.67      0.61         9
#
#
# Akurasi
#
# 0.6666666666666666
#
# Grafik
#
# 85
# Indosat
#
# Matrik
#
# [[5 0]
#  [2 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83         5
#            1       1.00      0.50      0.67         4
#
#     accuracy                           0.78         9
#    macro avg       0.86      0.75      0.75         9
# weighted avg       0.84      0.78      0.76         9
#
#
# Akurasi
#
# 0.7777777777777778
#
# Grafik
#
# 86
# Indosat
#
# Matrik
#
# [[4 2]
#  [3 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.67      0.62         6
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.44         9
#    macro avg       0.29      0.33      0.31         9
# weighted avg       0.38      0.44      0.41         9
#
#
# Akurasi
#
# 0.4444444444444444
#
# Grafik
#
# 87
# Indosat
#
# Matrik
#
# [[3 1]
#  [5 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.38      0.75      0.50         4
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.33         9
#    macro avg       0.19      0.38      0.25         9
# weighted avg       0.17      0.33      0.22         9
#
#
# Akurasi
#
# 0.3333333333333333
#
# Grafik
#
# 88
# Indosat
#
# Matrik
#
# [[3 3]
#  [2 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.50      0.55         6
#            1       0.25      0.33      0.29         3
#
#     accuracy                           0.44         9
#    macro avg       0.42      0.42      0.42         9
# weighted avg       0.48      0.44      0.46         9
#
#
# Akurasi
#
# 0.4444444444444444
#
# Grafik
#
# 89
# Indosat
#
# Matrik
#
# [[3 1]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.43      0.75      0.55         4
#            1       0.50      0.20      0.29         5
#
#     accuracy                           0.44         9
#    macro avg       0.46      0.47      0.42         9
# weighted avg       0.47      0.44      0.40         9
#
#
# Akurasi
#
# 0.4444444444444444
#
# Grafik
#
# 90
# Indosat
#
# Matrik
#
# [[2 1]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.33      0.67      0.44         3
#            1       0.50      0.20      0.29         5
#
#     accuracy                           0.38         8
#    macro avg       0.42      0.43      0.37         8
# weighted avg       0.44      0.38      0.35         8
#
#
# Akurasi
#
# 0.375
#
# Grafik
#
# 91
# Indosat
#
# Matrik
#
# [[3 4]
#  [0 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.43      0.60         7
#            1       0.20      1.00      0.33         1
#
#     accuracy                           0.50         8
#    macro avg       0.60      0.71      0.47         8
# weighted avg       0.90      0.50      0.57         8
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 92
# Indosat
#
# Matrik
#
# [[3 4]
#  [1 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.43      0.55         7
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.38         8
#    macro avg       0.38      0.21      0.27         8
# weighted avg       0.66      0.38      0.48         8
#
#
# Akurasi
#
# 0.375
#
# Grafik
#
# 93
# Indosat
#
# Matrik
#
# [[2 4]
#  [1 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.33      0.44         6
#            1       0.20      0.50      0.29         2
#
#     accuracy                           0.38         8
#    macro avg       0.43      0.42      0.37         8
# weighted avg       0.55      0.38      0.40         8
#
#
# Akurasi
#
# 0.375
#
# Grafik
#
# 94
# Indosat
#
# Matrik
#
# [[1 2]
#  [5 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.17      0.33      0.22         3
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.12         8
#    macro avg       0.08      0.17      0.11         8
# weighted avg       0.06      0.12      0.08         8
#
#
# Akurasi
#
# 0.125
#
# Grafik
#
# 95
# Indosat
#
# Matrik
#
# [[5 0]
#  [3 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.62      1.00      0.77         5
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.62         8
#    macro avg       0.31      0.50      0.38         8
# weighted avg       0.39      0.62      0.48         8
#
#
# Akurasi
#
# 0.625
#
# Grafik
#
# 96
# Indosat
#
# Matrik
#
# [[3 1]
#  [4 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.43      0.75      0.55         4
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.38         8
#    macro avg       0.21      0.38      0.27         8
# weighted avg       0.21      0.38      0.27         8
#
#
# Akurasi
#
# 0.375
#
# Grafik
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 97
# Indosat
#
# Matrik
#
# [[2 3]
#  [2 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.40      0.44         5
#            1       0.25      0.33      0.29         3
#
#     accuracy                           0.38         8
#    macro avg       0.38      0.37      0.37         8
# weighted avg       0.41      0.38      0.38         8
#
#
# Akurasi
#
# 0.375
#
# Grafik
#
# 98
# Indosat
#
# Matrik
#
# [[5 3]
#  [0 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.62      0.77         8
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.62         8
#    macro avg       0.50      0.31      0.38         8
# weighted avg       1.00      0.62      0.77         8
#
#
# Akurasi
#
# 0.625
#
# Grafik
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 99
# Indosat
#
# Matrik
#
# [[5 0]
#  [3 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.62      1.00      0.77         5
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.62         8
#    macro avg       0.31      0.50      0.38         8
# weighted avg       0.39      0.62      0.48         8
#
#
# Akurasi
#
# 0.625
#
# Grafik

# %%
x_train, x_test, y_train, y_test = klasifikasiData(data='indosat', split_jadi=60)
klasifikasiRandomForestClassifier = RandomForestClassifier(n_estimators=100)
klasifikasiRandomForestClassifier.fit(x_train, y_train)
predic_y = klasifikasiRandomForestClassifier.predict(x_test)
klasifikasiRandomForestClassifier.predict_proba(x_test)
  
printHasil(y_test, predic_y, "Indosat")
import pickle
file = open('RandomForest_Indosat.otak', 'wb')

# dump information to that file
pickle.dump(klasifikasiRandomForestClassifier, file)

# close the file
file.close()
# Out:
# Indosat
#
# Matrik
#
# [[6 1]
#  [3 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.86      0.75         7
#            1       0.50      0.25      0.33         4
#
#     accuracy                           0.64        11
#    macro avg       0.58      0.55      0.54        11
# weighted avg       0.61      0.64      0.60        11
#
#
# Akurasi
#
# 0.6363636363636364
#
# Grafik

# %%
# Smartfren
for totalsplit in range(5,100):
  x_train, x_test, y_train, y_test = klasifikasiData(data='freen', split_jadi=totalsplit)
  klasifikasiRandomForestClassifier = RandomForestClassifier(n_estimators=100)
  klasifikasiRandomForestClassifier.fit(x_train, y_train)
  predic_y = klasifikasiRandomForestClassifier.predict(x_test)
  klasifikasiRandomForestClassifier.predict_proba(x_test)
  print(totalsplit)


  printHasil(y_test, predic_y, "Freen")
# Out:
# 5
# Freen
#
# Matrik
#
# [[10  3]
#  [ 3  1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.77      0.77        13
#            1       0.25      0.25      0.25         4
#
#     accuracy                           0.65        17
#    macro avg       0.51      0.51      0.51        17
# weighted avg       0.65      0.65      0.65        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 6
# Freen
#
# Matrik
#
# [[13  2]
#  [ 1  1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.87      0.90        15
#            1       0.33      0.50      0.40         2
#
#     accuracy                           0.82        17
#    macro avg       0.63      0.68      0.65        17
# weighted avg       0.86      0.82      0.84        17
#
#
# Akurasi
#
# 0.8235294117647058
#
# Grafik
#
# 7
# Freen
#
# Matrik
#
# [[7 1]
#  [7 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.88      0.64         8
#            1       0.67      0.22      0.33         9
#
#     accuracy                           0.53        17
#    macro avg       0.58      0.55      0.48        17
# weighted avg       0.59      0.53      0.48        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 8
# Freen
#
# Matrik
#
# [[11  2]
#  [ 3  1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.85      0.81        13
#            1       0.33      0.25      0.29         4
#
#     accuracy                           0.71        17
#    macro avg       0.56      0.55      0.55        17
# weighted avg       0.68      0.71      0.69        17
#
#
# Akurasi
#
# 0.7058823529411765
#
# Grafik
#
# 9
# Freen
#
# Matrik
#
# [[9 3]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.69      0.75      0.72        12
#            1       0.25      0.20      0.22         5
#
#     accuracy                           0.59        17
#    macro avg       0.47      0.47      0.47        17
# weighted avg       0.56      0.59      0.57        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 10
# Freen
#
# Matrik
#
# [[9 1]
#  [6 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.90      0.72        10
#            1       0.00      0.00      0.00         6
#
#     accuracy                           0.56        16
#    macro avg       0.30      0.45      0.36        16
# weighted avg       0.38      0.56      0.45        16
#
#
# Akurasi
#
# 0.5625
#
# Grafik
#
# 11
# Freen
#
# Matrik
#
# [[7 1]
#  [7 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.88      0.64         8
#            1       0.50      0.12      0.20         8
#
#     accuracy                           0.50        16
#    macro avg       0.50      0.50      0.42        16
# weighted avg       0.50      0.50      0.42        16
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 12
# Freen
#
# Matrik
#
# [[8 2]
#  [4 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.80      0.73        10
#            1       0.50      0.33      0.40         6
#
#     accuracy                           0.62        16
#    macro avg       0.58      0.57      0.56        16
# weighted avg       0.60      0.62      0.60        16
#
#
# Akurasi
#
# 0.625
#
# Grafik
#
# 13
# Freen
#
# Matrik
#
# [[10  2]
#  [ 2  2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83        12
#            1       0.50      0.50      0.50         4
#
#     accuracy                           0.75        16
#    macro avg       0.67      0.67      0.67        16
# weighted avg       0.75      0.75      0.75        16
#
#
# Akurasi
#
# 0.75
#
# Grafik
#
# 14
# Freen
#
# Matrik
#
# [[10  1]
#  [ 4  1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.91      0.80        11
#            1       0.50      0.20      0.29         5
#
#     accuracy                           0.69        16
#    macro avg       0.61      0.55      0.54        16
# weighted avg       0.65      0.69      0.64        16
#
#
# Akurasi
#
# 0.6875
#
# Grafik
#
# 15
# Freen
#
# Matrik
#
# [[10  1]
#  [ 4  1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.91      0.80        11
#            1       0.50      0.20      0.29         5
#
#     accuracy                           0.69        16
#    macro avg       0.61      0.55      0.54        16
# weighted avg       0.65      0.69      0.64        16
#
#
# Akurasi
#
# 0.6875
#
# Grafik
#
# 16
# Freen
#
# Matrik
#
# [[9 2]
#  [5 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.82      0.72        11
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.56        16
#    macro avg       0.32      0.41      0.36        16
# weighted avg       0.44      0.56      0.50        16
#
#
# Akurasi
#
# 0.5625
#
# Grafik
#
# 17
# Freen
#
# Matrik
#
# [[9 2]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.69      0.82      0.75        11
#            1       0.33      0.20      0.25         5
#
#     accuracy                           0.62        16
#    macro avg       0.51      0.51      0.50        16
# weighted avg       0.58      0.62      0.59        16
#
#
# Akurasi
#
# 0.625
#
# Grafik
#
# 18
# Freen
#
# Matrik
#
# [[7 0]
#  [8 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.47      1.00      0.64         7
#            1       1.00      0.11      0.20         9
#
#     accuracy                           0.50        16
#    macro avg       0.73      0.56      0.42        16
# weighted avg       0.77      0.50      0.39        16
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 19
# Freen
#
# Matrik
#
# [[9 2]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.69      0.82      0.75        11
#            1       0.33      0.20      0.25         5
#
#     accuracy                           0.62        16
#    macro avg       0.51      0.51      0.50        16
# weighted avg       0.58      0.62      0.59        16
#
#
# Akurasi
#
# 0.625
#
# Grafik
#
# 20
# Freen
#
# Matrik
#
# [[9 1]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.90      0.82        10
#            1       0.67      0.40      0.50         5
#
#     accuracy                           0.73        15
#    macro avg       0.71      0.65      0.66        15
# weighted avg       0.72      0.73      0.71        15
#
#
# Akurasi
#
# 0.7333333333333333
#
# Grafik
#
# 21
# Freen
#
# Matrik
#
# [[8 3]
#  [3 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.73      0.73        11
#            1       0.25      0.25      0.25         4
#
#     accuracy                           0.60        15
#    macro avg       0.49      0.49      0.49        15
# weighted avg       0.60      0.60      0.60        15
#
#
# Akurasi
#
# 0.6
#
# Grafik
#
# 22
# Freen
#
# Matrik
#
# [[10  0]
#  [ 5  0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80        10
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.67        15
#    macro avg       0.33      0.50      0.40        15
# weighted avg       0.44      0.67      0.53        15
#
#
# Akurasi
#
# 0.6666666666666666
#
# Grafik
#
# 23
# Freen
#
# Matrik
#
# [[9 3]
#  [3 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75        12
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.60        15
#    macro avg       0.38      0.38      0.38        15
# weighted avg       0.60      0.60      0.60        15
#
#
# Akurasi
#
# 0.6
#
# Grafik
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 24
# Freen
#
# Matrik
#
# [[10  3]
#  [ 1  1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.77      0.83        13
#            1       0.25      0.50      0.33         2
#
#     accuracy                           0.73        15
#    macro avg       0.58      0.63      0.58        15
# weighted avg       0.82      0.73      0.77        15
#
#
# Akurasi
#
# 0.7333333333333333
#
# Grafik
#
# 25
# Freen
#
# Matrik
#
# [[8 1]
#  [6 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.89      0.70         9
#            1       0.00      0.00      0.00         6
#
#     accuracy                           0.53        15
#    macro avg       0.29      0.44      0.35        15
# weighted avg       0.34      0.53      0.42        15
#
#
# Akurasi
#
# 0.5333333333333333
#
# Grafik
#
# 26
# Freen
#
# Matrik
#
# [[12  1]
#  [ 2  0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.92      0.89        13
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.80        15
#    macro avg       0.43      0.46      0.44        15
# weighted avg       0.74      0.80      0.77        15
#
#
# Akurasi
#
# 0.8
#
# Grafik
#
# 27
# Freen
#
# Matrik
#
# [[8 2]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.80      0.76        10
#            1       0.50      0.40      0.44         5
#
#     accuracy                           0.67        15
#    macro avg       0.61      0.60      0.60        15
# weighted avg       0.65      0.67      0.66        15
#
#
# Akurasi
#
# 0.6666666666666666
#
# Grafik
#
# 28
# Freen
#
# Matrik
#
# [[9 1]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.69      0.90      0.78        10
#            1       0.50      0.20      0.29         5
#
#     accuracy                           0.67        15
#    macro avg       0.60      0.55      0.53        15
# weighted avg       0.63      0.67      0.62        15
#
#
# Akurasi
#
# 0.6666666666666666
#
# Grafik
#
# 29
# Freen
#
# Matrik
#
# [[10  2]
#  [ 2  1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83        12
#            1       0.33      0.33      0.33         3
#
#     accuracy                           0.73        15
#    macro avg       0.58      0.58      0.58        15
# weighted avg       0.73      0.73      0.73        15
#
#
# Akurasi
#
# 0.7333333333333333
#
# Grafik
#
# 30
# Freen
#
# Matrik
#
# [[8 3]
#  [2 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.73      0.76        11
#            1       0.25      0.33      0.29         3
#
#     accuracy                           0.64        14
#    macro avg       0.53      0.53      0.52        14
# weighted avg       0.68      0.64      0.66        14
#
#
# Akurasi
#
# 0.6428571428571429
#
# Grafik
#
# 31
# Freen
#
# Matrik
#
# [[9 1]
#  [4 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.69      0.90      0.78        10
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.64        14
#    macro avg       0.35      0.45      0.39        14
# weighted avg       0.49      0.64      0.56        14
#
#
# Akurasi
#
# 0.6428571428571429
#
# Grafik
#
# 32
# Freen
#
# Matrik
#
# [[8 3]
#  [2 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.73      0.76        11
#            1       0.25      0.33      0.29         3
#
#     accuracy                           0.64        14
#    macro avg       0.53      0.53      0.52        14
# weighted avg       0.68      0.64      0.66        14
#
#
# Akurasi
#
# 0.6428571428571429
#
# Grafik
#
# 33
# Freen
#
# Matrik
#
# [[10  0]
#  [ 3  1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        10
#            1       1.00      0.25      0.40         4
#
#     accuracy                           0.79        14
#    macro avg       0.88      0.62      0.63        14
# weighted avg       0.84      0.79      0.74        14
#
#
# Akurasi
#
# 0.7857142857142857
#
# Grafik
#
# 34
# Freen
#
# Matrik
#
# [[11  1]
#  [ 1  1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92        12
#            1       0.50      0.50      0.50         2
#
#     accuracy                           0.86        14
#    macro avg       0.71      0.71      0.71        14
# weighted avg       0.86      0.86      0.86        14
#
#
# Akurasi
#
# 0.8571428571428571
#
# Grafik
#
# 35
# Freen
#
# Matrik
#
# [[9 1]
#  [4 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.69      0.90      0.78        10
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.64        14
#    macro avg       0.35      0.45      0.39        14
# weighted avg       0.49      0.64      0.56        14
#
#
# Akurasi
#
# 0.6428571428571429
#
# Grafik
#
# 36
# Freen
#
# Matrik
#
# [[10  1]
#  [ 2  1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.91      0.87        11
#            1       0.50      0.33      0.40         3
#
#     accuracy                           0.79        14
#    macro avg       0.67      0.62      0.63        14
# weighted avg       0.76      0.79      0.77        14
#
#
# Akurasi
#
# 0.7857142857142857
#
# Grafik
#
# 37
# Freen
#
# Matrik
#
# [[11  1]
#  [ 1  1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92        12
#            1       0.50      0.50      0.50         2
#
#     accuracy                           0.86        14
#    macro avg       0.71      0.71      0.71        14
# weighted avg       0.86      0.86      0.86        14
#
#
# Akurasi
#
# 0.8571428571428571
#
# Grafik
#
# 38
# Freen
#
# Matrik
#
# [[10  2]
#  [ 2  0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83        12
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.71        14
#    macro avg       0.42      0.42      0.42        14
# weighted avg       0.71      0.71      0.71        14
#
#
# Akurasi
#
# 0.7142857142857143
#
# Grafik
#
# 39
# Freen
#
# Matrik
#
# [[8 2]
#  [3 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.80      0.76        10
#            1       0.33      0.25      0.29         4
#
#     accuracy                           0.64        14
#    macro avg       0.53      0.53      0.52        14
# weighted avg       0.61      0.64      0.63        14
#
#
# Akurasi
#
# 0.6428571428571429
#
# Grafik
#
# 40
# Freen
#
# Matrik
#
# [[8 1]
#  [2 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.89      0.84         9
#            1       0.67      0.50      0.57         4
#
#     accuracy                           0.77        13
#    macro avg       0.73      0.69      0.71        13
# weighted avg       0.76      0.77      0.76        13
#
#
# Akurasi
#
# 0.7692307692307693
#
# Grafik
#
# 41
# Freen
#
# Matrik
#
# [[10  0]
#  [ 1  2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95        10
#            1       1.00      0.67      0.80         3
#
#     accuracy                           0.92        13
#    macro avg       0.95      0.83      0.88        13
# weighted avg       0.93      0.92      0.92        13
#
#
# Akurasi
#
# 0.9230769230769231
#
# Grafik
#
# 42
# Freen
#
# Matrik
#
# [[10  0]
#  [ 2  1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91        10
#            1       1.00      0.33      0.50         3
#
#     accuracy                           0.85        13
#    macro avg       0.92      0.67      0.70        13
# weighted avg       0.87      0.85      0.81        13
#
#
# Akurasi
#
# 0.8461538461538461
#
# Grafik
#
# 43
# Freen
#
# Matrik
#
# [[8 0]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80         8
#            1       1.00      0.20      0.33         5
#
#     accuracy                           0.69        13
#    macro avg       0.83      0.60      0.57        13
# weighted avg       0.79      0.69      0.62        13
#
#
# Akurasi
#
# 0.6923076923076923
#
# Grafik
#
# 44
# Freen
#
# Matrik
#
# [[10  1]
#  [ 1  1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91        11
#            1       0.50      0.50      0.50         2
#
#     accuracy                           0.85        13
#    macro avg       0.70      0.70      0.70        13
# weighted avg       0.85      0.85      0.85        13
#
#
# Akurasi
#
# 0.8461538461538461
#
# Grafik
#
# 45
# Freen
#
# Matrik
#
# [[10  1]
#  [ 1  1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91        11
#            1       0.50      0.50      0.50         2
#
#     accuracy                           0.85        13
#    macro avg       0.70      0.70      0.70        13
# weighted avg       0.85      0.85      0.85        13
#
#
# Akurasi
#
# 0.8461538461538461
#
# Grafik
#
# 46
# Freen
#
# Matrik
#
# [[9 0]
#  [4 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.69      1.00      0.82         9
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.69        13
#    macro avg       0.35      0.50      0.41        13
# weighted avg       0.48      0.69      0.57        13
#
#
# Akurasi
#
# 0.6923076923076923
#
# Grafik
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 47
# Freen
#
# Matrik
#
# [[7 1]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.88      0.74         8
#            1       0.50      0.20      0.29         5
#
#     accuracy                           0.62        13
#    macro avg       0.57      0.54      0.51        13
# weighted avg       0.58      0.62      0.56        13
#
#
# Akurasi
#
# 0.6153846153846154
#
# Grafik
#
# 48
# Freen
#
# Matrik
#
# [[7 0]
#  [4 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.64      1.00      0.78         7
#            1       1.00      0.33      0.50         6
#
#     accuracy                           0.69        13
#    macro avg       0.82      0.67      0.64        13
# weighted avg       0.80      0.69      0.65        13
#
#
# Akurasi
#
# 0.6923076923076923
#
# Grafik
#
# 49
# Freen
#
# Matrik
#
# [[6 0]
#  [6 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         6
#            1       1.00      0.14      0.25         7
#
#     accuracy                           0.54        13
#    macro avg       0.75      0.57      0.46        13
# weighted avg       0.77      0.54      0.44        13
#
#
# Akurasi
#
# 0.5384615384615384
#
# Grafik
#
# 50
# Freen
#
# Matrik
#
# [[5 0]
#  [6 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.45      1.00      0.62         5
#            1       1.00      0.14      0.25         7
#
#     accuracy                           0.50        12
#    macro avg       0.73      0.57      0.44        12
# weighted avg       0.77      0.50      0.41        12
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 51
# Freen
#
# Matrik
#
# [[8 0]
#  [3 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      1.00      0.84         8
#            1       1.00      0.25      0.40         4
#
#     accuracy                           0.75        12
#    macro avg       0.86      0.62      0.62        12
# weighted avg       0.82      0.75      0.69        12
#
#
# Akurasi
#
# 0.75
#
# Grafik
#
# 52
# Freen
#
# Matrik
#
# [[11  0]
#  [ 0  1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00        12
#    macro avg       1.00      1.00      1.00        12
# weighted avg       1.00      1.00      1.00        12
#
#
# Akurasi
#
# 1.0
#
# Grafik
#
# 53
# Freen
#
# Matrik
#
# [[8 1]
#  [2 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.89      0.84         9
#            1       0.50      0.33      0.40         3
#
#     accuracy                           0.75        12
#    macro avg       0.65      0.61      0.62        12
# weighted avg       0.72      0.75      0.73        12
#
#
# Akurasi
#
# 0.75
#
# Grafik
#
# 54
# Freen
#
# Matrik
#
# [[7 0]
#  [5 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.58      1.00      0.74         7
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.58        12
#    macro avg       0.29      0.50      0.37        12
# weighted avg       0.34      0.58      0.43        12
#
#
# Akurasi
#
# 0.5833333333333334
#
# Grafik
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 55
# Freen
#
# Matrik
#
# [[7 0]
#  [5 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.58      1.00      0.74         7
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.58        12
#    macro avg       0.29      0.50      0.37        12
# weighted avg       0.34      0.58      0.43        12
#
#
# Akurasi
#
# 0.5833333333333334
#
# Grafik
#
# 56
# Freen
#
# Matrik
#
# [[6 3]
#  [1 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.67      0.75         9
#            1       0.40      0.67      0.50         3
#
#     accuracy                           0.67        12
#    macro avg       0.63      0.67      0.62        12
# weighted avg       0.74      0.67      0.69        12
#
#
# Akurasi
#
# 0.6666666666666666
#
# Grafik
#
# 57
# Freen
#
# Matrik
#
# [[7 0]
#  [5 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.58      1.00      0.74         7
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.58        12
#    macro avg       0.29      0.50      0.37        12
# weighted avg       0.34      0.58      0.43        12
#
#
# Akurasi
#
# 0.5833333333333334
#
# Grafik
#
# 58
# Freen
#
# Matrik
#
# [[7 1]
#  [4 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.88      0.74         8
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.58        12
#    macro avg       0.32      0.44      0.37        12
# weighted avg       0.42      0.58      0.49        12
#
#
# Akurasi
#
# 0.5833333333333334
#
# Grafik
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 59
# Freen
#
# Matrik
#
# [[10  1]
#  [ 1  0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91        11
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.83        12
#    macro avg       0.45      0.45      0.45        12
# weighted avg       0.83      0.83      0.83        12
#
#
# Akurasi
#
# 0.8333333333333334
#
# Grafik
#
# 60
# Freen
#
# Matrik
#
# [[7 0]
#  [3 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.82         7
#            1       1.00      0.25      0.40         4
#
#     accuracy                           0.73        11
#    macro avg       0.85      0.62      0.61        11
# weighted avg       0.81      0.73      0.67        11
#
#
# Akurasi
#
# 0.7272727272727273
#
# Grafik
#
# 61
# Freen
#
# Matrik
#
# [[5 0]
#  [6 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.45      1.00      0.62         5
#            1       0.00      0.00      0.00         6
#
#     accuracy                           0.45        11
#    macro avg       0.23      0.50      0.31        11
# weighted avg       0.21      0.45      0.28        11
#
#
# Akurasi
#
# 0.45454545454545453
#
# Grafik
#
# 62
# Freen
#
# Matrik
#
# [[9 0]
#  [2 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90         9
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.82        11
#    macro avg       0.41      0.50      0.45        11
# weighted avg       0.67      0.82      0.74        11
#
#
# Akurasi
#
# 0.8181818181818182
#
# Grafik
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 63
# Freen
#
# Matrik
#
# [[8 2]
#  [1 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84        10
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.73        11
#    macro avg       0.44      0.40      0.42        11
# weighted avg       0.81      0.73      0.77        11
#
#
# Akurasi
#
# 0.7272727272727273
#
# Grafik
#
# 64
# Freen
#
# Matrik
#
# [[6 0]
#  [5 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.55      1.00      0.71         6
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.55        11
#    macro avg       0.27      0.50      0.35        11
# weighted avg       0.30      0.55      0.39        11
#
#
# Akurasi
#
# 0.5454545454545454
#
# Grafik
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 65
# Freen
#
# Matrik
#
# [[5 0]
#  [5 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         5
#            1       1.00      0.17      0.29         6
#
#     accuracy                           0.55        11
#    macro avg       0.75      0.58      0.48        11
# weighted avg       0.77      0.55      0.46        11
#
#
# Akurasi
#
# 0.5454545454545454
#
# Grafik
#
# 66
# Freen
#
# Matrik
#
# [[8 0]
#  [3 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      1.00      0.84         8
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.73        11
#    macro avg       0.36      0.50      0.42        11
# weighted avg       0.53      0.73      0.61        11
#
#
# Akurasi
#
# 0.7272727272727273
#
# Grafik
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 67
# Freen
#
# Matrik
#
# [[6 3]
#  [1 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.67      0.75         9
#            1       0.25      0.50      0.33         2
#
#     accuracy                           0.64        11
#    macro avg       0.55      0.58      0.54        11
# weighted avg       0.75      0.64      0.67        11
#
#
# Akurasi
#
# 0.6363636363636364
#
# Grafik
#
# 68
# Freen
#
# Matrik
#
# [[8 0]
#  [3 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      1.00      0.84         8
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.73        11
#    macro avg       0.36      0.50      0.42        11
# weighted avg       0.53      0.73      0.61        11
#
#
# Akurasi
#
# 0.7272727272727273
#
# Grafik
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 69
# Freen
#
# Matrik
#
# [[5 2]
#  [4 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.71      0.63         7
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.45        11
#    macro avg       0.28      0.36      0.31        11
# weighted avg       0.35      0.45      0.40        11
#
#
# Akurasi
#
# 0.45454545454545453
#
# Grafik
#
# 70
# Freen
#
# Matrik
#
# [[6 0]
#  [4 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.60      1.00      0.75         6
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.60        10
#    macro avg       0.30      0.50      0.37        10
# weighted avg       0.36      0.60      0.45        10
#
#
# Akurasi
#
# 0.6
#
# Grafik
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 71
# Freen
#
# Matrik
#
# [[8 1]
#  [0 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94         9
#            1       0.50      1.00      0.67         1
#
#     accuracy                           0.90        10
#    macro avg       0.75      0.94      0.80        10
# weighted avg       0.95      0.90      0.91        10
#
#
# Akurasi
#
# 0.9
#
# Grafik
#
# 72
# Freen
#
# Matrik
#
# [[5 3]
#  [2 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.62      0.67         8
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.50        10
#    macro avg       0.36      0.31      0.33        10
# weighted avg       0.57      0.50      0.53        10
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 73
# Freen
#
# Matrik
#
# [[6 1]
#  [2 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.86      0.80         7
#            1       0.50      0.33      0.40         3
#
#     accuracy                           0.70        10
#    macro avg       0.62      0.60      0.60        10
# weighted avg       0.68      0.70      0.68        10
#
#
# Akurasi
#
# 0.7
#
# Grafik
#
# 74
# Freen
#
# Matrik
#
# [[6 1]
#  [3 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.86      0.75         7
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.60        10
#    macro avg       0.33      0.43      0.38        10
# weighted avg       0.47      0.60      0.53        10
#
#
# Akurasi
#
# 0.6
#
# Grafik
#
# 75
# Freen
#
# Matrik
#
# [[6 1]
#  [2 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.86      0.80         7
#            1       0.50      0.33      0.40         3
#
#     accuracy                           0.70        10
#    macro avg       0.62      0.60      0.60        10
# weighted avg       0.68      0.70      0.68        10
#
#
# Akurasi
#
# 0.7
#
# Grafik
#
# 76
# Freen
#
# Matrik
#
# [[8 0]
#  [2 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89         8
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.80        10
#    macro avg       0.40      0.50      0.44        10
# weighted avg       0.64      0.80      0.71        10
#
#
# Akurasi
#
# 0.8
#
# Grafik
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 77
# Freen
#
# Matrik
#
# [[7 0]
#  [3 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.82         7
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.70        10
#    macro avg       0.35      0.50      0.41        10
# weighted avg       0.49      0.70      0.58        10
#
#
# Akurasi
#
# 0.7
#
# Grafik
#
# 78
# Freen
#
# Matrik
#
# [[8 0]
#  [2 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89         8
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.80        10
#    macro avg       0.40      0.50      0.44        10
# weighted avg       0.64      0.80      0.71        10
#
#
# Akurasi
#
# 0.8
#
# Grafik
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 79
# Freen
#
# Matrik
#
# [[8 0]
#  [2 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89         8
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.80        10
#    macro avg       0.40      0.50      0.44        10
# weighted avg       0.64      0.80      0.71        10
#
#
# Akurasi
#
# 0.8
#
# Grafik
#
# 80
# Freen
#
# Matrik
#
# [[7 0]
#  [2 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.78      1.00      0.88         7
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.78         9
#    macro avg       0.39      0.50      0.44         9
# weighted avg       0.60      0.78      0.68         9
#
#
# Akurasi
#
# 0.7777777777777778
#
# Grafik
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 81
# Freen
#
# Matrik
#
# [[6 1]
#  [2 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.86      0.80         7
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.67         9
#    macro avg       0.38      0.43      0.40         9
# weighted avg       0.58      0.67      0.62         9
#
#
# Akurasi
#
# 0.6666666666666666
#
# Grafik
#
# 82
# Freen
#
# Matrik
#
# [[4 1]
#  [2 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.80      0.73         5
#            1       0.67      0.50      0.57         4
#
#     accuracy                           0.67         9
#    macro avg       0.67      0.65      0.65         9
# weighted avg       0.67      0.67      0.66         9
#
#
# Akurasi
#
# 0.6666666666666666
#
# Grafik
#
# 83
# Freen
#
# Matrik
#
# [[5 2]
#  [2 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.71      0.71         7
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.56         9
#    macro avg       0.36      0.36      0.36         9
# weighted avg       0.56      0.56      0.56         9
#
#
# Akurasi
#
# 0.5555555555555556
#
# Grafik
#
# 84
# Freen
#
# Matrik
#
# [[4 2]
#  [3 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.67      0.62         6
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.44         9
#    macro avg       0.29      0.33      0.31         9
# weighted avg       0.38      0.44      0.41         9
#
#
# Akurasi
#
# 0.4444444444444444
#
# Grafik
#
# 85
# Freen
#
# Matrik
#
# [[4 0]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         4
#            1       1.00      0.20      0.33         5
#
#     accuracy                           0.56         9
#    macro avg       0.75      0.60      0.50         9
# weighted avg       0.78      0.56      0.48         9
#
#
# Akurasi
#
# 0.5555555555555556
#
# Grafik
#
# 86
# Freen
#
# Matrik
#
# [[4 0]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         4
#            1       1.00      0.20      0.33         5
#
#     accuracy                           0.56         9
#    macro avg       0.75      0.60      0.50         9
# weighted avg       0.78      0.56      0.48         9
#
#
# Akurasi
#
# 0.5555555555555556
#
# Grafik
#
# 87
# Freen
#
# Matrik
#
# [[5 0]
#  [3 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.62      1.00      0.77         5
#            1       1.00      0.25      0.40         4
#
#     accuracy                           0.67         9
#    macro avg       0.81      0.62      0.58         9
# weighted avg       0.79      0.67      0.61         9
#
#
# Akurasi
#
# 0.6666666666666666
#
# Grafik
#
# 88
# Freen
#
# Matrik
#
# [[6 1]
#  [2 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.86      0.80         7
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.67         9
#    macro avg       0.38      0.43      0.40         9
# weighted avg       0.58      0.67      0.62         9
#
#
# Akurasi
#
# 0.6666666666666666
#
# Grafik
#
# 89
# Freen
#
# Matrik
#
# [[3 2]
#  [3 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.60      0.55         5
#            1       0.33      0.25      0.29         4
#
#     accuracy                           0.44         9
#    macro avg       0.42      0.42      0.42         9
# weighted avg       0.43      0.44      0.43         9
#
#
# Akurasi
#
# 0.4444444444444444
#
# Grafik
#
# 90
# Freen
#
# Matrik
#
# [[5 1]
#  [2 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.83      0.77         6
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.62         8
#    macro avg       0.36      0.42      0.38         8
# weighted avg       0.54      0.62      0.58         8
#
#
# Akurasi
#
# 0.625
#
# Grafik
#
# 91
# Freen
#
# Matrik
#
# [[7 1]
#  [0 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.88      0.93         8
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.88         8
#    macro avg       0.50      0.44      0.47         8
# weighted avg       1.00      0.88      0.93         8
#
#
# Akurasi
#
# 0.875
#
# Grafik
#
# 92
# Freen
#
# Matrik
#
# [[7 0]
#  [0 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         7
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         8
#    macro avg       1.00      1.00      1.00         8
# weighted avg       1.00      1.00      1.00         8
#
#
# Akurasi
#
# 1.0
#
# Grafik
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 93
# Freen
#
# Matrik
#
# [[6 0]
#  [2 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86         6
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.75         8
#    macro avg       0.38      0.50      0.43         8
# weighted avg       0.56      0.75      0.64         8
#
#
# Akurasi
#
# 0.75
#
# Grafik
#
# 94
# Freen
#
# Matrik
#
# [[5 1]
#  [1 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83         6
#            1       0.50      0.50      0.50         2
#
#     accuracy                           0.75         8
#    macro avg       0.67      0.67      0.67         8
# weighted avg       0.75      0.75      0.75         8
#
#
# Akurasi
#
# 0.75
#
# Grafik
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 95
# Freen
#
# Matrik
#
# [[5 0]
#  [3 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.62      1.00      0.77         5
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.62         8
#    macro avg       0.31      0.50      0.38         8
# weighted avg       0.39      0.62      0.48         8
#
#
# Akurasi
#
# 0.625
#
# Grafik
#
# 96
# Freen
#
# Matrik
#
# [[4 1]
#  [3 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.80      0.67         5
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.50         8
#    macro avg       0.29      0.40      0.33         8
# weighted avg       0.36      0.50      0.42         8
#
#
# Akurasi
#
# 0.5
#
# Grafik
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 97
# Freen
#
# Matrik
#
# [[4 3]
#  [1 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.57      0.67         7
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.50         8
#    macro avg       0.40      0.29      0.33         8
# weighted avg       0.70      0.50      0.58         8
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 98
# Freen
#
# Matrik
#
# [[5 1]
#  [2 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.83      0.77         6
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.62         8
#    macro avg       0.36      0.42      0.38         8
# weighted avg       0.54      0.62      0.58         8
#
#
# Akurasi
#
# 0.625
#
# Grafik
#
# 99
# Freen
#
# Matrik
#
# [[6 0]
#  [2 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86         6
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.75         8
#    macro avg       0.38      0.50      0.43         8
# weighted avg       0.56      0.75      0.64         8
#
#
# Akurasi
#
# 0.75
#
# Grafik
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
x_train, x_test, y_train, y_test = klasifikasiData(data='freen', split_jadi=92)
klasifikasiRandomForestClassifier = RandomForestClassifier(n_estimators=100)
klasifikasiRandomForestClassifier.fit(x_train, y_train)
predic_y = klasifikasiRandomForestClassifier.predict(x_test)
klasifikasiRandomForestClassifier.predict_proba(x_test)
  
printHasil(y_test, predic_y, "Freen")
import pickle
file = open('RandomForest_Freen.otak', 'wb')

# dump information to that file
pickle.dump(klasifikasiRandomForestClassifier, file)

# close the file
file.close()
# Out:
# Freen
#
# Matrik
#
# [[7 0]
#  [0 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         7
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         8
#    macro avg       1.00      1.00      1.00         8
# weighted avg       1.00      1.00      1.00         8
#
#
# Akurasi
#
# 1.0
#
# Grafik

# %% [markdown]
# # **Klasifikasi ExtraTreesClassifier**

# %%
# Telkomsel
for totalsplit in range(5,100):
  x_train, x_test, y_train, y_test = klasifikasiData(data='telkom', split_jadi=totalsplit)
  klasifikasiExtraTrees = ExtraTreesClassifier(n_estimators=100)
  klasifikasiExtraTrees.fit(x_train, y_train)
  predic_y = klasifikasiExtraTrees.predict(x_test)
  klasifikasiExtraTrees.predict_proba(x_test)
  print(totalsplit)

  printHasil(y_test, predic_y, "Telkomsel")

# %%
x_train, x_test, y_train, y_test = klasifikasiData(data='telkom', split_jadi=91)
regresiExtraTrees = ExtraTreesRegressor(n_estimators=100)
regresiExtraTrees.fit(x_train, y_train)
predic_y = klasifikasiExtraTrees.predict(x_test)
klasifikasiExtraTrees.predict_proba(x_test)
  
printHasil(y_test, predic_y, "Telkomsel")
import pickle
file = open('ExtraTrees_Telkomsel.otak', 'wb')

# dump information to that file
pickle.dump(klasifikasiExtraTrees, file)

# close the file
file.close()
# Out:
# Telkomsel
#
# Matrik
#
# [[3 1]
#  [1 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75         4
#            1       0.75      0.75      0.75         4
#
#     accuracy                           0.75         8
#    macro avg       0.75      0.75      0.75         8
# weighted avg       0.75      0.75      0.75         8
#
#
# Akurasi
#
# 0.75
#
# Grafik

# %%
# Indosat
for totalsplit in range(5,100):
  x_train, x_test, y_train, y_test = klasifikasiData(data='indosat', split_jadi=totalsplit)
  klasifikasiExtraTrees = ExtraTreesClassifier(n_estimators=100)
  klasifikasiExtraTrees.fit(x_train, y_train)
  predic_y = klasifikasiExtraTrees.predict(x_test)
  klasifikasiExtraTrees.predict_proba(x_test)
  print(totalsplit)

  printHasil(y_test, predic_y, "Indosat")

# %%
x_train, x_test, y_train, y_test = klasifikasiData(data='indosat', split_jadi=19)
klasifikasiExtraTrees = ExtraTreesClassifier(n_estimators=100)
klasifikasiExtraTrees.fit(x_train, y_train)
predic_y = klasifikasiExtraTrees.predict(x_test)
klasifikasiExtraTrees.predict_proba(x_test)
  
printHasil(y_test, predic_y, "Indosat")
import pickle
file = open('ExtraTrees_Indosat.otak', 'wb')

# dump information to that file
pickle.dump(klasifikasiExtraTrees, file)

# close the file
file.close()

# %%
# Smartfren
for totalsplit in range(5,100):
  x_train, x_test, y_train, y_test = klasifikasiData(data='freen', split_jadi=totalsplit)
  klasifikasiExtraTrees = ExtraTreesClassifier(n_estimators=100)
  klasifikasiExtraTrees.fit(x_train, y_train)
  predic_y = klasifikasiExtraTrees.predict(x_test)
  klasifikasiExtraTrees.predict_proba(x_test)
  print(totalsplit)

  printHasil(y_test, predic_y, "Freen")

# %%
x_train, x_test, y_train, y_test = klasifikasiData(data='freen', split_jadi=41)
klasifikasiExtraTrees = ExtraTreesClassifier(n_estimators=100)
klasifikasiExtraTrees.fit(x_train, y_train)
predic_y = klasifikasiExtraTrees.predict(x_test)
klasifikasiExtraTrees.predict_proba(x_test)
  
printHasil(y_test, predic_y, "Freen")
import pickle
file = open('ExtraTrees_Freen.otak', 'wb')

# dump information to that file
pickle.dump(klasifikasiExtraTrees, file)

# close the file
file.close()
# Out:
# Freen
#
# Matrik
#
# [[9 1]
#  [1 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90        10
#            1       0.67      0.67      0.67         3
#
#     accuracy                           0.85        13
#    macro avg       0.78      0.78      0.78        13
# weighted avg       0.85      0.85      0.85        13
#
#
# Akurasi
#
# 0.8461538461538461
#
# Grafik

# %% [markdown]
# # **Klasifikasi GradientBoostingClassifier**

# %%
# Telkomsel
for totalsplit in range(5,100):
  klasifikasiData(data='telkom', split_jadi=totalsplit)
  klasifikasiGradientBoosting = GradientBoostingClassifier(n_estimators=100)
  klasifikasiGradientBoosting.fit(x_train, y_train)
  predic_y = klasifikasiGradientBoosting.predict(x_test)
  klasifikasiGradientBoosting.predict_proba(x_test)

  print(totalsplit)

  printHasil(y_test, predic_y, "Telkomsel")

# %%
x_train, x_test, y_train, y_test = klasifikasiData(data='telkom', split_jadi=63)
klasifikasiData(data='telkom', split_jadi=totalsplit)
klasifikasiGradientBoosting = GradientBoostingClassifier(n_estimators=100)
klasifikasiGradientBoosting.fit(x_train, y_train)
predic_y = klasifikasiGradientBoosting.predict(x_test)
klasifikasiGradientBoosting.predict_proba(x_test)

printHasil(y_test, predic_y, "Telkomsel")
import pickle
file = open('GradientBoosting_Telkomsel.otak', 'wb')

# dump information to that file
pickle.dump(klasifikasiGradientBoosting, file)

# close the file
file.close()
# Out:
# Telkomsel
#
# Matrik
#
# [[5 1]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.83      0.71         6
#            1       0.67      0.40      0.50         5
#
#     accuracy                           0.64        11
#    macro avg       0.65      0.62      0.61        11
# weighted avg       0.64      0.64      0.62        11
#
#
# Akurasi
#
# 0.6363636363636364
#
# Grafik

# %%
# Indosat
for totalsplit in range(5,100):
  klasifikasiData(data='indosat', split_jadi=totalsplit)
  klasifikasiGradientBoosting = GradientBoostingClassifier(n_estimators=100)
  klasifikasiGradientBoosting.fit(x_train, y_train)
  predic_y = klasifikasiGradientBoosting.predict(x_test)
  klasifikasiGradientBoosting.predict_proba(x_test)

  print(totalsplit)

  printHasil(y_test, predic_y, "ISAT")

# %%
x_train, x_test, y_train, y_test = klasifikasiData(data='indosat', split_jadi=6)
klasifikasiData(data='indosat', split_jadi=totalsplit)
klasifikasiGradientBoosting = GradientBoostingClassifier(n_estimators=100)
klasifikasiGradientBoosting.fit(x_train, y_train)
predic_y = klasifikasiGradientBoosting.predict(x_test)
klasifikasiGradientBoosting.predict_proba(x_test)

printHasil(y_test, predic_y, "Indosat")
import pickle
file = open('GradientBoosting_Indosat.otak', 'wb')

# dump information to that file
pickle.dump(klasifikasiGradientBoosting, file)

# close the file
file.close()
# Out:
# Indosat
#
# Matrik
#
# [[8 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.65        17
#    macro avg       0.61      0.63      0.61        17
# weighted avg       0.69      0.65      0.66        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik

# %%
# Smartfren
for totalsplit in range(5,100):
  klasifikasiData(data='fren', split_jadi=totalsplit)
  klasifikasiGradientBoosting = GradientBoostingClassifier(n_estimators=100)
  klasifikasiGradientBoosting.fit(x_train, y_train)
  predic_y = klasifikasiGradientBoosting.predict(x_test)
  klasifikasiGradientBoosting.predict_proba(x_test)

  print(totalsplit)

  printHasil(y_test, predic_y, "FREN")
# Out:
# 5
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 6
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 7
# FREN
#
# Matrik
#
# [[8 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.65        17
#    macro avg       0.61      0.63      0.61        17
# weighted avg       0.69      0.65      0.66        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 8
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 9
# FREN
#
# Matrik
#
# [[8 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.65        17
#    macro avg       0.61      0.63      0.61        17
# weighted avg       0.69      0.65      0.66        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 10
# FREN
#
# Matrik
#
# [[7 5]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.58      0.67        12
#            1       0.38      0.60      0.46         5
#
#     accuracy                           0.59        17
#    macro avg       0.58      0.59      0.56        17
# weighted avg       0.66      0.59      0.61        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 11
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 12
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 13
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 14
# FREN
#
# Matrik
#
# [[8 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.65        17
#    macro avg       0.61      0.63      0.61        17
# weighted avg       0.69      0.65      0.66        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 15
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 16
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 17
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 18
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 19
# FREN
#
# Matrik
#
# [[8 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.65        17
#    macro avg       0.61      0.63      0.61        17
# weighted avg       0.69      0.65      0.66        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 20
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 21
# FREN
#
# Matrik
#
# [[8 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.65        17
#    macro avg       0.61      0.63      0.61        17
# weighted avg       0.69      0.65      0.66        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 22
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 23
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 24
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 25
# FREN
#
# Matrik
#
# [[7 5]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.58      0.67        12
#            1       0.38      0.60      0.46         5
#
#     accuracy                           0.59        17
#    macro avg       0.58      0.59      0.56        17
# weighted avg       0.66      0.59      0.61        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 26
# FREN
#
# Matrik
#
# [[8 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.65        17
#    macro avg       0.61      0.63      0.61        17
# weighted avg       0.69      0.65      0.66        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 27
# FREN
#
# Matrik
#
# [[8 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.65        17
#    macro avg       0.61      0.63      0.61        17
# weighted avg       0.69      0.65      0.66        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 28
# FREN
#
# Matrik
#
# [[8 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.65        17
#    macro avg       0.61      0.63      0.61        17
# weighted avg       0.69      0.65      0.66        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 29
# FREN
#
# Matrik
#
# [[8 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.65        17
#    macro avg       0.61      0.63      0.61        17
# weighted avg       0.69      0.65      0.66        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 30
# FREN
#
# Matrik
#
# [[8 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.65        17
#    macro avg       0.61      0.63      0.61        17
# weighted avg       0.69      0.65      0.66        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 31
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 32
# FREN
#
# Matrik
#
# [[8 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.65        17
#    macro avg       0.61      0.63      0.61        17
# weighted avg       0.69      0.65      0.66        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 33
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 34
# FREN
#
# Matrik
#
# [[8 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.65        17
#    macro avg       0.61      0.63      0.61        17
# weighted avg       0.69      0.65      0.66        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 35
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 36
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 37
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 38
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 39
# FREN
#
# Matrik
#
# [[7 5]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.58      0.67        12
#            1       0.38      0.60      0.46         5
#
#     accuracy                           0.59        17
#    macro avg       0.58      0.59      0.56        17
# weighted avg       0.66      0.59      0.61        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 40
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 41
# FREN
#
# Matrik
#
# [[8 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.65        17
#    macro avg       0.61      0.63      0.61        17
# weighted avg       0.69      0.65      0.66        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 42
# FREN
#
# Matrik
#
# [[7 5]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.58      0.67        12
#            1       0.38      0.60      0.46         5
#
#     accuracy                           0.59        17
#    macro avg       0.58      0.59      0.56        17
# weighted avg       0.66      0.59      0.61        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 43
# FREN
#
# Matrik
#
# [[8 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.65        17
#    macro avg       0.61      0.63      0.61        17
# weighted avg       0.69      0.65      0.66        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 44
# FREN
#
# Matrik
#
# [[7 5]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.58      0.67        12
#            1       0.38      0.60      0.46         5
#
#     accuracy                           0.59        17
#    macro avg       0.58      0.59      0.56        17
# weighted avg       0.66      0.59      0.61        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 45
# FREN
#
# Matrik
#
# [[8 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.65        17
#    macro avg       0.61      0.63      0.61        17
# weighted avg       0.69      0.65      0.66        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 46
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 47
# FREN
#
# Matrik
#
# [[8 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.65        17
#    macro avg       0.61      0.63      0.61        17
# weighted avg       0.69      0.65      0.66        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 48
# FREN
#
# Matrik
#
# [[8 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.65        17
#    macro avg       0.61      0.63      0.61        17
# weighted avg       0.69      0.65      0.66        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 49
# FREN
#
# Matrik
#
# [[8 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.65        17
#    macro avg       0.61      0.63      0.61        17
# weighted avg       0.69      0.65      0.66        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 50
# FREN
#
# Matrik
#
# [[8 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.65        17
#    macro avg       0.61      0.63      0.61        17
# weighted avg       0.69      0.65      0.66        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 51
# FREN
#
# Matrik
#
# [[8 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.65        17
#    macro avg       0.61      0.63      0.61        17
# weighted avg       0.69      0.65      0.66        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 52
# FREN
#
# Matrik
#
# [[8 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.65        17
#    macro avg       0.61      0.63      0.61        17
# weighted avg       0.69      0.65      0.66        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 53
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 54
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 55
# FREN
#
# Matrik
#
# [[8 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.65        17
#    macro avg       0.61      0.63      0.61        17
# weighted avg       0.69      0.65      0.66        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 56
# FREN
#
# Matrik
#
# [[8 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.65        17
#    macro avg       0.61      0.63      0.61        17
# weighted avg       0.69      0.65      0.66        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 57
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 58
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 59
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 60
# FREN
#
# Matrik
#
# [[8 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.65        17
#    macro avg       0.61      0.63      0.61        17
# weighted avg       0.69      0.65      0.66        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 61
# FREN
#
# Matrik
#
# [[8 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.65        17
#    macro avg       0.61      0.63      0.61        17
# weighted avg       0.69      0.65      0.66        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 62
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 63
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 64
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 65
# FREN
#
# Matrik
#
# [[8 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.65        17
#    macro avg       0.61      0.63      0.61        17
# weighted avg       0.69      0.65      0.66        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 66
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 67
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 68
# FREN
#
# Matrik
#
# [[8 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.65        17
#    macro avg       0.61      0.63      0.61        17
# weighted avg       0.69      0.65      0.66        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 69
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 70
# FREN
#
# Matrik
#
# [[8 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.65        17
#    macro avg       0.61      0.63      0.61        17
# weighted avg       0.69      0.65      0.66        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 71
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 72
# FREN
#
# Matrik
#
# [[8 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.65        17
#    macro avg       0.61      0.63      0.61        17
# weighted avg       0.69      0.65      0.66        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 73
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 74
# FREN
#
# Matrik
#
# [[8 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.65        17
#    macro avg       0.61      0.63      0.61        17
# weighted avg       0.69      0.65      0.66        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 75
# FREN
#
# Matrik
#
# [[8 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.65        17
#    macro avg       0.61      0.63      0.61        17
# weighted avg       0.69      0.65      0.66        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 76
# FREN
#
# Matrik
#
# [[7 5]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.58      0.67        12
#            1       0.38      0.60      0.46         5
#
#     accuracy                           0.59        17
#    macro avg       0.58      0.59      0.56        17
# weighted avg       0.66      0.59      0.61        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 77
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 78
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 79
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 80
# FREN
#
# Matrik
#
# [[8 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.65        17
#    macro avg       0.61      0.63      0.61        17
# weighted avg       0.69      0.65      0.66        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 81
# FREN
#
# Matrik
#
# [[8 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.65        17
#    macro avg       0.61      0.63      0.61        17
# weighted avg       0.69      0.65      0.66        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 82
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 83
# FREN
#
# Matrik
#
# [[8 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.65        17
#    macro avg       0.61      0.63      0.61        17
# weighted avg       0.69      0.65      0.66        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 84
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 85
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 86
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 87
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 88
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 89
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 90
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 91
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 92
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 93
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 94
# FREN
#
# Matrik
#
# [[8 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.65        17
#    macro avg       0.61      0.63      0.61        17
# weighted avg       0.69      0.65      0.66        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 95
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 96
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 97
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 98
# FREN
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 99
# FREN
#
# Matrik
#
# [[8 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.65        17
#    macro avg       0.61      0.63      0.61        17
# weighted avg       0.69      0.65      0.66        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik

# %%
x_train, x_test, y_train, y_test = klasifikasiData(data='fren', split_jadi=6)
klasifikasiData(data='fren', split_jadi=totalsplit)
klasifikasiGradientBoosting = GradientBoostingClassifier(n_estimators=100)
klasifikasiGradientBoosting.fit(x_train, y_train)
predic_y = klasifikasiGradientBoosting.predict(x_test)
klasifikasiGradientBoosting.predict_proba(x_test)

printHasil(y_test, predic_y, "Smartfren")
import pickle
file = open('GradientBoosting_Smartfren.otak', 'wb')

# dump information to that file
pickle.dump(klasifikasiGradientBoosting, file)

# close the file
file.close()
# Out:
# Smartfren
#
# Matrik
#
# [[12  3]
#  [ 1  1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.80      0.86        15
#            1       0.25      0.50      0.33         2
#
#     accuracy                           0.76        17
#    macro avg       0.59      0.65      0.60        17
# weighted avg       0.84      0.76      0.80        17
#
#
# Akurasi
#
# 0.7647058823529411
#
# Grafik

# %% [markdown]
# # Klasifikasi StackingClassifier

# %%
# Telkomsel
for totalsplit in range(5,100):
  klasifikasiData(data='telkom', split_jadi=totalsplit)
# Ngestack randomforesclassifier
  estimators = [('rf', RandomForestClassifier(n_estimators=100, random_state=42))]
  klasifikasiStackingClassifier = StackingClassifier(estimators=estimators)
  klasifikasiStackingClassifier.fit(x_train, y_train)
  predic_y = klasifikasiStackingClassifier.predict(x_test)
  klasifikasiStackingClassifier.predict_proba(x_test)
  
  print(totalsplit)
  printHasil(y_test, predic_y, "TLKM")

# %%
# indosat
for totalsplit in range(5,100):
  klasifikasiData(data='indosat', split_jadi=totalsplit)
# Ngestack randomforesclassifier
  estimators = [('rf', RandomForestClassifier(n_estimators=100, random_state=42))]
  klasifikasiStackingClassifier = StackingClassifier(estimators=estimators)
  klasifikasiStackingClassifier.fit(x_train, y_train)
  predic_y = klasifikasiStackingClassifier.predict(x_test)
  klasifikasiStackingClassifier.predict_proba(x_test)
  
  print(totalsplit)
  printHasil(y_test, predic_y, "indosat")

# %%
# smartfren
for totalsplit in range(5,100):
  klasifikasiData(data='fren', split_jadi=totalsplit)
# Ngestack randomforesclassifier
  estimators = [('rf', RandomForestClassifier(n_estimators=100, random_state=42))]
  klasifikasiStackingClassifier = StackingClassifier(estimators=estimators)
  klasifikasiStackingClassifier.fit(x_train, y_train)
  predic_y = klasifikasiStackingClassifier.predict(x_test)
  klasifikasiStackingClassifier.predict_proba(x_test)
  
  print(totalsplit)
  printHasil(y_test, predic_y, "fren")

# %% [markdown]
# # Klasifikasi GaussianProcessClassifier

# %%
# Telkomsel
for totalsplit in range(5,100):
  klasifikasiData(data='telkom', split_jadi=totalsplit)
  klasifikasiGaussianProcessClassifier=GradientBoostingClassifier(n_estimators=100)
  klasifikasiGaussianProcessClassifier.fit(x_train, y_train)
  predic_y = klasifikasiGaussianProcessClassifier.predict(x_test)
  klasifikasiGaussianProcessClassifier.predict_proba(x_test)
  print(totalsplit)
  printHasil(y_test, predic_y, "TLKM")
# Out:
# 5
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 6
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 7
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 8
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 9
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 10
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 11
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 12
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 13
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 14
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 15
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 16
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 17
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 18
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 19
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 20
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 21
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 22
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 23
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 24
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 25
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 26
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 27
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 28
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 29
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 30
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 31
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 32
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 33
# TLKM
#
# Matrik
#
# [[8 4]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67        12
#            1       0.20      0.20      0.20         5
#
#     accuracy                           0.53        17
#    macro avg       0.43      0.43      0.43        17
# weighted avg       0.53      0.53      0.53        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 34
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 35
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 36
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 37
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 38
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 39
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 40
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 41
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 42
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 43
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 44
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 45
# TLKM
#
# Matrik
#
# [[9 3]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75        12
#            1       0.40      0.40      0.40         5
#
#     accuracy                           0.65        17
#    macro avg       0.57      0.57      0.58        17
# weighted avg       0.65      0.65      0.65        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 46
# TLKM
#
# Matrik
#
# [[8 4]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67        12
#            1       0.20      0.20      0.20         5
#
#     accuracy                           0.53        17
#    macro avg       0.43      0.43      0.43        17
# weighted avg       0.53      0.53      0.53        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 47
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 48
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 49
# TLKM
#
# Matrik
#
# [[9 3]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75        12
#            1       0.40      0.40      0.40         5
#
#     accuracy                           0.65        17
#    macro avg       0.57      0.57      0.58        17
# weighted avg       0.65      0.65      0.65        17
#
#
# Akurasi
#
# 0.6470588235294118
#
# Grafik
#
# 50
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 51
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 52
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 53
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 54
# TLKM
#
# Matrik
#
# [[9 3]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.69      0.75      0.72        12
#            1       0.25      0.20      0.22         5
#
#     accuracy                           0.59        17
#    macro avg       0.47      0.47      0.47        17
# weighted avg       0.56      0.59      0.57        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 55
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 56
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 57
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 58
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 59
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 60
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 61
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 62
# TLKM
#
# Matrik
#
# [[8 4]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67        12
#            1       0.20      0.20      0.20         5
#
#     accuracy                           0.53        17
#    macro avg       0.43      0.43      0.43        17
# weighted avg       0.53      0.53      0.53        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 63
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 64
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 65
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 66
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 67
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 68
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 69
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 70
# TLKM
#
# Matrik
#
# [[8 4]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67        12
#            1       0.20      0.20      0.20         5
#
#     accuracy                           0.53        17
#    macro avg       0.43      0.43      0.43        17
# weighted avg       0.53      0.53      0.53        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 71
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 72
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 73
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 74
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 75
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 76
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 77
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 78
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 79
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 80
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 81
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 82
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 83
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 84
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 85
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 86
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 87
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 88
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 89
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 90
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 91
# TLKM
#
# Matrik
#
# [[9 3]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.69      0.75      0.72        12
#            1       0.25      0.20      0.22         5
#
#     accuracy                           0.59        17
#    macro avg       0.47      0.47      0.47        17
# weighted avg       0.56      0.59      0.57        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 92
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 93
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 94
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 95
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 96
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik
#
# 97
# TLKM
#
# Matrik
#
# [[8 4]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67        12
#            1       0.20      0.20      0.20         5
#
#     accuracy                           0.53        17
#    macro avg       0.43      0.43      0.43        17
# weighted avg       0.53      0.53      0.53        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 98
# TLKM
#
# Matrik
#
# [[7 5]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64        12
#            1       0.29      0.40      0.33         5
#
#     accuracy                           0.53        17
#    macro avg       0.49      0.49      0.48        17
# weighted avg       0.58      0.53      0.55        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 99
# TLKM
#
# Matrik
#
# [[8 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.59        17
#    macro avg       0.53      0.53      0.53        17
# weighted avg       0.61      0.59      0.60        17
#
#
# Akurasi
#
# 0.5882352941176471
#
# Grafik

# %%
x_train, x_test, y_train, y_test = klasifikasiData(data='telkom', split_jadi=52)
klasifikasiData(data='telkom', split_jadi=totalsplit)
klasifikasiGaussianProcessClassifier = GradientBoostingClassifier(n_estimators=100)
klasifikasiGaussianProcessClassifier.fit(x_train, y_train)
predic_y = klasifikasiGaussianProcessClassifier.predict(x_test)
klasifikasiGaussianProcessClassifier.predict_proba(x_test)

printHasil(y_test, predic_y, "TLKM") 

import pickle
file = open('Gausian_Telkom.otak', 'wb')

# dump information to that file
pickle.dump(klasifikasiGaussianProcessClassifier, file)

# close the file
file.close()
# Out:
# TLKM
#
# Matrik
#
# [[3 4]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.43      0.50         7
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.50        12
#    macro avg       0.51      0.51      0.50        12
# weighted avg       0.53      0.50      0.50        12
#
#
# Akurasi
#
# 0.5
#
# Grafik

# %%
# Indosat
for totalsplit in range(5,100):
  klasifikasiData(data='indosat', split_jadi=totalsplit)
  klasifikasiGaussianProcessClassifier = GradientBoostingClassifier(n_estimators=100)
  klasifikasiGaussianProcessClassifier.fit(x_train, y_train)
  predic_y = klasifikasiGaussianProcessClassifier.predict(x_test)
  klasifikasiGaussianProcessClassifier.predict_proba(x_test)
  print(totalsplit)
  printHasil(y_test, predic_y, "Indosat")

# %%
x_train, x_test, y_train, y_test = klasifikasiData(data='indosat', split_jadi=72)
klasifikasiData(data='indosat', split_jadi=totalsplit)
klasifikasiGaussianProcessClassifier = GradientBoostingClassifier(n_estimators=100)
klasifikasiGaussianProcessClassifier.fit(x_train, y_train)
predic_y = klasifikasiGaussianProcessClassifier.predict(x_test)
klasifikasiGaussianProcessClassifier.predict_proba(x_test)

printHasil(y_test, predic_y, "indosat") 

import pickle
file = open('Gausian_Indosat.otak', 'wb')

# dump information to that file
pickle.dump(klasifikasiGaussianProcessClassifier, file)

# close the file
file.close()
# Out:
# indosat
#
# Matrik
#
# [[4 1]
#  [5 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.44      0.80      0.57         5
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.40        10
#    macro avg       0.22      0.40      0.29        10
# weighted avg       0.22      0.40      0.29        10
#
#
# Akurasi
#
# 0.4
#
# Grafik

# %%
# Smartfren
for totalsplit in range(5,100):
  klasifikasiData(data='fren', split_jadi=totalsplit)
  klasifikasiGaussianProcessClassifier = GradientBoostingClassifier(n_estimators=100)
  klasifikasiGaussianProcessClassifier.fit(x_train, y_train)
  predic_y = klasifikasiGaussianProcessClassifier.predict(x_test)
  klasifikasiGaussianProcessClassifier.predict_proba(x_test)
  print(totalsplit)
  printHasil(y_test, predic_y, "smartfren")

# %%
x_train, x_test, y_train, y_test = klasifikasiData(data='fren', split_jadi=35)
klasifikasiData(data='fren', split_jadi=totalsplit)
klasifikasiGaussianProcessClassifier = GradientBoostingClassifier(n_estimators=100)
klasifikasiGaussianProcessClassifier.fit(x_train, y_train)
predic_y = klasifikasiGaussianProcessClassifier.predict(x_test)
klasifikasiGaussianProcessClassifier.predict_proba(x_test)

printHasil(y_test, predic_y, "smartfren") 

import pickle
file = open('Gausian_fren.otak', 'wb')

# dump information to that file
pickle.dump(klasifikasiGaussianProcessClassifier, file)

# close the file
file.close()
# Out:
# smartfren
#
# Matrik
#
# [[6 4]
#  [4 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.60      0.60        10
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.43        14
#    macro avg       0.30      0.30      0.30        14
# weighted avg       0.43      0.43      0.43        14
#
#
# Akurasi
#
# 0.42857142857142855
#
# Grafik

# %% [markdown]
# #**Klasifikasi DummyClassifier**

# %%
# Telkomsel

for totalsplit in range(5,100):
    x_train, x_test, y_train, y_test = klasifikasiData(data='telkomsel', split_jadi=totalsplit)
    klasifikasiDummy = DummyClassifier(strategy="most_frequent")
    klasifikasiDummy.fit(x_train, y_train)
    DummyClassifier(strategy='most_frequent')
    predic_y = klasifikasiDummy.predict(x_test)
    klasifikasiDummy.predict_proba(x_test)

    print(totalsplit)
    
    printHasil(y_test, predic_y, "Telkomsel")

# %%
x_train, x_test, y_train, y_test = klasifikasiData(data='telkomsel', split_jadi=83)
klasifikasiKNeighbor = KNeighborsClassifier(n_neighbors=5)
klasifikasiKNeighbor.fit(x_train, y_train)
predic_y = klasifikasiKNeighbor.predict(x_test)
  
printHasil(y_test, predic_y, "Telkomsel")
import pickle
file = open('Dummy_Telkomsel.otak', 'wb')

# dump information to that file
pickle.dump(klasifikasiKNeighbor, file)

# close the file
file.close()
# Out:
# Telkomsel
#
# Matrik
#
# [[4 3]
#  [2 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.57      0.62         7
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.44         9
#    macro avg       0.33      0.29      0.31         9
# weighted avg       0.52      0.44      0.48         9
#
#
# Akurasi
#
# 0.4444444444444444
#
# Grafik

# %% [markdown]
# # Klasifikasi SGDClassifier

# %%
# Telkomsel
for totalsplit in range(5,100):
  x_train, x_test, y_train, y_test = klasifikasiData(data='telkom', split_jadi=totalsplit)
  klasifikasiSGDClassifier = make_pipeline(StandardScaler(),SGDClassifier(max_iter=100, tol=1e-3))
  klasifikasiSGDClassifier.fit(x_train, y_train)
  predic_y = klasifikasiSGDClassifier.predict(x_test)
  print(totalsplit)

  printHasil(y_test, predic_y, "Telkomsel")

# %%
x_train, x_test, y_train, y_test = klasifikasiData(data='telkom', split_jadi=96)
klasifikasiSGDClassifier = make_pipeline(StandardScaler(),SGDClassifier(max_iter=100, tol=1e-3))
klasifikasiSGDClassifier.fit(x_train, y_train)
predic_y = klasifikasiSGDClassifier.predict(x_test)
  
printHasil(y_test, predic_y, "Telkomsel")
import pickle
file = open('SGD_Telkomsel.otak', 'wb')

# dump information to that file
pickle.dump(klasifikasiSGDClassifier, file)

# close the file
file.close()
# Out:
# Telkomsel
#
# Matrik
#
# [[3 3]
#  [0 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67         6
#            1       0.40      1.00      0.57         2
#
#     accuracy                           0.62         8
#    macro avg       0.70      0.75      0.62         8
# weighted avg       0.85      0.62      0.64         8
#
#
# Akurasi
#
# 0.625
#
# Grafik

# %%
# Indosat
for totalsplit in range(5,100):
  x_train, x_test, y_train, y_test = klasifikasiData(data='indosat', split_jadi=totalsplit)
  klasifikasiSGDClassifier = make_pipeline(StandardScaler(),SGDClassifier(max_iter=100, tol=1e-3))
  klasifikasiSGDClassifier.fit(x_train, y_train)
  predic_y = klasifikasiSGDClassifier.predict(x_test)
  print(totalsplit)

  printHasil(y_test, predic_y, "Indosat")
# Out:
# 5
# Indosat
#
# Matrik
#
# [[ 2 10]
#  [ 0  5]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.17      0.29        12
#            1       0.33      1.00      0.50         5
#
#     accuracy                           0.41        17
#    macro avg       0.67      0.58      0.39        17
# weighted avg       0.80      0.41      0.35        17
#
#
# Akurasi
#
# 0.4117647058823529
#
# Grafik
#
# 6
# Indosat
#
# Matrik
#
# [[5 7]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.42      0.48        12
#            1       0.12      0.20      0.15         5
#
#     accuracy                           0.35        17
#    macro avg       0.34      0.31      0.32        17
# weighted avg       0.43      0.35      0.38        17
#
#
# Akurasi
#
# 0.35294117647058826
#
# Grafik
#
# 7
# Indosat
#
# Matrik
#
# [[2 6]
#  [2 7]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.25      0.33         8
#            1       0.54      0.78      0.64         9
#
#     accuracy                           0.53        17
#    macro avg       0.52      0.51      0.48        17
# weighted avg       0.52      0.53      0.49        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 8
# Indosat
#
# Matrik
#
# [[4 6]
#  [2 5]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.40      0.50        10
#            1       0.45      0.71      0.56         7
#
#     accuracy                           0.53        17
#    macro avg       0.56      0.56      0.53        17
# weighted avg       0.58      0.53      0.52        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 9
# Indosat
#
# Matrik
#
# [[7 2]
#  [6 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.54      0.78      0.64         9
#            1       0.50      0.25      0.33         8
#
#     accuracy                           0.53        17
#    macro avg       0.52      0.51      0.48        17
# weighted avg       0.52      0.53      0.49        17
#
#
# Akurasi
#
# 0.5294117647058824
#
# Grafik
#
# 10
# Indosat
#
# Matrik
#
# [[5 5]
#  [3 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.50      0.56        10
#            1       0.38      0.50      0.43         6
#
#     accuracy                           0.50        16
#    macro avg       0.50      0.50      0.49        16
# weighted avg       0.53      0.50      0.51        16
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 11
# Indosat
#
# Matrik
#
# [[3 4]
#  [3 6]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.43      0.46         7
#            1       0.60      0.67      0.63         9
#
#     accuracy                           0.56        16
#    macro avg       0.55      0.55      0.55        16
# weighted avg       0.56      0.56      0.56        16
#
#
# Akurasi
#
# 0.5625
#
# Grafik
#
# 12
# Indosat
#
# Matrik
#
# [[5 3]
#  [4 4]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.62      0.59         8
#            1       0.57      0.50      0.53         8
#
#     accuracy                           0.56        16
#    macro avg       0.56      0.56      0.56        16
# weighted avg       0.56      0.56      0.56        16
#
#
# Akurasi
#
# 0.5625
#
# Grafik
#
# 13
# Indosat
#
# Matrik
#
# [[5 4]
#  [5 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.56      0.53         9
#            1       0.33      0.29      0.31         7
#
#     accuracy                           0.44        16
#    macro avg       0.42      0.42      0.42        16
# weighted avg       0.43      0.44      0.43        16
#
#
# Akurasi
#
# 0.4375
#
# Grafik
#
# 14
# Indosat
#
# Matrik
#
# [[4 4]
#  [7 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.36      0.50      0.42         8
#            1       0.20      0.12      0.15         8
#
#     accuracy                           0.31        16
#    macro avg       0.28      0.31      0.29        16
# weighted avg       0.28      0.31      0.29        16
#
#
# Akurasi
#
# 0.3125
#
# Grafik
#
# 15
# Indosat
#
# Matrik
#
# [[5 7]
#  [4 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.42      0.48        12
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.31        16
#    macro avg       0.28      0.21      0.24        16
# weighted avg       0.42      0.31      0.36        16
#
#
# Akurasi
#
# 0.3125
#
# Grafik
#
# 16
# Indosat
#
# Matrik
#
# [[2 7]
#  [2 5]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.22      0.31         9
#            1       0.42      0.71      0.53         7
#
#     accuracy                           0.44        16
#    macro avg       0.46      0.47      0.42        16
# weighted avg       0.46      0.44      0.40        16
#
#
# Akurasi
#
# 0.4375
#
# Grafik
#
# 17
# Indosat
#
# Matrik
#
# [[1 6]
#  [3 6]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.25      0.14      0.18         7
#            1       0.50      0.67      0.57         9
#
#     accuracy                           0.44        16
#    macro avg       0.38      0.40      0.38        16
# weighted avg       0.39      0.44      0.40        16
#
#
# Akurasi
#
# 0.4375
#
# Grafik
#
# 18
# Indosat
#
# Matrik
#
# [[7 3]
#  [5 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.58      0.70      0.64        10
#            1       0.25      0.17      0.20         6
#
#     accuracy                           0.50        16
#    macro avg       0.42      0.43      0.42        16
# weighted avg       0.46      0.50      0.47        16
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 19
# Indosat
#
# Matrik
#
# [[7 2]
#  [5 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.58      0.78      0.67         9
#            1       0.50      0.29      0.36         7
#
#     accuracy                           0.56        16
#    macro avg       0.54      0.53      0.52        16
# weighted avg       0.55      0.56      0.53        16
#
#
# Akurasi
#
# 0.5625
#
# Grafik
#
# 20
# Indosat
#
# Matrik
#
# [[2 5]
#  [1 7]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.29      0.40         7
#            1       0.58      0.88      0.70         8
#
#     accuracy                           0.60        15
#    macro avg       0.62      0.58      0.55        15
# weighted avg       0.62      0.60      0.56        15
#
#
# Akurasi
#
# 0.6
#
# Grafik
#
# 21
# Indosat
#
# Matrik
#
# [[2 8]
#  [1 4]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.20      0.31        10
#            1       0.33      0.80      0.47         5
#
#     accuracy                           0.40        15
#    macro avg       0.50      0.50      0.39        15
# weighted avg       0.56      0.40      0.36        15
#
#
# Akurasi
#
# 0.4
#
# Grafik
#
# 22
# Indosat
#
# Matrik
#
# [[5 6]
#  [3 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.45      0.53        11
#            1       0.14      0.25      0.18         4
#
#     accuracy                           0.40        15
#    macro avg       0.38      0.35      0.35        15
# weighted avg       0.50      0.40      0.43        15
#
#
# Akurasi
#
# 0.4
#
# Grafik
#
# 23
# Indosat
#
# Matrik
#
# [[6 3]
#  [5 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.55      0.67      0.60         9
#            1       0.25      0.17      0.20         6
#
#     accuracy                           0.47        15
#    macro avg       0.40      0.42      0.40        15
# weighted avg       0.43      0.47      0.44        15
#
#
# Akurasi
#
# 0.4666666666666667
#
# Grafik
#
# 24
# Indosat
#
# Matrik
#
# [[7 5]
#  [2 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.58      0.67        12
#            1       0.17      0.33      0.22         3
#
#     accuracy                           0.53        15
#    macro avg       0.47      0.46      0.44        15
# weighted avg       0.66      0.53      0.58        15
#
#
# Akurasi
#
# 0.5333333333333333
#
# Grafik
#
# 25
# Indosat
#
# Matrik
#
# [[8 2]
#  [5 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.80      0.70        10
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.53        15
#    macro avg       0.31      0.40      0.35        15
# weighted avg       0.41      0.53      0.46        15
#
#
# Akurasi
#
# 0.5333333333333333
#
# Grafik
#
# 26
# Indosat
#
# Matrik
#
# [[4 3]
#  [4 4]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.57      0.53         7
#            1       0.57      0.50      0.53         8
#
#     accuracy                           0.53        15
#    macro avg       0.54      0.54      0.53        15
# weighted avg       0.54      0.53      0.53        15
#
#
# Akurasi
#
# 0.5333333333333333
#
# Grafik
#
# 27
# Indosat
#
# Matrik
#
# [[2 4]
#  [2 7]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.33      0.40         6
#            1       0.64      0.78      0.70         9
#
#     accuracy                           0.60        15
#    macro avg       0.57      0.56      0.55        15
# weighted avg       0.58      0.60      0.58        15
#
#
# Akurasi
#
# 0.6
#
# Grafik
#
# 28
# Indosat
#
# Matrik
#
# [[7 2]
#  [6 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.54      0.78      0.64         9
#            1       0.00      0.00      0.00         6
#
#     accuracy                           0.47        15
#    macro avg       0.27      0.39      0.32        15
# weighted avg       0.32      0.47      0.38        15
#
#
# Akurasi
#
# 0.4666666666666667
#
# Grafik
#
# 29
# Indosat
#
# Matrik
#
# [[9 1]
#  [5 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.90      0.75        10
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.60        15
#    macro avg       0.32      0.45      0.38        15
# weighted avg       0.43      0.60      0.50        15
#
#
# Akurasi
#
# 0.6
#
# Grafik
#
# 30
# Indosat
#
# Matrik
#
# [[5 4]
#  [1 4]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.56      0.67         9
#            1       0.50      0.80      0.62         5
#
#     accuracy                           0.64        14
#    macro avg       0.67      0.68      0.64        14
# weighted avg       0.71      0.64      0.65        14
#
#
# Akurasi
#
# 0.6428571428571429
#
# Grafik
#
# 31
# Indosat
#
# Matrik
#
# [[8 1]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.89      0.76         9
#            1       0.50      0.20      0.29         5
#
#     accuracy                           0.64        14
#    macro avg       0.58      0.54      0.52        14
# weighted avg       0.61      0.64      0.59        14
#
#
# Akurasi
#
# 0.6428571428571429
#
# Grafik
#
# 32
# Indosat
#
# Matrik
#
# [[4 1]
#  [6 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.40      0.80      0.53         5
#            1       0.75      0.33      0.46         9
#
#     accuracy                           0.50        14
#    macro avg       0.57      0.57      0.50        14
# weighted avg       0.62      0.50      0.49        14
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 33
# Indosat
#
# Matrik
#
# [[4 2]
#  [7 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.36      0.67      0.47         6
#            1       0.33      0.12      0.18         8
#
#     accuracy                           0.36        14
#    macro avg       0.35      0.40      0.33        14
# weighted avg       0.35      0.36      0.31        14
#
#
# Akurasi
#
# 0.35714285714285715
#
# Grafik
#
# 34
# Indosat
#
# Matrik
#
# [[5 3]
#  [3 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.62      0.62         8
#            1       0.50      0.50      0.50         6
#
#     accuracy                           0.57        14
#    macro avg       0.56      0.56      0.56        14
# weighted avg       0.57      0.57      0.57        14
#
#
# Akurasi
#
# 0.5714285714285714
#
# Grafik
#
# 35
# Indosat
#
# Matrik
#
# [[6 4]
#  [4 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.60      0.60        10
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.43        14
#    macro avg       0.30      0.30      0.30        14
# weighted avg       0.43      0.43      0.43        14
#
#
# Akurasi
#
# 0.42857142857142855
#
# Grafik
#
# 36
# Indosat
#
# Matrik
#
# [[6 3]
#  [5 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.55      0.67      0.60         9
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.43        14
#    macro avg       0.27      0.33      0.30        14
# weighted avg       0.35      0.43      0.39        14
#
#
# Akurasi
#
# 0.42857142857142855
#
# Grafik
#
# 37
# Indosat
#
# Matrik
#
# [[6 3]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.67      0.71         9
#            1       0.50      0.60      0.55         5
#
#     accuracy                           0.64        14
#    macro avg       0.62      0.63      0.63        14
# weighted avg       0.66      0.64      0.65        14
#
#
# Akurasi
#
# 0.6428571428571429
#
# Grafik
#
# 38
# Indosat
#
# Matrik
#
# [[4 3]
#  [1 6]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.57      0.67         7
#            1       0.67      0.86      0.75         7
#
#     accuracy                           0.71        14
#    macro avg       0.73      0.71      0.71        14
# weighted avg       0.73      0.71      0.71        14
#
#
# Akurasi
#
# 0.7142857142857143
#
# Grafik
#
# 39
# Indosat
#
# Matrik
#
# [[3 5]
#  [4 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.43      0.38      0.40         8
#            1       0.29      0.33      0.31         6
#
#     accuracy                           0.36        14
#    macro avg       0.36      0.35      0.35        14
# weighted avg       0.37      0.36      0.36        14
#
#
# Akurasi
#
# 0.35714285714285715
#
# Grafik
#
# 40
# Indosat
#
# Matrik
#
# [[2 7]
#  [3 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.40      0.22      0.29         9
#            1       0.12      0.25      0.17         4
#
#     accuracy                           0.23        13
#    macro avg       0.26      0.24      0.23        13
# weighted avg       0.32      0.23      0.25        13
#
#
# Akurasi
#
# 0.23076923076923078
#
# Grafik
#
# 41
# Indosat
#
# Matrik
#
# [[7 4]
#  [2 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.64      0.70        11
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.54        13
#    macro avg       0.39      0.32      0.35        13
# weighted avg       0.66      0.54      0.59        13
#
#
# Akurasi
#
# 0.5384615384615384
#
# Grafik
#
# 42
# Indosat
#
# Matrik
#
# [[3 4]
#  [4 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.43      0.43      0.43         7
#            1       0.33      0.33      0.33         6
#
#     accuracy                           0.38        13
#    macro avg       0.38      0.38      0.38        13
# weighted avg       0.38      0.38      0.38        13
#
#
# Akurasi
#
# 0.38461538461538464
#
# Grafik
#
# 43
# Indosat
#
# Matrik
#
# [[5 5]
#  [0 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67        10
#            1       0.38      1.00      0.55         3
#
#     accuracy                           0.62        13
#    macro avg       0.69      0.75      0.61        13
# weighted avg       0.86      0.62      0.64        13
#
#
# Akurasi
#
# 0.6153846153846154
#
# Grafik
#
# 44
# Indosat
#
# Matrik
#
# [[1 4]
#  [6 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.14      0.20      0.17         5
#            1       0.33      0.25      0.29         8
#
#     accuracy                           0.23        13
#    macro avg       0.24      0.23      0.23        13
# weighted avg       0.26      0.23      0.24        13
#
#
# Akurasi
#
# 0.23076923076923078
#
# Grafik
#
# 45
# Indosat
#
# Matrik
#
# [[5 4]
#  [3 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.56      0.59         9
#            1       0.20      0.25      0.22         4
#
#     accuracy                           0.46        13
#    macro avg       0.41      0.40      0.41        13
# weighted avg       0.49      0.46      0.48        13
#
#
# Akurasi
#
# 0.46153846153846156
#
# Grafik
#
# 46
# Indosat
#
# Matrik
#
# [[3 2]
#  [6 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.33      0.60      0.43         5
#            1       0.50      0.25      0.33         8
#
#     accuracy                           0.38        13
#    macro avg       0.42      0.42      0.38        13
# weighted avg       0.44      0.38      0.37        13
#
#
# Akurasi
#
# 0.38461538461538464
#
# Grafik
#
# 47
# Indosat
#
# Matrik
#
# [[3 3]
#  [4 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.43      0.50      0.46         6
#            1       0.50      0.43      0.46         7
#
#     accuracy                           0.46        13
#    macro avg       0.46      0.46      0.46        13
# weighted avg       0.47      0.46      0.46        13
#
#
# Akurasi
#
# 0.46153846153846156
#
# Grafik
#
# 48
# Indosat
#
# Matrik
#
# [[3 3]
#  [4 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.43      0.50      0.46         6
#            1       0.50      0.43      0.46         7
#
#     accuracy                           0.46        13
#    macro avg       0.46      0.46      0.46        13
# weighted avg       0.47      0.46      0.46        13
#
#
# Akurasi
#
# 0.46153846153846156
#
# Grafik
#
# 49
# Indosat
#
# Matrik
#
# [[6 1]
#  [4 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.86      0.71         7
#            1       0.67      0.33      0.44         6
#
#     accuracy                           0.62        13
#    macro avg       0.63      0.60      0.58        13
# weighted avg       0.63      0.62      0.59        13
#
#
# Akurasi
#
# 0.6153846153846154
#
# Grafik
#
# 50
# Indosat
#
# Matrik
#
# [[5 2]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.71      0.67         7
#            1       0.50      0.40      0.44         5
#
#     accuracy                           0.58        12
#    macro avg       0.56      0.56      0.56        12
# weighted avg       0.57      0.58      0.57        12
#
#
# Akurasi
#
# 0.5833333333333334
#
# Grafik
#
# 51
# Indosat
#
# Matrik
#
# [[2 2]
#  [3 5]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.40      0.50      0.44         4
#            1       0.71      0.62      0.67         8
#
#     accuracy                           0.58        12
#    macro avg       0.56      0.56      0.56        12
# weighted avg       0.61      0.58      0.59        12
#
#
# Akurasi
#
# 0.5833333333333334
#
# Grafik
#
# 52
# Indosat
#
# Matrik
#
# [[3 5]
#  [2 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.38      0.46         8
#            1       0.29      0.50      0.36         4
#
#     accuracy                           0.42        12
#    macro avg       0.44      0.44      0.41        12
# weighted avg       0.50      0.42      0.43        12
#
#
# Akurasi
#
# 0.4166666666666667
#
# Grafik
#
# 53
# Indosat
#
# Matrik
#
# [[4 3]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.57      0.62         7
#            1       0.50      0.60      0.55         5
#
#     accuracy                           0.58        12
#    macro avg       0.58      0.59      0.58        12
# weighted avg       0.60      0.58      0.59        12
#
#
# Akurasi
#
# 0.5833333333333334
#
# Grafik
#
# 54
# Indosat
#
# Matrik
#
# [[4 3]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.57      0.57         7
#            1       0.40      0.40      0.40         5
#
#     accuracy                           0.50        12
#    macro avg       0.49      0.49      0.49        12
# weighted avg       0.50      0.50      0.50        12
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 55
# Indosat
#
# Matrik
#
# [[4 2]
#  [5 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.44      0.67      0.53         6
#            1       0.33      0.17      0.22         6
#
#     accuracy                           0.42        12
#    macro avg       0.39      0.42      0.38        12
# weighted avg       0.39      0.42      0.38        12
#
#
# Akurasi
#
# 0.4166666666666667
#
# Grafik
#
# 56
# Indosat
#
# Matrik
#
# [[2 3]
#  [4 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.33      0.40      0.36         5
#            1       0.50      0.43      0.46         7
#
#     accuracy                           0.42        12
#    macro avg       0.42      0.41      0.41        12
# weighted avg       0.43      0.42      0.42        12
#
#
# Akurasi
#
# 0.4166666666666667
#
# Grafik
#
# 57
# Indosat
#
# Matrik
#
# [[6 2]
#  [1 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.75      0.80         8
#            1       0.60      0.75      0.67         4
#
#     accuracy                           0.75        12
#    macro avg       0.73      0.75      0.73        12
# weighted avg       0.77      0.75      0.76        12
#
#
# Akurasi
#
# 0.75
#
# Grafik
#
# 58
# Indosat
#
# Matrik
#
# [[4 3]
#  [2 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.57      0.62         7
#            1       0.50      0.60      0.55         5
#
#     accuracy                           0.58        12
#    macro avg       0.58      0.59      0.58        12
# weighted avg       0.60      0.58      0.59        12
#
#
# Akurasi
#
# 0.5833333333333334
#
# Grafik
#
# 59
# Indosat
#
# Matrik
#
# [[2 1]
#  [5 4]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.29      0.67      0.40         3
#            1       0.80      0.44      0.57         9
#
#     accuracy                           0.50        12
#    macro avg       0.54      0.56      0.49        12
# weighted avg       0.67      0.50      0.53        12
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 60
# Indosat
#
# Matrik
#
# [[7 0]
#  [3 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.82         7
#            1       1.00      0.25      0.40         4
#
#     accuracy                           0.73        11
#    macro avg       0.85      0.62      0.61        11
# weighted avg       0.81      0.73      0.67        11
#
#
# Akurasi
#
# 0.7272727272727273
#
# Grafik
#
# 61
# Indosat
#
# Matrik
#
# [[6 2]
#  [2 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75         8
#            1       0.33      0.33      0.33         3
#
#     accuracy                           0.64        11
#    macro avg       0.54      0.54      0.54        11
# weighted avg       0.64      0.64      0.64        11
#
#
# Akurasi
#
# 0.6363636363636364
#
# Grafik
#
# 62
# Indosat
#
# Matrik
#
# [[6 4]
#  [0 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.60      0.75        10
#            1       0.20      1.00      0.33         1
#
#     accuracy                           0.64        11
#    macro avg       0.60      0.80      0.54        11
# weighted avg       0.93      0.64      0.71        11
#
#
# Akurasi
#
# 0.6363636363636364
#
# Grafik
#
# 63
# Indosat
#
# Matrik
#
# [[3 6]
#  [0 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.33      0.50         9
#            1       0.25      1.00      0.40         2
#
#     accuracy                           0.45        11
#    macro avg       0.62      0.67      0.45        11
# weighted avg       0.86      0.45      0.48        11
#
#
# Akurasi
#
# 0.45454545454545453
#
# Grafik
#
# 64
# Indosat
#
# Matrik
#
# [[3 4]
#  [0 4]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.43      0.60         7
#            1       0.50      1.00      0.67         4
#
#     accuracy                           0.64        11
#    macro avg       0.75      0.71      0.63        11
# weighted avg       0.82      0.64      0.62        11
#
#
# Akurasi
#
# 0.6363636363636364
#
# Grafik
#
# 65
# Indosat
#
# Matrik
#
# [[2 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.40      0.33      0.36         6
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.36        11
#    macro avg       0.37      0.37      0.36        11
# weighted avg       0.37      0.36      0.36        11
#
#
# Akurasi
#
# 0.36363636363636365
#
# Grafik
#
# 66
# Indosat
#
# Matrik
#
# [[4 4]
#  [1 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.50      0.62         8
#            1       0.33      0.67      0.44         3
#
#     accuracy                           0.55        11
#    macro avg       0.57      0.58      0.53        11
# weighted avg       0.67      0.55      0.57        11
#
#
# Akurasi
#
# 0.5454545454545454
#
# Grafik
#
# 67
# Indosat
#
# Matrik
#
# [[4 3]
#  [3 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.57      0.57         7
#            1       0.25      0.25      0.25         4
#
#     accuracy                           0.45        11
#    macro avg       0.41      0.41      0.41        11
# weighted avg       0.45      0.45      0.45        11
#
#
# Akurasi
#
# 0.45454545454545453
#
# Grafik
#
# 68
# Indosat
#
# Matrik
#
# [[5 0]
#  [2 4]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83         5
#            1       1.00      0.67      0.80         6
#
#     accuracy                           0.82        11
#    macro avg       0.86      0.83      0.82        11
# weighted avg       0.87      0.82      0.82        11
#
#
# Akurasi
#
# 0.8181818181818182
#
# Grafik
#
# 69
# Indosat
#
# Matrik
#
# [[4 3]
#  [2 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.57      0.62         7
#            1       0.40      0.50      0.44         4
#
#     accuracy                           0.55        11
#    macro avg       0.53      0.54      0.53        11
# weighted avg       0.57      0.55      0.55        11
#
#
# Akurasi
#
# 0.5454545454545454
#
# Grafik
#
# 70
# Indosat
#
# Matrik
#
# [[4 1]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.80      0.62         5
#            1       0.50      0.20      0.29         5
#
#     accuracy                           0.50        10
#    macro avg       0.50      0.50      0.45        10
# weighted avg       0.50      0.50      0.45        10
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 71
# Indosat
#
# Matrik
#
# [[3 6]
#  [0 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.33      0.50         9
#            1       0.14      1.00      0.25         1
#
#     accuracy                           0.40        10
#    macro avg       0.57      0.67      0.38        10
# weighted avg       0.91      0.40      0.47        10
#
#
# Akurasi
#
# 0.4
#
# Grafik
#
# 72
# Indosat
#
# Matrik
#
# [[4 1]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.80      0.67         5
#            1       0.67      0.40      0.50         5
#
#     accuracy                           0.60        10
#    macro avg       0.62      0.60      0.58        10
# weighted avg       0.62      0.60      0.58        10
#
#
# Akurasi
#
# 0.6
#
# Grafik
#
# 73
# Indosat
#
# Matrik
#
# [[6 1]
#  [0 3]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.86      0.92         7
#            1       0.75      1.00      0.86         3
#
#     accuracy                           0.90        10
#    macro avg       0.88      0.93      0.89        10
# weighted avg       0.93      0.90      0.90        10
#
#
# Akurasi
#
# 0.9
#
# Grafik
#
# 74
# Indosat
#
# Matrik
#
# [[2 2]
#  [2 4]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50         4
#            1       0.67      0.67      0.67         6
#
#     accuracy                           0.60        10
#    macro avg       0.58      0.58      0.58        10
# weighted avg       0.60      0.60      0.60        10
#
#
# Akurasi
#
# 0.6
#
# Grafik
#
# 75
# Indosat
#
# Matrik
#
# [[3 2]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.60      0.55         5
#            1       0.50      0.40      0.44         5
#
#     accuracy                           0.50        10
#    macro avg       0.50      0.50      0.49        10
# weighted avg       0.50      0.50      0.49        10
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 76
# Indosat
#
# Matrik
#
# [[4 3]
#  [1 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.57      0.67         7
#            1       0.40      0.67      0.50         3
#
#     accuracy                           0.60        10
#    macro avg       0.60      0.62      0.58        10
# weighted avg       0.68      0.60      0.62        10
#
#
# Akurasi
#
# 0.6
#
# Grafik
#
# 77
# Indosat
#
# Matrik
#
# [[5 1]
#  [2 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.83      0.77         6
#            1       0.67      0.50      0.57         4
#
#     accuracy                           0.70        10
#    macro avg       0.69      0.67      0.67        10
# weighted avg       0.70      0.70      0.69        10
#
#
# Akurasi
#
# 0.7
#
# Grafik
#
# 78
# Indosat
#
# Matrik
#
# [[6 1]
#  [1 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86         7
#            1       0.67      0.67      0.67         3
#
#     accuracy                           0.80        10
#    macro avg       0.76      0.76      0.76        10
# weighted avg       0.80      0.80      0.80        10
#
#
# Akurasi
#
# 0.8
#
# Grafik
#
# 79
# Indosat
#
# Matrik
#
# [[5 1]
#  [2 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.83      0.77         6
#            1       0.67      0.50      0.57         4
#
#     accuracy                           0.70        10
#    macro avg       0.69      0.67      0.67        10
# weighted avg       0.70      0.70      0.69        10
#
#
# Akurasi
#
# 0.7
#
# Grafik
#
# 80
# Indosat
#
# Matrik
#
# [[4 1]
#  [3 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.80      0.67         5
#            1       0.50      0.25      0.33         4
#
#     accuracy                           0.56         9
#    macro avg       0.54      0.53      0.50         9
# weighted avg       0.54      0.56      0.52         9
#
#
# Akurasi
#
# 0.5555555555555556
#
# Grafik
#
# 81
# Indosat
#
# Matrik
#
# [[5 2]
#  [2 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.71      0.71         7
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.56         9
#    macro avg       0.36      0.36      0.36         9
# weighted avg       0.56      0.56      0.56         9
#
#
# Akurasi
#
# 0.5555555555555556
#
# Grafik
#
# 82
# Indosat
#
# Matrik
#
# [[3 3]
#  [2 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.50      0.55         6
#            1       0.25      0.33      0.29         3
#
#     accuracy                           0.44         9
#    macro avg       0.42      0.42      0.42         9
# weighted avg       0.48      0.44      0.46         9
#
#
# Akurasi
#
# 0.4444444444444444
#
# Grafik
#
# 83
# Indosat
#
# Matrik
#
# [[1 4]
#  [3 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.25      0.20      0.22         5
#            1       0.20      0.25      0.22         4
#
#     accuracy                           0.22         9
#    macro avg       0.23      0.23      0.22         9
# weighted avg       0.23      0.22      0.22         9
#
#
# Akurasi
#
# 0.2222222222222222
#
# Grafik
#
# 84
# Indosat
#
# Matrik
#
# [[3 2]
#  [2 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.60      0.60         5
#            1       0.50      0.50      0.50         4
#
#     accuracy                           0.56         9
#    macro avg       0.55      0.55      0.55         9
# weighted avg       0.56      0.56      0.56         9
#
#
# Akurasi
#
# 0.5555555555555556
#
# Grafik
#
# 85
# Indosat
#
# Matrik
#
# [[4 1]
#  [2 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.80      0.73         5
#            1       0.67      0.50      0.57         4
#
#     accuracy                           0.67         9
#    macro avg       0.67      0.65      0.65         9
# weighted avg       0.67      0.67      0.66         9
#
#
# Akurasi
#
# 0.6666666666666666
#
# Grafik
#
# 86
# Indosat
#
# Matrik
#
# [[3 3]
#  [3 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50         6
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.33         9
#    macro avg       0.25      0.25      0.25         9
# weighted avg       0.33      0.33      0.33         9
#
#
# Akurasi
#
# 0.3333333333333333
#
# Grafik
#
# 87
# Indosat
#
# Matrik
#
# [[0 4]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.33      0.40      0.36         5
#
#     accuracy                           0.22         9
#    macro avg       0.17      0.20      0.18         9
# weighted avg       0.19      0.22      0.20         9
#
#
# Akurasi
#
# 0.2222222222222222
#
# Grafik
#
# 88
# Indosat
#
# Matrik
#
# [[2 4]
#  [2 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.33      0.40         6
#            1       0.20      0.33      0.25         3
#
#     accuracy                           0.33         9
#    macro avg       0.35      0.33      0.33         9
# weighted avg       0.40      0.33      0.35         9
#
#
# Akurasi
#
# 0.3333333333333333
#
# Grafik
#
# 89
# Indosat
#
# Matrik
#
# [[1 3]
#  [1 4]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.25      0.33         4
#            1       0.57      0.80      0.67         5
#
#     accuracy                           0.56         9
#    macro avg       0.54      0.53      0.50         9
# weighted avg       0.54      0.56      0.52         9
#
#
# Akurasi
#
# 0.5555555555555556
#
# Grafik
#
# 90
# Indosat
#
# Matrik
#
# [[2 1]
#  [3 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.40      0.67      0.50         3
#            1       0.67      0.40      0.50         5
#
#     accuracy                           0.50         8
#    macro avg       0.53      0.53      0.50         8
# weighted avg       0.57      0.50      0.50         8
#
#
# Akurasi
#
# 0.5
#
# Grafik
#
# 91
# Indosat
#
# Matrik
#
# [[4 3]
#  [0 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.57      0.73         7
#            1       0.25      1.00      0.40         1
#
#     accuracy                           0.62         8
#    macro avg       0.62      0.79      0.56         8
# weighted avg       0.91      0.62      0.69         8
#
#
# Akurasi
#
# 0.625
#
# Grafik
#
# 92
# Indosat
#
# Matrik
#
# [[2 5]
#  [1 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.29      0.40         7
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.25         8
#    macro avg       0.33      0.14      0.20         8
# weighted avg       0.58      0.25      0.35         8
#
#
# Akurasi
#
# 0.25
#
# Grafik
#
# 93
# Indosat
#
# Matrik
#
# [[3 3]
#  [2 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.50      0.55         6
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.38         8
#    macro avg       0.30      0.25      0.27         8
# weighted avg       0.45      0.38      0.41         8
#
#
# Akurasi
#
# 0.375
#
# Grafik
#
# 94
# Indosat
#
# Matrik
#
# [[0 3]
#  [4 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         3
#            1       0.25      0.20      0.22         5
#
#     accuracy                           0.12         8
#    macro avg       0.12      0.10      0.11         8
# weighted avg       0.16      0.12      0.14         8
#
#
# Akurasi
#
# 0.125
#
# Grafik
#
# 95
# Indosat
#
# Matrik
#
# [[4 1]
#  [1 2]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80         5
#            1       0.67      0.67      0.67         3
#
#     accuracy                           0.75         8
#    macro avg       0.73      0.73      0.73         8
# weighted avg       0.75      0.75      0.75         8
#
#
# Akurasi
#
# 0.75
#
# Grafik
#
# 96
# Indosat
#
# Matrik
#
# [[3 1]
#  [4 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.43      0.75      0.55         4
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.38         8
#    macro avg       0.21      0.38      0.27         8
# weighted avg       0.21      0.38      0.27         8
#
#
# Akurasi
#
# 0.375
#
# Grafik
#
# 97
# Indosat
#
# Matrik
#
# [[2 3]
#  [2 1]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.40      0.44         5
#            1       0.25      0.33      0.29         3
#
#     accuracy                           0.38         8
#    macro avg       0.38      0.37      0.37         8
# weighted avg       0.41      0.38      0.38         8
#
#
# Akurasi
#
# 0.375
#
# Grafik
#
# 98
# Indosat
#
# Matrik
#
# [[6 2]
#  [0 0]]
#
# Hasil
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       1.00      0.75      0.86         8
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.75         8
#    macro avg       0.50      0.38      0.43         8
# weighted avg       1.00      0.75      0.86         8
#
#
# Akurasi
#
# 0.75
#
# Grafik
#
# 99
# Indosat
#
# Matrik
#
# [[2 3]
#  [3 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.40      0.40      0.40         5
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.25         8
#    macro avg       0.20      0.20      0.20         8
# weighted avg       0.25      0.25      0.25         8
#
#
# Akurasi
#
# 0.25
#
# Grafik

# %%
x_train, x_test, y_train, y_test = klasifikasiData(data='indosat', split_jadi=81)
klasifikasiSGDClassifier = make_pipeline(StandardScaler(),SGDClassifier(max_iter=100, tol=1e-3))
klasifikasiSGDClassifier.fit(x_train, y_train)
predic_y = klasifikasiSGDClassifier.predict(x_test)
  
printHasil(y_test, predic_y, "Indosat")
import pickle
file = open('SGD_indosat.otak', 'wb')

# dump information to that file
pickle.dump(klasifikasiSGDClassifier, file)

# close the file
file.close()
# Out:
# Indosat
#
# Matrik
#
# [[7 0]
#  [2 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.78      1.00      0.88         7
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.78         9
#    macro avg       0.39      0.50      0.44         9
# weighted avg       0.60      0.78      0.68         9
#
#
# Akurasi
#
# 0.7777777777777778
#
# Grafik
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Smartfren
for totalsplit in range(5,100):
  x_train, x_test, y_train, y_test = klasifikasiData(data='freen', split_jadi=totalsplit)
  klasifikasiSGDClassifier = make_pipeline(StandardScaler(),SGDClassifier(max_iter=100, tol=1e-3))
  klasifikasiSGDClassifier.fit(x_train, y_train)
  predic_y = klasifikasiSGDClassifier.predict(x_test)
  print(totalsplit)

  printHasil(y_test, predic_y, "Freen")

# %%
x_train, x_test, y_train, y_test = klasifikasiData(data='freen', split_jadi=59)
klasifikasiSGDClassifier = make_pipeline(StandardScaler(),SGDClassifier(max_iter=100, tol=1e-3))
klasifikasiSGDClassifier.fit(x_train, y_train)
predic_y = klasifikasiSGDClassifier.predict(x_test)
  
printHasil(y_test, predic_y, "Freen")
import pickle
file = open('SGD_Freen.otak', 'wb')

# dump information to that file
pickle.dump(klasifikasiSGDClassifier, file)

# close the file
file.close()
# Out:
# Freen
#
# Matrik
#
# [[8 3]
#  [1 0]]
#
# Hasil
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.73      0.80        11
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.67        12
#    macro avg       0.44      0.36      0.40        12
# weighted avg       0.81      0.67      0.73        12
#
#
# Akurasi
#
# 0.6666666666666666
#
# Grafik
